# %%
import os
dir_root = os.getcwd()
dir_root
# Out:
# '/content'

# %%
os.listdir(dir_root)
# Out:
# ['.config', 'sample_data']

# %%
from google.colab import drive
drive.mount('/content/drive/', force_remount=True)
# Out:
# Mounted at /content/drive/

# %%
import pathlib
dir_images = "/content/drive/My Drive/MA_RGB_fil_100"

# %%
dir_grado1 = os.path.join(dir_images, 'grd0_ma')
dir_grado2 = os.path.join(dir_images, 'grd1_ma')
dir_grado3 = os.path.join(dir_images, 'grd2_ma')
dir_grado4 = os.path.join(dir_images, 'grd3_ma')
dir_grado5 = os.path.join(dir_images, 'grd4_ma')

# %%
dir_grado1
# Out:
# '/content/drive/My Drive/MA_RGB_fil_100/grd0_ma'

# %%
len(os.listdir(dir_grado1))
# Out:
# 100

# %%
import numpy as np
import pandas as pd
pd.__version__
# Out:
# '1.1.5'

# %%
import numpy as np
import os
import re
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
import keras
#from keras.utils import to_categorical
from keras.models import Sequential,Input,Model
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
#from keras.layers.normalization import BatchNormalization
from keras.layers.advanced_activations import LeakyReLU
import tensorflow as tf

# %%
dirname = os.path.join(os.getcwd(), dir_images)

# %%
imgpath = dirname + os.sep

# %%
imgpath
# Out:
# '/content/drive/My Drive/MA_RGB_fil_100/'

# %%
images = []
directories = []
dircount = []
prevRoot=''
cant=0

print("leyendo imagenes de ",imgpath)
# Out:
# leyendo imagenes de  /content/drive/My Drive/MA_RGB_fil_100/

# %%
for root, dirnames, filenames in os.walk(imgpath):
    for filename in filenames:
        if re.search("\.(jpg|jpeg|png|bmp|tiff)$", filename):
            cant=cant+1
            filepath = os.path.join(root, filename)
            image = plt.imread(filepath)
            images.append(image)
            b = "Leyendo..." + str(cant)
            print (b, end="\r")
            if prevRoot !=root:
                print(root, cant)
                prevRoot=root
                directories.append(root)
                dircount.append(cant)
                cant=0
dircount.append(cant)

dircount = dircount[1:]
dircount[0]=dircount[0]+1
print('Directorios leidos:',len(directories))
print("Imagenes en cada directorio", dircount)
print('suma Total de imagenes en subdirs:',sum(dircount))
# Out:
# /content/drive/My Drive/MA_RGB_fil_100/grd0_ma 1
# /content/drive/My Drive/MA_RGB_fil_100/grd1_ma 100
# /content/drive/My Drive/MA_RGB_fil_100/grd2_ma 100
# /content/drive/My Drive/MA_RGB_fil_100/grd3_ma 100
# /content/drive/My Drive/MA_RGB_fil_100/grd4_ma 100
# Directorios leidos: 5
# Imagenes en cada directorio [101, 100, 100, 100, 99]
# suma Total de imagenes en subdirs: 500

# %%
labels=[]
indice=0
for cantidad in dircount:
    for i in range(cantidad):
        labels.append(indice)
    indice=indice+1
print("Cantidad etiquetas creadas: ",len(labels))

deportes=[]
indice=0
for directorio in directories:
    name = directorio.split(os.sep)
    print(indice , name[len(name)-1])
    deportes.append(name[len(name)-1])
    indice=indice+1

y = np.array(labels)
X = np.array(images, dtype=np.uint8) #convierto de lista a numpy

# Find the unique numbers from the train labels
classes = np.unique(y)
nClasses = len(classes)
print('Total number of outputs : ', nClasses)
print('Output classes : ', classes)
# Out:
# Cantidad etiquetas creadas:  500
# 0 grd0_ma
# 1 grd1_ma
# 2 grd2_ma
# 3 grd3_ma
# 4 grd4_ma
# Total number of outputs :  5
# Output classes :  [0 1 2 3 4]

# %%
#from keras.utils import to_categorical
from tensorflow.keras.utils import to_categorical
#Mezclar todo y crear los grupos de entrenamiento y testing
train_x,x_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=13)
print('Training data shape : ', train_x.shape, y_train.shape)
print('Testing data shape : ', x_test.shape, y_test.shape)

train_x = train_x.astype('float32')
x_test = x_test.astype('float32')
train_x = train_x / 255.
x_test = x_test / 255.

# Change the labels from categorical to one-hot encoding
train_Y_one_hot = to_categorical(y_train)
test_Y_one_hot = to_categorical(y_test)

# Display the change for category label using one-hot encoding
print('Original label:', y_train[0])
print('After conversion to one-hot:', train_Y_one_hot[0])

train_x,valid_X,train_label,valid_label = train_test_split(train_x, train_Y_one_hot, test_size=0.2, random_state=13)

print(train_x.shape,valid_X.shape,train_label.shape,valid_label.shape)
# Out:
# Training data shape :  (400, 100, 100, 3) (400,)
# Testing data shape :  (100, 100, 100, 3) (100,)
# Original label: 2
# After conversion to one-hot: [0. 0. 1. 0. 0.]
# (320, 100, 100, 3) (80, 100, 100, 3) (320, 5) (80, 5)

# %%
import keras
from keras.models import Sequential,Input,Model
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
#from keras.layers.normalization import BatchNormalization
from keras.layers.advanced_activations import LeakyReLU
import tensorflow as tf

# %%
INIT_LR = 1e-4
epochs = 100
batch_size = 64

model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3),activation='linear',padding='same',input_shape=(100,100,3)))
model.add(LeakyReLU(alpha=0.1))
model.add(MaxPooling2D((2, 2),padding='same'))
model.add(Dropout(0.5))

model.add(Conv2D(64, (3, 3), activation='linear',padding='same'))
model.add(LeakyReLU(alpha=0.1))
model.add(MaxPooling2D(pool_size=(2, 2),padding='same'))
model.add(Dropout(0.5))
model.add(Conv2D(128, (3, 3), activation='linear',padding='same'))
model.add(LeakyReLU(alpha=0.1))
model.add(MaxPooling2D(pool_size=(2, 2),padding='same'))
model.add(Dropout(0.5))


model.add(Flatten())
model.add(Dense(128, activation='linear'))
model.add(LeakyReLU(alpha=0.1))
model.add(Dropout(0.5))
model.add(Dense(nClasses, activation='softmax'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 100, 100, 32)      896
#
#  leaky_re_lu (LeakyReLU)     (None, 100, 100, 32)      0
#
#  max_pooling2d (MaxPooling2D  (None, 50, 50, 32)       0
#  )
#
#  dropout (Dropout)           (None, 50, 50, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 50, 50, 64)        18496
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 50, 50, 64)        0
#
#  max_pooling2d_1 (MaxPooling  (None, 25, 25, 64)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 25, 25, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 25, 25, 128)       73856
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 25, 25, 128)       0
#
#  max_pooling2d_2 (MaxPooling  (None, 13, 13, 128)      0
#  2D)
#
#  dropout_2 (Dropout)         (None, 13, 13, 128)       0
#
#  flatten (Flatten)           (None, 21632)             0
#
#  dense (Dense)               (None, 128)               2769024
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 128)               0
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 5)                 645
#
# =================================================================
# Total params: 2,862,917
# Trainable params: 2,862,917
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss=keras.losses.categorical_crossentropy, optimizer=tf.keras.optimizers.Adam(learning_rate=INIT_LR, decay=INIT_LR / 100),metrics=['accuracy'])

# %%
callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0.0001, patience=3)

grado_train_dropout = model.fit(train_x, train_label, batch_size=batch_size,epochs=epochs,verbose=1,validation_data=(valid_X, valid_label),callbacks=[callback])
# Out:
# Epoch 1/100
# 5/5 [==============================] - 9s 2s/step - loss: 1.7804 - accuracy: 0.2000 - val_loss: 1.6260 - val_accuracy: 0.1875
# Epoch 2/100
# 5/5 [==============================] - 8s 2s/step - loss: 1.7108 - accuracy: 0.2281 - val_loss: 1.6058 - val_accuracy: 0.2375
# Epoch 3/100
# 5/5 [==============================] - 8s 2s/step - loss: 1
100
# 5/5 [==============================] - 8s 2s/step - loss: 0.9566 - accuracy: 0.6094 - val_loss: 1.2414 - val_accuracy: 0.5125
# Epoch 33/100
# 5/5 [==============================] - 8s 2s/step - loss: 0.9494 - accuracy: 0.5813 - val_loss: 1.2143 - val_accuracy: 0.5750
# Epoch 34/100
# 5/5 [==============================] - 8s 2s/step - loss: 0.9082 - accuracy: 0.6313 - val_loss: 1.2432 - val_accuracy: 0.5250
# Epoch 35/100
# 5/5 [==============================] - 8s 2s/step - loss: 0.9356 - accuracy: 0.6094 - val_loss: 1.1921 - val_accuracy: 0.5750
# Epoch 36/100
# 5/5 [==============================] - 8s 2s/step - loss: 0.9007 - accuracy: 0.6313 - val_loss: 1.2122 - val_accuracy: 0.5375
# Epoch 37/100
# 5/5 [==============================] - 8s 2s/step - loss: 0.9083 - accuracy: 0.6250 - val_loss: 1.1903 - val_accuracy: 0.5750
# Epoch 38/100
# 5/5 [==============================] - 8s 2s/step - loss: 0.8601 - accuracy: 0.6313 - val_loss: 1.1802 - val_accuracy: 0.5625
# Epoch 39/100
# 5/5 [==============================] - 8s 2s/step - loss: 0.8511 - accuracy: 0.6562 - val_loss: 1.1769 - val_accuracy: 0.5375
# Epoch 40/100
# 5/5 [==============================] - 8s 2s/step - loss: 0.8704 - accuracy: 0.6062 - val_loss: 1.1582 - val_accuracy: 0.6000
# Epoch 41/100
# 5/5 [==============================] - 8s 2s/step - loss: 0.8542 - accuracy: 0.6500 - val_loss: 1.1639 - val_accuracy: 0.5750
# Epoch 42/100
# 5/5 [==============================] - 8s 2s/step - loss: 0.8305 - accuracy: 0.6875 - val_loss: 1.1567 - val_accuracy: 0.5625
# Epoch 43/100
# 5/5 [==============================] - 8s 2s/step - loss: 0.8092 - accuracy: 0.6469 - val_loss: 1.1420 - val_accuracy: 0.6000
# Epoch 44/100
# 5/5 [==============================] - 8s 2s/step - loss: 0.7942 - accuracy: 0.7000 - val_loss: 1.1505 - val_accuracy: 0.5875
# Epoch 45/100
# 5/5 [==============================] - 8s 2s/step - loss: 0.8035 - accuracy: 0.6625 - val_loss: 1.1287 - val_accuracy: 0.5750
# Epoch 46/100
# 5/5 [==============================] - 8s 2s/step - loss: 0.7962 - accuracy: 0.6625 - val_loss: 1.1357 - val_accuracy: 0.5750
# Epoch 47/100
# 5/5 [==============================] - 8s 2s/step - loss: 0.7797 - accuracy: 0.6969 - val_loss: 1.1219 - val_accuracy: 0.6000
# Epoch 48/100
# 5/5 [==============================] - 8s 2s/step - loss: 0.7726 - accuracy: 0.6750 - val_loss: 1.1156 - val_accuracy: 0.5875
# Epoch 49/100
# 5/5 [==============================] - 8s 2s/step - loss: 0.7986 - accuracy: 0.6375 - val_loss: 1.1330 - val_accuracy: 0.5750
# Epoch 50/100
# 5/5 [==============================] - 8s 2s/step - loss: 0.7364 - accuracy: 0.7094 - val_loss: 1.1179 - val_accuracy: 0.5875
# Epoch 51/100
# 5/5 [==============================] - 8s 2s/step - loss: 0.7366 - accuracy: 0.7000 - val_loss: 1.1245 - val_accuracy: 0.5750

# %% [markdown]
# ***RPUEBA MOBILENETV2***

# %%
preprocess_input = tf.keras.applications.mobilenet_v2.preprocess_input

# %%
rescale = tf.keras.layers.experimental.preprocessing.Rescaling(1./127.5, offset= -1)

# %%
IMG_SIZE = (100, 100)
img_height=100
img_width=100

IMG_SHAPE = IMG_SIZE + (3,)
base_model = tf.keras.applications.MobileNetV2(input_shape=IMG_SHAPE,
                                               include_top=False,
                                               weights='imagenet')
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9412608/9406464 [==============================] - 0s 0us/step
# 9420800/9406464 [==============================] - 0s 0us/step

# %%
base_model.trainable = False

base_model.summary()
# Out:
# Model: "mobilenetv2_1.00_224"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 100, 100, 3  0           []
#                                 )]
#
#  Conv1 (Conv2D)                 (None, 50, 50, 32)   864         ['input_1[0][0]']
#
#  bn_Conv1 (BatchNormalization)  (None, 50, 50, 32)   128         ['Conv1[0][0]']
#
#  Conv1_relu (ReLU)              (None, 50, 50, 32)   0           ['bn_Conv1[0][0]']
#
#  expanded_conv_depthwise (Depth  (None, 50, 50, 32)  288         ['Conv1_relu[0][0]']
#  wiseConv2D)
#
#  expanded_conv_depthwise_BN (Ba  (None, 50, 50, 32)  128         ['expanded_conv_depthwise[0][0]']
#  tchNormalization)
#
#  expanded_conv_depthwise_relu (  (None, 50, 50, 32)  0           ['expanded_conv_depthwise_BN[0][0
#  ReLU)                                                           ]']
#
#  expanded_conv_project (Conv2D)  (None, 50, 50, 16)  512         ['expanded_conv_depthwise_relu[0]
#                                                                  [0]']
#
#  expanded_conv_project_BN (Batc  (None, 50, 50, 16)  64          ['expanded_conv_project[0][0]']
#  hNormalization)
#
#  block_1_expand (Conv2D)        (None, 50, 50, 96)   1536        ['expanded_conv_project_BN[0][0]'
#                                                                  ]
#
#  block_1_expand_BN (BatchNormal  (None, 50, 50, 96)  384         ['block_1_expand[0][0]']
#  ization)
#
#  block_1_expand_relu (ReLU)     (None, 50, 50, 96)   0           ['block_1_expand_BN[0][0]']
#
#  block_1_pad (ZeroPadding2D)    (None, 51, 51, 96)   0           ['block_1_expand_relu[0][0]']
#
#  block_1_depthwise (DepthwiseCo  (None, 25, 25, 96)  864         ['block_1_pad[0][0]']
#  nv2D)
#
#  block_1_depthwise_BN (BatchNor  (None, 25, 25, 96)  384         ['block_1_depthwise[0][0]']
#  malization)
#
#  block_1_depthwise_relu (ReLU)  (None, 25, 25, 96)   0           ['block_1_depthwise_BN[0][0]']
#
#  block_1_project (Conv2D)       (None, 25, 25, 24)   2304        ['block_1_depthwise_relu[0][0]']
#
#  block_1_project_BN (BatchNorma  (None, 25, 25, 24)  96          ['block_1_project[0][0]']
#  lization)
#
#  block_2_expand (Conv2D)        (None, 25, 25, 144)  3456        ['block_1_project_BN[0][0]']
#
#  block_2_expand_BN (BatchNormal  (None, 25, 25, 144)  576        ['block_2_expand[0][0]']
#  ization)
#
#  block_2_expand_relu (ReLU)     (None, 25, 25, 144)  0           ['block_2_expand_BN[0][0]']
#
#  block_2_depthwise (DepthwiseCo  (None, 25, 25, 144)  1296       ['block_2_expand_relu[0][0]']
#  nv2D)
#
#  block_2_depthwise_BN (BatchNor  (None, 25, 25, 144)  576        ['block_2_depthwise[0][0]']
#  malization)
#
#  block_2_depthwise_relu (ReLU)  (None, 25, 25, 144)  0           ['block_2_depthwise_BN[0][0]']
#
#  block_2_project (Conv2D)       (None, 25, 25, 24)   3456        ['block_2_depthwise_relu[0][0]']
#
#  block_2_project_BN (BatchNorma  (None, 25, 25, 24)  96          ['block_2_project[0][0]']
#  lization)
#
#  block_2_add (Add)              (None, 25, 25, 24)   0           ['block_1_project_BN[0][0]',
#                                                                   'block_2_project_BN[0][0]']
#
#  block_3_expand (Conv2D)        (None, 25, 25, 144)  3456        ['block_2_add[0][0]']
#
#  block_3_expand_BN (BatchNormal  (None, 25, 25, 144)  576        ['block_3_expand[0][0]']
#  ization)
#
#  block_3_expand_relu (ReLU)     (None, 25, 25, 144)  0           ['block_3_expand_BN[0][0]']
#
#  block_3_pad (ZeroPadding2D)    (None, 27, 27, 144)  0           ['block_3_expand_relu[0][0]']
#
#  block_3_depthwise (DepthwiseCo  (None, 13, 13, 144)  1296       ['block_3_pad[0][0]']
#  nv2D)
#
#  block_3_depthwise_BN (BatchNor  (None, 13, 13, 144)  576        ['block_3_depthwise[0][0]']
#  malization)
#
#  block_3_depthwise_relu (ReLU)  (None, 13, 13, 144)  0           ['block_3_depthwise_BN[0][0]']
#
#  block_3_project (Conv2D)       (None, 13, 13, 32)   4608        ['block_3_depthwise_relu[0][0]']
#
#  block_3_project_BN (BatchNorma  (None, 13, 13, 32)  128         ['block_3_project[0][0]']
#  lization)
#
#  block_4_expand (Conv2D)        (None, 13, 13, 192)  6144        ['block_3_project_BN[0][0]']
#
#  block_4_expand_BN (BatchNormal  (None, 13, 13, 192)  768        ['block_4_expand[0][0]']
#  ization)
#
#  block_4_expand_relu (ReLU)     (None, 13, 13, 192)  0           ['block_4_expand_BN[0][0]']
#
#  block_4_depthwise (DepthwiseCo  (None, 13, 13, 192)  1728       ['block_4_expand_relu[0][0]']
#  nv2D)
#
#  block_4_depthwise_BN (BatchNor  (None, 13, 13, 192)  768        ['block_4_depthwise[0][0]']
#  malization)
#
#  block_4_depthwise_relu (ReLU)  (None, 13, 13, 192)  0           ['block_4_depthwise_BN[0][0]']
#
#  block_4_project (Conv2D)       (None, 13, 13, 32)   6144        ['block_4_depthwise_relu[0][0]']
#
#  block_4_project_BN (BatchNorma  (None, 13, 13, 32)  128         ['block_4_project[0][0]']
#  lization)
#
#  block_4_add (Add)              (None, 13, 13, 32)   0           ['block_3_project_BN[0][0]',
#                                                                   'block_4_project_BN[0][0]']
#
#  block_5_expand (Conv2D)        (None, 13, 13, 192)  6144        ['block_4_add[0][0]']
#
#  block_5_expand_BN (BatchNormal  (None, 13, 13, 192)  768        ['block_5_expand[0][0]']
#  ization)
#
#  block_5_expand_relu (ReLU)     (None, 13, 13, 192)  0           ['block_5_expand_BN[0][0]']
#
#  block_5_depthwise (DepthwiseCo  (None, 13, 13, 192)  1728       ['block_5_expand_relu[0][0]']
#  nv2D)
#
#  block_5_depthwise_BN (BatchNor  (None, 13, 13, 192)  768        ['block_5_depthwise[0][0]']
#  malization)
#
#  block_5_depthwise_relu (ReLU)  (None, 13, 13, 192)  0           ['block_5_depthwise_BN[0][0]']
#
#  block_5_project (Conv2D)       (None, 13, 13, 32)   6144        ['block_5_depthwise_relu[0][0]']
#
#  block_5_project_BN (BatchNorma  (None, 13, 13, 32)  128         ['block_5_project[0][0]']
#  lization)
#
#  block_5_add (Add)              (None, 13, 13, 32)   0           ['block_4_add[0][0]',
#                                                                   'block_5_project_BN[0][0]']
#
#  block_6_expand (Conv2D)        (None, 13, 13, 192)  6144        ['block_5_add[0][0]']
#
#  block_6_expand_BN (BatchNormal  (None, 13, 13, 192)  768        ['block_6_expand[0][0]']
#  ization)
#
#  block_6_expand_relu (ReLU)     (None, 13, 13, 192)  0           ['block_6_expand_BN[0][0]']
#
#  block_6_pad (ZeroPadding2D)    (None, 15, 15, 192)  0           ['block_6_expand_relu[0][0]']
#
#  block_6_depthwise (DepthwiseCo  (None, 7, 7, 192)   1728        ['block_6_pad[0][0]']
#  nv2D)
#
#  block_6_depthwise_BN (BatchNor  (None, 7, 7, 192)   768         ['block_6_depthwise[0][0]']
#  malization)
#
#  block_6_depthwise_relu (ReLU)  (None, 7, 7, 192)    0           ['block_6_depthwise_BN[0][0]']
#
#  block_6_project (Conv2D)       (None, 7, 7, 64)     12288       ['block_6_depthwise_relu[0][0]']
#
#  block_6_project_BN (BatchNorma  (None, 7, 7, 64)    256         ['block_6_project[0][0]']
#  lization)
#
#  block_7_expand (Conv2D)        (None, 7, 7, 384)    24576       ['block_6_project_BN[0][0]']
#
#  block_7_expand_BN (BatchNormal  (None, 7, 7, 384)   1536        ['block_7_expand[0][0]']
#  ization)
#
#  block_7_expand_relu (ReLU)     (None, 7, 7, 384)    0           ['block_7_expand_BN[0][0]']
#
#  block_7_depthwise (DepthwiseCo  (None, 7, 7, 384)   3456        ['block_7_expand_relu[0][0]']
#  nv2D)
#
#  block_7_depthwise_BN (BatchNor  (None, 7, 7, 384)   1536        ['block_7_depthwise[0][0]']
#  malization)
#
#  block_7_depthwise_relu (ReLU)  (None, 7, 7, 384)    0           ['block_7_depthwise_BN[0][0]']
#
#  block_7_project (Conv2D)       (None, 7, 7, 64)     24576       ['block_7_depthwise_relu[0][0]']
#
#  block_7_project_BN (BatchNorma  (None, 7, 7, 64)    256         ['block_7_project[0][0]']
#  lization)
#
#  block_7_add (Add)              (None, 7, 7, 64)     0           ['block_6_project_BN[0][0]',
#                                                                   'block_7_project_BN[0][0]']
#
#  block_8_expand (Conv2D)        (None, 7, 7, 384)    24576       ['block_7_add[0][0]']
#
#  block_8_expand_BN (BatchNormal  (None, 7, 7, 384)   1536        ['block_8_expand[0][0]']
#  ization)
#
#  block_8_expand_relu (ReLU)     (None, 7, 7, 384)    0           ['block_8_expand_BN[0][0]']
#
#  block_8_depthwise (DepthwiseCo  (None, 7, 7, 384)   3456        ['block_8_expand_relu[0][0]']
#  nv2D)
#
#  block_8_depthwise_BN (BatchNor  (None, 7, 7, 384)   1536        ['block_8_depthwise[0][0]']
#  malization)
#
#  block_8_depthwise_relu (ReLU)  (None, 7, 7, 384)    0           ['block_8_depthwise_BN[0][0]']
#
#  block_8_project (Conv2D)       (None, 7, 7, 64)     24576       ['block_8_depthwise_relu[0][0]']
#
#  block_8_project_BN (BatchNorma  (None, 7, 7, 64)    256         ['block_8_project[0][0]']
#  lization)
#
#  block_8_add (Add)              (None, 7, 7, 64)     0           ['block_7_add[0][0]',
#                                                                   'block_8_project_BN[0][0]']
#
#  block_9_expand (Conv2D)        (None, 7, 7, 384)    24576       ['block_8_add[0][0]']
#
#  block_9_expand_BN (BatchNormal  (None, 7, 7, 384)   1536        ['block_9_expand[0][0]']
#  ization)
#
#  block_9_expand_relu (ReLU)     (None, 7, 7, 384)    0           ['block_9_expand_BN[0][0]']
#
#  block_9_depthwise (DepthwiseCo  (None, 7, 7, 384)   3456        ['block_9_expand_relu[0][0]']
#  nv2D)
#
#  block_9_depthwise_BN (BatchNor  (None, 7, 7, 384)   1536        ['block_9_depthwise[0][0]']
#  malization)
#
#  block_9_depthwise_relu (ReLU)  (None, 7, 7, 384)    0           ['block_9_depthwise_BN[0][0]']
#
#  block_9_project (Conv2D)       (None, 7, 7, 64)     24576       ['block_9_depthwise_relu[0][0]']
#
#  block_9_project_BN (BatchNorma  (None, 7, 7, 64)    256         ['block_9_project[0][0]']
#  lization)
#
#  block_9_add (Add)              (None, 7, 7, 64)     0           ['block_8_add[0][0]',
#                                                                   'block_9_project_BN[0][0]']
#
#  block_10_expand (Conv2D)       (None, 7, 7, 384)    24576       ['block_9_add[0][0]']
#
#  block_10_expand_BN (BatchNorma  (None, 7, 7, 384)   1536        ['block_10_expand[0][0]']
#  lization)
#
#  block_10_expand_relu (ReLU)    (None, 7, 7, 384)    0           ['block_10_expand_BN[0][0]']
#
#  block_10_depthwise (DepthwiseC  (None, 7, 7, 384)   3456        ['block_10_expand_relu[0][0]']
#  onv2D)
#
#  block_10_depthwise_BN (BatchNo  (None, 7, 7, 384)   1536        ['block_10_depthwise[0][0]']
#  rmalization)
#
#  block_10_depthwise_relu (ReLU)  (None, 7, 7, 384)   0           ['block_10_depthwise_BN[0][0]']
#
#  block_10_project (Conv2D)      (None, 7, 7, 96)     36864       ['block_10_depthwise_relu[0][0]']
#
#  block_10_project_BN (BatchNorm  (None, 7, 7, 96)    384         ['block_10_project[0][0]']
#  alization)
#
#  block_11_expand (Conv2D)       (None, 7, 7, 576)    55296       ['block_10_project_BN[0][0]']
#
#  block_11_expand_BN (BatchNorma  (None, 7, 7, 576)   2304        ['block_11_expand[0][0]']
#  lization)
#
#  block_11_expand_relu (ReLU)    (None, 7, 7, 576)    0           ['block_11_expand_BN[0][0]']
#
#  block_11_depthwise (DepthwiseC  (None, 7, 7, 576)   5184        ['block_11_expand_relu[0][0]']
#  onv2D)
#
#  block_11_depthwise_BN (BatchNo  (None, 7, 7, 576)   2304        ['block_11_depthwise[0][0]']
#  rmalization)
#
#  block_11_depthwise_relu (ReLU)  (None, 7, 7, 576)   0           ['block_11_depthwise_BN[0][0]']
#
#  block_11_project (Conv2D)      (None, 7, 7, 96)     55296       ['block_11_depthwise_relu[0][0]']
#
#  block_11_project_BN (BatchNorm  (None, 7, 7, 96)    384         ['block_11_project[0][0]']
#  alization)
#
#  block_11_add (Add)             (None, 7, 7, 96)     0           ['block_10_project_BN[0][0]',
#                                                                   'block_11_project_BN[0][0]']
#
#  block_12_expand (Conv2D)       (None, 7, 7, 576)    55296       ['block_11_add[0][0]']
#
#  block_12_expand_BN (BatchNorma  (None, 7, 7, 576)   2304        ['block_12_expand[0][0]']
#  lization)
#
#  block_12_expand_relu (ReLU)    (None, 7, 7, 576)    0           ['block_12_expand_BN[0][0]']
#
#  block_12_depthwise (DepthwiseC  (None, 7, 7, 576)   5184        ['block_12_expand_relu[0][0]']
#  onv2D)
#
#  block_12_depthwise_BN (BatchNo  (None, 7, 7, 576)   2304        ['block_12_depthwise[0][0]']
#  rmalization)
#
#  block_12_depthwise_relu (ReLU)  (None, 7, 7, 576)   0           ['block_12_depthwise_BN[0][0]']
#
#  block_12_project (Conv2D)      (None, 7, 7, 96)     55296       ['block_12_depthwise_relu[0][0]']
#
#  block_12_project_BN (BatchNorm  (None, 7, 7, 96)    384         ['block_12_project[0][0]']
#  alization)
#
#  block_12_add (Add)             (None, 7, 7, 96)     0           ['block_11_add[0][0]',
#                                                                   'block_12_project_BN[0][0]']
#
#  block_13_expand (Conv2D)       (None, 7, 7, 576)    55296       ['block_12_add[0][0]']
#
#  block_13_expand_BN (BatchNorma  (None, 7, 7, 576)   2304        ['block_13_expand[0][0]']
#  lization)
#
#  block_13_expand_relu (ReLU)    (None, 7, 7, 576)    0           ['block_13_expand_BN[0][0]']
#
#  block_13_pad (ZeroPadding2D)   (None, 9, 9, 576)    0           ['block_13_expand_relu[0][0]']
#
#  block_13_depthwise (DepthwiseC  (None, 4, 4, 576)   5184        ['block_13_pad[0][0]']
#  onv2D)
#
#  block_13_depthwise_BN (BatchNo  (None, 4, 4, 576)   2304        ['block_13_depthwise[0][0]']
#  rmalization)
#
#  block_13_depthwise_relu (ReLU)  (None, 4, 4, 576)   0           ['block_13_depthwise_BN[0][0]']
#
#  block_13_project (Conv2D)      (None, 4, 4, 160)    92160       ['block_13_depthwise_relu[0][0]']
#
#  block_13_project_BN (BatchNorm  (None, 4, 4, 160)   640         ['block_13_project[0][0]']
#  alization)
#
#  block_14_expand (Conv2D)       (None, 4, 4, 960)    153600      ['block_13_project_BN[0][0]']
#
#  block_14_expand_BN (BatchNorma  (None, 4, 4, 960)   3840        ['block_14_expand[0][0]']
#  lization)
#
#  block_14_expand_relu (ReLU)    (None, 4, 4, 960)    0           ['block_14_expand_BN[0][0]']
#
#  block_14_depthwise (DepthwiseC  (None, 4, 4, 960)   8640        ['block_14_expand_relu[0][0]']
#  onv2D)
#
#  block_14_depthwise_BN (BatchNo  (None, 4, 4, 960)   3840        ['block_14_depthwise[0][0]']
#  rmalization)
#
#  block_14_depthwise_relu (ReLU)  (None, 4, 4, 960)   0           ['block_14_depthwise_BN[0][0]']
#
#  block_14_project (Conv2D)      (None, 4, 4, 160)    153600      ['block_14_depthwise_relu[0][0]']
#
#  block_14_project_BN (BatchNorm  (None, 4, 4, 160)   640         ['block_14_project[0][0]']
#  alization)
#
#  block_14_add (Add)             (None, 4, 4, 160)    0           ['block_13_project_BN[0][0]',
#                                                                   'block_14_project_BN[0][0]']
#
#  block_15_expand (Conv2D)       (None, 4, 4, 960)    153600      ['block_14_add[0][0]']
#
#  block_15_expand_BN (BatchNorma  (None, 4, 4, 960)   3840        ['block_15_expand[0][0]']
#  lization)
#
#  block_15_expand_relu (ReLU)    (None, 4, 4, 960)    0           ['block_15_expand_BN[0][0]']
#
#  block_15_depthwise (DepthwiseC  (None, 4, 4, 960)   8640        ['block_15_expand_relu[0][0]']
#  onv2D)
#
#  block_15_depthwise_BN (BatchNo  (None, 4, 4, 960)   3840        ['block_15_depthwise[0][0]']
#  rmalization)
#
#  block_15_depthwise_relu (ReLU)  (None, 4, 4, 960)   0           ['block_15_depthwise_BN[0][0]']
#
#  block_15_project (Conv2D)      (None, 4, 4, 160)    153600      ['block_15_depthwise_relu[0][0]']
#
#  block_15_project_BN (BatchNorm  (None, 4, 4, 160)   640         ['block_15_project[0][0]']
#  alization)
#
#  block_15_add (Add)             (None, 4, 4, 160)    0           ['block_14_add[0][0]',
#                                                                   'block_15_project_BN[0][0]']
#
#  block_16_expand (Conv2D)       (None, 4, 4, 960)    153600      ['block_15_add[0][0]']
#
#  block_16_expand_BN (BatchNorma  (None, 4, 4, 960)   3840        ['block_16_expand[0][0]']
#  lization)
#
#  block_16_expand_relu (ReLU)    (None, 4, 4, 960)    0           ['block_16_expand_BN[0][0]']
#
#  block_16_depthwise (DepthwiseC  (None, 4, 4, 960)   8640        ['block_16_expand_relu[0][0]']
#  onv2D)
#
#  block_16_depthwise_BN (BatchNo  (None, 4, 4, 960)   3840        ['block_16_depthwise[0][0]']
#  rmalization)
#
#  block_16_depthwise_relu (ReLU)  (None, 4, 4, 960)   0           ['block_16_depthwise_BN[0][0]']
#
#  block_16_project (Conv2D)      (None, 4, 4, 320)    307200      ['block_16_depthwise_relu[0][0]']
#
#  block_16_project_BN (BatchNorm  (None, 4, 4, 320)   1280        ['block_16_project[0][0]']
#  alization)
#
#  Conv_1 (Conv2D)                (None, 4, 4, 1280)   409600      ['block_16_project_BN[0][0]']
#
#  Conv_1_bn (BatchNormalization)  (None, 4, 4, 1280)  5120        ['Conv_1[0][0]']
#
#  out_relu (ReLU)                (None, 4, 4, 1280)   0           ['Conv_1_bn[0][0]']
#
# ==================================================================================================
# Total params: 2,257,984
# Trainable params: 0
# Non-trainable params: 2,257,984
# __________________________________________________________________________________________________

# %%
for layer in base_model.layers:
           if layer.name == 'block5_conv1':
              break
           layer.trainable = False

# %%
# We add our classificator (top_model) to the last layer of the model
last = base_model.layers[-1].output
x = Flatten()(last)
x = Dense(1000, activation='relu', name='fc1')(x)
x = Dropout(0.3)(x)
x = Dense(5, activation='softmax', name='predictions')(x)
model_out = Model(base_model.input, x)
#We compile the model

# %%
model_out.compile(loss=keras.losses.categorical_crossentropy, optimizer=tf.keras.optimizers.Adam(learning_rate=INIT_LR, decay=INIT_LR / 100),metrics=['accuracy'])

# %%
model_out.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 100, 100, 3  0           []
#                                 )]
#
#  Conv1 (Conv2D)                 (None, 50, 50, 32)   864         ['input_1[0][0]']
#
#  bn_Conv1 (BatchNormalization)  (None, 50, 50, 32)   128         ['Conv1[0][0]']
#
#  Conv1_relu (ReLU)              (None, 50, 50, 32)   0           ['bn_Conv1[0][0]']
#
#  expanded_conv_depthwise (Depth  (None, 50, 50, 32)  288         ['Conv1_relu[0][0]']
#  wiseConv2D)
#
#  expanded_conv_depthwise_BN (Ba  (None, 50, 50, 32)  128         ['expanded_conv_depthwise[0][0]']
#  tchNormalization)
#
#  expanded_conv_depthwise_relu (  (None, 50, 50, 32)  0           ['expanded_conv_depthwise_BN[0][0
#  ReLU)                                                           ]']
#
#  expanded_conv_project (Conv2D)  (None, 50, 50, 16)  512         ['expanded_conv_depthwise_relu[0]
#                                                                  [0]']
#
#  expanded_conv_project_BN (Batc  (None, 50, 50, 16)  64          ['expanded_conv_project[0][0]']
#  hNormalization)
#
#  block_1_expand (Conv2D)        (None, 50, 50, 96)   1536        ['expanded_conv_project_BN[0][0]'
#                                                                  ]
#
#  block_1_expand_BN (BatchNormal  (None, 50, 50, 96)  384         ['block_1_expand[0][0]']
#  ization)
#
#  block_1_expand_relu (ReLU)     (None, 50, 50, 96)   0           ['block_1_expand_BN[0][0]']
#
#  block_1_pad (ZeroPadding2D)    (None, 51, 51, 96)   0           ['block_1_expand_relu[0][0]']
#
#  block_1_depthwise (DepthwiseCo  (None, 25, 25, 96)  864         ['block_1_pad[0][0]']
#  nv2D)
#
#  block_1_depthwise_BN (BatchNor  (None, 25, 25, 96)  384         ['block_1_depthwise[0][0]']
#  malization)
#
#  block_1_depthwise_relu (ReLU)  (None, 25, 25, 96)   0           ['block_1_depthwise_BN[0][0]']
#
#  block_1_project (Conv2D)       (None, 25, 25, 24)   2304        ['block_1_depthwise_relu[0][0]']
#
#  block_1_project_BN (BatchNorma  (None, 25, 25, 24)  96          ['block_1_project[0][0]']
#  lization)
#
#  block_2_expand (Conv2D)        (None, 25, 25, 144)  3456        ['block_1_project_BN[0][0]']
#
#  block_2_expand_BN (BatchNormal  (None, 25, 25, 144)  576        ['block_2_expand[0][0]']
#  ization)
#
#  block_2_expand_relu (ReLU)     (None, 25, 25, 144)  0           ['block_2_expand_BN[0][0]']
#
#  block_2_depthwise (DepthwiseCo  (None, 25, 25, 144)  1296       ['block_2_expand_relu[0][0]']
#  nv2D)
#
#  block_2_depthwise_BN (BatchNor  (None, 25, 25, 144)  576        ['block_2_depthwise[0][0]']
#  malization)
#
#  block_2_depthwise_relu (ReLU)  (None, 25, 25, 144)  0           ['block_2_depthwise_BN[0][0]']
#
#  block_2_project (Conv2D)       (None, 25, 25, 24)   3456        ['block_2_depthwise_relu[0][0]']
#
#  block_2_project_BN (BatchNorma  (None, 25, 25, 24)  96          ['block_2_project[0][0]']
#  lization)
#
#  block_2_add (Add)              (None, 25, 25, 24)   0           ['block_1_project_BN[0][0]',
#                                                                   'block_2_project_BN[0][0]']
#
#  block_3_expand (Conv2D)        (None, 25, 25, 144)  3456        ['block_2_add[0][0]']
#
#  block_3_expand_BN (BatchNormal  (None, 25, 25, 144)  576        ['block_3_expand[0][0]']
#  ization)
#
#  block_3_expand_relu (ReLU)     (None, 25, 25, 144)  0           ['block_3_expand_BN[0][0]']
#
#  block_3_pad (ZeroPadding2D)    (None, 27, 27, 144)  0           ['block_3_expand_relu[0][0]']
#
#  block_3_depthwise (DepthwiseCo  (None, 13, 13, 144)  1296       ['block_3_pad[0][0]']
#  nv2D)
#
#  block_3_depthwise_BN (BatchNor  (None,
# %%
acc = grado_train_dropout.history['accuracy']
val_acc = grado_train_dropout.history['val_accuracy']

loss = grado_train_dropout.history['loss']
val_loss = grado_train_dropout.history['val_loss']

plt.figure(figsize=(10, 10))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Exactitud Entrenamiento ')
plt.plot(val_acc, label='Exactitud Validación')
plt.legend(loc='lower right')
plt.ylabel('Exactitud')
plt.ylim([min(plt.ylim()),1])
plt.title('Exactitud Entrenamiento y Validación ')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Pérdida Entrenamiento')
plt.plot(val_loss, label='Pérdida Validación')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,1.0])
plt.title(' Pérdida Entrenamiento y Validación ')
plt.xlabel('epoch')
plt.show()

# %%
test_eval = model_out.evaluate(x_test, test_Y_one_hot, verbose=1)

print('Test loss:', test_eval[0])
print('Test accuracy:', test_eval[1])
# Out:
# 4/4 [==============================] - 1s 207ms/step - loss: 0.4986 - accuracy: 0.9200
# Test loss: 0.49856671690940857
# Test accuracy: 0.9200000166893005

# %%
predicted_classes = model_out.predict(x_test)
predicted_classes = np.argmax(np.round(predicted_classes),axis=1)
predicted_classes.shape, y_test.shape
# Out:
# ((100,), (100,))

# %%
from sklearn.metrics import classification_report
target_names = ["Class {}".format(i) for i in range(nClasses)]
print(classification_report(y_test, predicted_classes, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#      Class 0       0.95      0.90      0.93        21
#      Class 1       0.89      0.84      0.86        19
#      Class 2       0.77      1.00      0.87        17
#      Class 3       1.00      0.91      0.95        23
#      Class 4       1.00      0.95      0.97        20
#
#     accuracy                           0.92       100
#    macro avg       0.92      0.92      0.92       100
# weighted avg       0.93      0.92      0.92       100

# %%
from sklearn.metrics import confusion_matrix

matriz=confusion_matrix(y_test, predicted_classes)
print(matriz)
# Out:
# [[19  2  0  0  0]
#  [ 0 16  3  0  0]
#  [ 0  0 17  0  0]
#  [ 0  0  2 21  0]
#  [ 1  0  0  0 19]]

# %%
import numpy as np
import cv2
import glob
import os
import matplotlib.pyplot as plt
import string
from mlxtend.plotting import plot_decision_regions
#from mpl_toolkits.mplot3d import Axes3D
#from sklearn.decomposition import PCA
#from sklearn.preprocessing import StandardScaler
#from sklearn.neighbors import KNeighborsClassifier
#from sklearn.tree import DecisionTreeClassifier
#from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.utils.multiclass import unique_labels
from sklearn import metrics
#from sklearn.svm import SVC


import json
from skimage import color
from skimage.feature import hog
#from sklearn import svm
from sklearn.metrics import classification_report,accuracy_score, recall_score
from subprocess import check_output

def plot_confusion_matrix(y_true, y_pred, classes,
                          normalize=False,
                          title=None,
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if not title:
        if normalize:
            title = 'Matriz de confusión'
        else:
            title = 'Matriz de confusión, sin normalización'

    # Compute confusion matrix

    cm = metrics.confusion_matrix(y_true, y_pred)
    # Only use the labels that appear in the data
    classes = unique_labels(y_true, y_pred)
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    fig, ax = plt.subplots()
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    # We want to show all ticks...

    ax.set(xticks=np.arange(cm.shape[1]),
           yticks=np.arange(cm.shape[0]),
           # ... and label them with the respective list entries
           xticklabels=labels, yticklabels=labels,
           title=title,
           ylabel='Etiqueta verdadera',
           xlabel='Etiqueta prevista')

    # Rotate the tick labels and set their alignment.

    plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
             rotation_mode="anchor")

    # Loop over data dimensions and create text annotations.

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], fmt),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")
    fig.tight_layout()
    return cm,ax

precision=metrics.accuracy_score(y_test,predicted_classes, normalize=False)

print("Muestras:{0:.2f}%".format(precision))
cm,_=plot_confusion_matrix(y_test,predicted_classes,classes=nClasses,normalize=False,title="Matriz de confusión")
plt.show()


precision=metrics.accuracy_score(y_test,predicted_classes, normalize=True)*100

print("Accuracy:{0:.2f}%".format(precision))
cm,_=plot_confusion_matrix(y_test,predicted_classes,classes=nClasses,normalize=True,title="Matriz de confusión")
plt.show()
# Out:
# Muestras:92.00%
# Accuracy:92.00%

# %%
import numpy as np
import cv2
import glob
import os
import matplotlib.pyplot as plt
import string
from mlxtend.plotting import plot_decision_regions
#from mpl_toolkits.mplot3d import Axes3D
#from sklearn.decomposition import PCA
#from sklearn.preprocessing import StandardScaler
#from sklearn.neighbors import KNeighborsClassifier
#from sklearn.tree import DecisionTreeClassifier
#from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.utils.multiclass import unique_labels
from sklearn import metrics
#from sklearn.svm import SVC


import json
from skimage import color
from skimage.feature import hog
#from sklearn import svm
from sklearn.metrics import classification_report,accuracy_score, recall_score
from subprocess import check_output

def plot_confusion_matrix(y_true, y_pred, classes,
                          normalize=False,
                          title=None,
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if not title:
        if normalize:
            title = 'Matriz de confusión'
        else:
            title = 'Matriz de confusión, sin normalización'

    # Compute confusion matrix

    cm = metrics.confusion_matrix(y_true, y_pred)
    # Only use the labels that appear in the data
    classes = unique_labels(y_true, y_pred)
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    fig, ax = plt.subplots()
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    # We want to show all ticks...

    ax.set(xticks=np.arange(cm.shape[1]),
           yticks=np.arange(cm.shape[0]),
           # ... and label them with the respective list entries
           xticklabels=labels, yticklabels=labels,
           title=title,
           ylabel='Etiqueta verdadera',
           xlabel='Etiqueta prevista')

    # Rotate the tick labels and set their alignment.

    plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
             rotation_mode="anchor")

    # Loop over data dimensions and create text annotations.

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], fmt),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")
    fig.tight_layout()
    return cm,ax

precision=metrics.accuracy_score(y_test,predicted_classes, normalize=True)*100

print("Accuracy:{0:.2f}%".format(precision))
cm,_=plot_confusion_matrix(y_test,predicted_classes,classes=nClasses,normalize=True,title="Matriz de confusión")
plt.show()
# Out:
# Accuracy:92.00%

# %%
model_out.save("/content/drive/My Drive/source_dir/gradoma_final_064.h5py")
# Out:
# INFO:tensorflow:Assets written to: /content/drive/My Drive/source_dir/gradoma_final_064.h5py/assets
# /usr/local/lib/python3.7/dist-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# /usr/local/lib/python3.7/dist-packages/keras/saving/saved_model/layer_serialization.py:112: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   return generic_utils.serialize_keras_object(obj)

# %% [markdown]
# NUEVA PRUEBA VGG16

# %%
#preprocess_input = tf.keras.applications.VGG16.preprocess_input
rescale = tf.keras.layers.experimental.preprocessing.Rescaling(1./127.5, offset= -1)
IMG_SIZE = (100, 100)
img_height=100
img_width=100

IMG_SHAPE = IMG_SIZE + (3,)
base_model = tf.keras.applications.VGG16(input_shape=IMG_SHAPE,
                                               include_top=False,
                                               weights='imagenet')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 0s 0us/step
# 58900480/58889256 [==============================] - 0s 0us/step

# %%
base_model.trainable = False

base_model.summary()
for layer in base_model.layers:
           if layer.name == 'block5_conv1':
              break
           layer.trainable = False


# We add our classificator (top_model) to the last layer of the model
last = base_model.layers[-1].output
x = Flatten()(last)
x = Dense(1000, activation='relu', name='fc1')(x)
x = Dropout(0.3)(x)
x = Dense(5, activation='softmax', name='predictions')(x)
model_out_vgg16 = Model(base_model.input, x)
#We compile the model
model_out_vgg16.compile(loss=keras.losses.categorical_crossentropy, optimizer=tf.keras.optimizers.Adam(learning_rate=INIT_LR, decay=INIT_LR / 100),metrics=['accuracy'])
model_out_vgg16.summary()
callback = tf.keras.callbacks.EarlyStopping(monitor='loss', min_delta=0.0001, patience=3)

grado_train_dropout = model_out_vgg16.fit(train_x, train_label, batch_size=batch_size,epochs=epochs,verbose=1,validation_data=(valid_X, valid_label),callbacks=[callback])
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 100, 100, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 100, 100, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 100, 100, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 50, 50, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 50, 50, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 50, 50, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 25, 25, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 25, 25, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 25, 25, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 25, 25, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 12, 12, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 12, 12, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 12, 12, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 12, 12, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 6, 6, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 6, 6, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 6, 6, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 6, 6, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 3, 3, 512)         0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 0
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 100, 100, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 100, 100, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 100, 100, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 50, 50, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 50, 50, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 50, 50, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 25, 25, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 25, 25, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 25, 25, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 25, 25, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 12, 12, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 12, 12, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 12, 12, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 12, 12, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 6, 6, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 6, 6, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 6, 6, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 6, 6, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 3, 3, 512)         0
#
#  flatten_2 (Flatten)         (None, 4608)              0
#
#  fc1 (Dense)                 (None, 1000)              4609000
#
#  dropout_5 (Dropout)         (None, 1000)              0
#
#  predictions (Dense)         (None, 5)                 5005
#
# =================================================================
# Total params: 19,328,693
# Trainable params: 4,614,005
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Epoch 1/100
# 5/5 [==============================] - 40s 8s/step - loss: 1.5665 - accuracy: 0.3187 - val_loss: 1.1279 - val_accuracy: 0.6250
# Epoch 2/100
# 5/5 [==============================] - 39s 8s/step - loss: 0.9977 - accuracy: 0.6281 - val_loss: 0.8454 - val_accuracy: 0.7375
# Epoch 3/100
# 5/5 [==============================] - 39s 8s/step - loss: 0.7083 - accuracy: 0.7875 - val_loss: 0.6954 - val_accuracy: 0.7750
# Epoch 4/100
# 5/5 [==============================] - 39s 8s/step - loss: 0.5403 - accuracy: 0.8219 - val_loss: 0.5696 - val_accuracy: 0.8250
# Epoch 5/100
# 5/5 [==============================] - 39s 8s/step - loss: 0.4425 - accuracy: 0.8813 - val_loss: 0.5133 - val_accuracy: 0.8125
# Epoch 6/100
# 5/5 [==============================] - 39s 8s/step - loss: 0.3635 - accuracy: 0.8813 - val_loss: 0.4894 - val_accuracy: 0.8500
# Epoch 7/100
# 5/5 [==============================] - 39s 8s/step - loss: 0.3323 - accuracy: 0.9031 - val_loss: 0.4540 - val_accuracy: 0.8500
# Epoch 8/100
# 5/5 [==============================] - 39s 8s/step - loss: 0.2735 - accuracy: 0.9312 - val_loss: 0.4276 - val_accuracy: 0.8750
# Epoch 9/100
# 5/5 [==============================] - 39s 8s/step - loss: 0.2584 - accuracy: 0.9375 - val_loss: 0.4153 - val_accuracy: 0.8750
# Epoch 10/100
# 5/5 [==============================] - 39s 8s/step - loss: 0.2275 - accuracy: 0.9438 - val_loss: 0.4104 - val_accuracy: 0.8500
# Epoch 11/100
# 5/5 [==============================] - 39s 8s/step - loss: 0.1928 - accuracy: 0.9594 - val_loss: 0.3857 - val_accuracy: 0.8875
# Epoch 12/100
# 5/5 [==============================] - 40s 8s/step - loss: 0.1795 - accuracy: 0.9563 - val_loss: 0.3804 - val_accuracy: 0.8750
# Epoch 13/100
# 5/5 [==============================] - 39s 8s/step - loss: 0.1600 - accuracy: 0.9750 - val_loss: 0.3684 - val_accuracy: 0.8750
# Epoch 14/100
# 5/5 [==============================] - 39s 8s/step - loss: 0.1479 - accuracy: 0.9688 - val_loss: 0.3656 - val_accuracy: 0.8875
# Epoch 15/100
# 5/5 [==============================] - 40s 8s/step - loss: 0.1330 - accuracy: 0.9812 - val_loss: 0.3652 - val_accuracy: 0.9000
# Epoch 16/100
# 5/5 [==============================] - 39s 8s/step - loss: 0
100
# 5/5 [==============================] - 39s 8s/step - loss: 0.0129 - accuracy: 1.0000 - val_loss: 0.3274 - val_accuracy: 0.9000
# Epoch 59/100
# 5/5 [==============================] - 39s 8s/step - loss: 0.0113 - accuracy: 1.0000 - val_loss: 0.3285 - val_accuracy: 0.9000
# Epoch 60/100
# 5/5 [==============================] - 39s 8s/step - loss: 0.0114 - accuracy: 1.0000 - val_loss: 0.3303 - val_accuracy: 0.9000
# Epoch 61/100
# 5/5 [==============================] - 39s 8s/step - loss: 0.0126 - accuracy: 1.0000 - val_loss: 0.3286 - val_accuracy: 0.9000
# Epoch 62/100
# 5/5 [==============================] - 39s 8s/step - loss: 0.0106 - accuracy: 1.0000 - val_loss: 0.3266 - val_accuracy: 0.9000
# Epoch 63/100
# 5/5 [==============================] - 39s 8s/step - loss: 0.0119 - accuracy: 1.0000 - val_loss: 0.3254 - val_accuracy: 0.9000
# Epoch 64/100
# 5/5 [==============================] - 39s 8s/step - loss: 0.0103 - accuracy: 1.0000 - val_loss: 0.3295 - val_accuracy: 0.9000
# Epoch 65/100
# 5/5 [==============================] - 39s 8s/step - loss: 0.0109 - accuracy: 1.0000 - val_loss: 0.3302 - val_accuracy: 0.9000
# Epoch 66/100
# 5/5 [==============================] - 39s 8s/step - loss: 0.0099 - accuracy: 1.0000 - val_loss: 0.3317 - val_accuracy: 0.9000
# Epoch 67/100
# 5/5 [==============================] - 39s 8s/step - loss: 0.0124 - accuracy: 1.0000 - val_loss: 0.3297 - val_accuracy: 0.9000
# Epoch 68/100
# 5/5 [==============================] - 39s 8s/step - loss: 0.0090 - accuracy: 1.0000 - val_loss: 0.3296 - val_accuracy: 0.9000
# Epoch 69/100
# 5/5 [==============================] - 40s 8s/step - loss: 0.0101 - accuracy: 1.0000 - val_loss: 0.3334 - val_accuracy: 0.9125
# Epoch 70/100
# 5/5 [==============================] - 40s 8s/step - loss: 0.0092 - accuracy: 1.0000 - val_loss: 0.3365 - val_accuracy: 0.9125
# Epoch 71/100
# 5/5 [==============================] - 39s 8s/step - loss: 0.0082 - accuracy: 1.0000 - val_loss: 0.3361 - val_accuracy: 0.9125
# Epoch 72/100
# 5/5 [==============================] - 39s 8s/step - loss: 0.0087 - accuracy: 1.0000 - val_loss: 0.3346 - val_accuracy: 0.9000
# Epoch 73/100
# 5/5 [==============================] - 39s 8s/step - loss: 0.0084 - accuracy: 1.0000 - val_loss: 0.3350 - val_accuracy: 0.9000
# Epoch 74/100
# 5/5 [==============================] - 39s 8s/step - loss: 0.0087 - accuracy: 1.0000 - val_loss: 0.3346 - val_accuracy: 0.9000

# %%
acc = grado_train_dropout.history['accuracy']
val_acc = grado_train_dropout.history['val_accuracy']

loss = grado_train_dropout.history['loss']
val_loss = grado_train_dropout.history['val_loss']

plt.figure(figsize=(10, 10))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Exactitud Entrenamiento ')
plt.plot(val_acc, label='Exactitud Validación')
plt.legend(loc='lower right')
plt.ylabel('Exactitud')
plt.ylim([min(plt.ylim()),1])
plt.title('Exactitud Entrenamiento y Validación ')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Pérdida Entrenamiento')
plt.plot(val_loss, label='Pérdida Validación')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,1.0])
plt.title(' Pérdida Entrenamiento y Validación ')
plt.xlabel('epoch')
plt.show()

# %%
test_eval = model_out_vgg16.evaluate(x_test, test_Y_one_hot, verbose=1)

print('Test loss:', test_eval[0])
print('Test accuracy:', test_eval[1])
# Out:
# 4/4 [==============================] - 10s 2s/step - loss: 0.3422 - accuracy: 0.9000
# Test loss: 0.34215855598449707
# Test accuracy: 0.8999999761581421

# %%
predicted_classes = model_out_vgg16.predict(x_test)
predicted_classes = np.argmax(np.round(predicted_classes),axis=1)
predicted_classes.shape, y_test.shape
# Out:
# ((100,), (100,))

# %%
from sklearn.metrics import classification_report
target_names = ["Class {}".format(i) for i in range(nClasses)]
print(classification_report(y_test, predicted_classes, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#      Class 0       0.90      0.86      0.88        21
#      Class 1       0.83      0.79      0.81        19
#      Class 2       0.79      0.88      0.83        17
#      Class 3       0.96      0.96      0.96        23
#      Class 4       1.00      1.00      1.00        20
#
#     accuracy                           0.90       100
#    macro avg       0.90      0.90      0.90       100
# weighted avg       0.90      0.90      0.90       100

# %%
from sklearn.metrics import confusion_matrix

matriz=confusion_matrix(y_test, predicted_classes)
print(matriz)
# Out:
# [[18  3  0  0  0]
#  [ 0 15  3  1  0]
#  [ 2  0 15  0  0]
#  [ 0  0  1 22  0]
#  [ 0  0  0  0 20]]

# %%
import numpy as np
import cv2
import glob
import os
import matplotlib.pyplot as plt
import string
from mlxtend.plotting import plot_decision_regions
#from mpl_toolkits.mplot3d import Axes3D
#from sklearn.decomposition import PCA
#from sklearn.preprocessing import StandardScaler
#from sklearn.neighbors import KNeighborsClassifier
#from sklearn.tree import DecisionTreeClassifier
#from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.utils.multiclass import unique_labels
from sklearn import metrics
#from sklearn.svm import SVC


import json
from skimage import color
from skimage.feature import hog
#from sklearn import svm
from sklearn.metrics import classification_report,accuracy_score, recall_score
from subprocess import check_output

def plot_confusion_matrix(y_true, y_pred, classes,
                          normalize=False,
                          title=None,
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if not title:
        if normalize:
            title = 'Matriz de confusión'
        else:
            title = 'Matriz de confusión, sin normalización'

    # Compute confusion matrix

    cm = metrics.confusion_matrix(y_true, y_pred)
    # Only use the labels that appear in the data
    classes = unique_labels(y_true, y_pred)
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    fig, ax = plt.subplots()
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    # We want to show all ticks...

    ax.set(xticks=np.arange(cm.shape[1]),
           yticks=np.arange(cm.shape[0]),
           # ... and label them with the respective list entries
           xticklabels=labels, yticklabels=labels,
           title=title,
           ylabel='Etiqueta verdadera',
           xlabel='Etiqueta prevista')

    # Rotate the tick labels and set their alignment.

    plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
             rotation_mode="anchor")

    # Loop over data dimensions and create text annotations.

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], fmt),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")
    fig.tight_layout()
    return cm,ax

precision=metrics.accuracy_score(y_test,predicted_classes, normalize=False)

print("Muestras:{0:.2f}".format(precision))
cm,_=plot_confusion_matrix(y_test,predicted_classes,classes=nClasses,normalize=False,title="Matriz de confusión")
plt.show()

precision=metrics.accuracy_score(y_test,predicted_classes, normalize=True)*100

print("Accuracy:{0:.2f}%".format(precision))
cm,_=plot_confusion_matrix(y_test,predicted_classes,classes=nClasses,normalize=True,title="Matriz de confusión")
plt.show()
# Out:
# Muestras:90.00
# Accuracy:90.00%

# %%
model_out_vgg16.save("/content/drive/My Drive/source_dir/gradoma_final_vgg16.h5py")
# Out:
# INFO:tensorflow:Assets written to: /content/drive/My Drive/source_dir/gradoma_final_vgg16.h5py/assets

# %% [markdown]
# New EfficientNetB0

# %%
#preprocess_input = tf.keras.applications.EfficientNetB0.preprocess_input
rescale = tf.keras.layers.experimental.preprocessing.Rescaling(1./127.5, offset= -1)
IMG_SIZE = (100, 100)
img_height=100
img_width=100

IMG_SHAPE = IMG_SIZE + (3,)
base_model = tf.keras.applications.EfficientNetB0(input_shape=IMG_SHAPE,
                                               include_top=False,
                                               weights='imagenet')
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16711680/16705208 [==============================] - 0s 0us/step
# 16719872/16705208 [==============================] - 0s 0us/step

# %%
base_model.trainable = False

base_model.summary()
for layer in base_model.layers:
           if layer.name == 'block5_conv1':
              break
           layer.trainable = False


# We add our classificator (top_model) to the last layer of the model
last = base_model.layers[-1].output
x = Flatten()(last)
x = Dense(1000, activation='relu', name='fc1')(x)
x = Dropout(0.3)(x)
x = Dense(5, activation='softmax', name='predictions')(x)
model_out_efb0 = Model(base_model.input, x)
#We compile the model
model_out_efb0.compile(loss=keras.losses.categorical_crossentropy, optimizer=tf.keras.optimizers.Adam(learning_rate=INIT_LR, decay=INIT_LR / 100),metrics=['accuracy'])
model_out_efb0.summary()
callback = tf.keras.callbacks.EarlyStopping(monitor='loss', min_delta=0.0001, patience=3)

grado_train_dropout = model_out_efb0.fit(train_x, train_label, batch_size=batch_size,epochs=epochs,verbose=1,validation_data=(valid_X, valid_label),callbacks=[callback])
# Out:
# Model: "efficientnetb0"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 100, 100, 3  0           []
#                                 )]
#
#  rescaling_3 (Rescaling)        (None, 100, 100, 3)  0           ['input_3[0][0]']
#
#  normalization (Normalization)  (None, 100, 100, 3)  7           ['rescaling_3[0][0]']
#
#  stem_conv_pad (ZeroPadding2D)  (None, 101, 101, 3)  0           ['normalization[0][0]']
#
#  stem_conv (Conv2D)             (None, 50, 50, 32)   864         ['stem_conv_pad[0][0]']
#
#  stem_bn (BatchNormalization)   (None, 50, 50, 32)   128         ['stem_conv[0][0]']
#
#  stem_activation (Activation)   (None, 50, 50, 32)   0           ['stem_bn[0][0]']
#
#  block1a_dwconv (DepthwiseConv2  (None, 50, 50, 32)  288         ['stem_activation[0][0]']
#  D)
#
#  block1a_bn (BatchNormalization  (None, 50, 50, 32)  128         ['block1a_dwconv[0][0]']
#  )
#
#  block1a_activation (Activation  (None, 50, 50, 32)  0           ['block1a_bn[0][0]']
#  )
#
#  block1a_se_squeeze (GlobalAver  (None, 32)          0           ['block1a_activation[0][0]']
#  agePooling2D)
#
#  block1a_se_reshape (Reshape)   (None, 1, 1, 32)     0           ['block1a_se_squeeze[0][0]']
#
#  block1a_se_reduce (Conv2D)     (None, 1, 1, 8)      264         ['block1a_se_reshape[0][0]']
#
#  block1a_se_expand (Conv2D)     (None, 1, 1, 32)     288         ['block1a_se_reduce[0][0]']
#
#  block1a_se_excite (Multiply)   (None, 50, 50, 32)   0           ['block1a_activation[0][0]',
#                                                                   'block1a_se_expand[0][0]']
#
#  block1a_project_conv (Conv2D)  (None, 50, 50, 16)   512         ['block1a_se_excite[0][0]']
#
#  block1a_project_bn (BatchNorma  (None, 50, 50, 16)  64          ['block1a_project_conv[0][0]']
#  lization)
#
#  block2a_expand_conv (Conv2D)   (None, 50, 50, 96)   1536        ['block1a_project_bn[0][0]']
#
#  block2a_expand_bn (BatchNormal  (None, 50, 50, 96)  384         ['block2a_expand_conv[0][0]']
#  ization)
#
#  block2a_expand_activation (Act  (None, 50, 50, 96)  0           ['block2a_expand_bn[0][0]']
#  ivation)
#
#  block2a_dwconv_pad (ZeroPaddin  (None, 51, 51, 96)  0           ['block2a_expand_activation[0][0]
#  g2D)                                                            ']
#
#  block2a_dwconv (DepthwiseConv2  (None, 25, 25, 96)  864         ['block2a_dwconv_pad[0][0]']
#  D)
#
#  block2a_bn (BatchNormalization  (None, 25, 25, 96)  384         ['block2a_dwconv[0][0]']
#  )
#
#  block2a_activation (Activation  (None, 25, 25, 96)  0           ['block2a_bn[0][0]']
#  )
#
#  block2a_se_squeeze (GlobalAver  (None, 96)          0           ['block2a_activation[0][0]']
#  agePooling2D)
#
#  block2a_se_reshape (Reshape)   (None, 1, 1, 96)     0           ['block2a_se_squeeze[0][0]']
#
#  block2a_se_reduce (Conv2D)     (None, 1, 1, 4)      388         ['block2a_se_reshape[0][0]']
#
#  block2a_se_expand (Conv2D)     (None, 1, 1, 96)     480         ['block2a_se_reduce[0][0]']
#
#  block2a_se_excite (Multiply)   (None, 25, 25, 96)   0           ['block2a_activation[0][0]',
#                                                                   'block2a_se_expand[0][0]']
#
#  block2a_project_conv (Conv2D)  (None, 25, 25, 24)   2304        ['block2a_se_excite[0][0]']
#
#  block2a_project_bn (BatchNorma  (None, 25, 25, 24)  96          ['block2a_project_conv[0][0]']
#  lization)
#
#  block2b_expand_conv (Conv2D)   (None, 25, 25, 144)  3456        ['block2a_project_bn[0][0]']
#
#  block2b_expand_bn (BatchNormal  (None, 25, 25, 144)  576        ['block2b_expand_conv[0][0]']
#  ization)
#
#  block2b_expand_activation (Act  (None, 25, 25, 144)  0          ['block2b_expand_bn[0][0]']
#  ivation)
#
#  block2b_dwconv (DepthwiseConv2  (None, 25, 25, 144)  1296       ['block2b_expand_activation[0][0]
#  D)                                                              ']
#
#  block2b_bn (BatchNormalization  (None, 25, 25, 144)  576        ['block2b_dwconv[0][0]']
#  )
#
#  block2b_activation (Activation  (None, 25, 25, 144)  0          ['block2b_bn[0][0]']
#  )
#
#  block2b_se_squeeze (GlobalAver  (None, 144)         0           ['block2b_activation[0][0]']
#  agePooling2D)
#
#  block2b_se_reshape (Reshape)   (None, 1, 1, 144)    0           ['block2b_se_squeeze[0][0]']
#
#  block2b_se_reduce (Conv2D)     (None, 1, 1, 6)      870         ['block2b_se_reshape[0][0]']
#
#  block2b_se_expand (Conv2D)     (None, 1, 1, 144)    1008        ['block2b_se_reduce[0][0]']
#
#  block2b_se_excite (Multiply)   (None, 25, 25, 144)  0           ['block2b_activation[0][0]',
#                                                                   'block2b_se_expand[0][0]']
#
#  block2b_project_conv (Conv2D)  (None, 25, 25, 24)   3456        ['block2b_se_excite[0][0]']
#
#  block2b_project_bn (BatchNorma  (None, 25, 25, 24)  96          ['block2b_project_conv[0][0]']
#  lization)
#
#  block2b_drop (Dropout)         (None, 25, 25, 24)   0           ['block2b_project_bn[0][0]']
#
#  block2b_add (Add)              (None, 25, 25, 24)   0           ['block2b_drop[0][0]',
#                                                                   'block2a_project_bn[0][0]']
#
#  block3a_expand_conv (Conv2D)   (None, 25, 25, 144)  3456        ['block2b_add[0][0]']
#
#  block3a_expand_bn (BatchNormal  (None, 25, 25, 144)  576        ['block3a_expand_conv[0][0]']
#  ization)
#
#  block3a_expand_activation (Act  (None, 25, 25, 144)  0          ['block3a_expand_bn[0][0]']
#  ivation)
#
#  block3a_dwconv_pad (ZeroPaddin  (None, 29, 29, 144)  0          ['block3a_expand_activation[0][0]
#  g2D)                                                            ']
#
#  block3a_dwconv (DepthwiseConv2  (None, 13, 13, 144)  3600       ['block3a_dwconv_pad[0][0]']
#  D)
#
#  block3a_bn (BatchNormalization  (None, 13, 13, 144)  576        ['block3a_dwconv[0][0]']
#  )
#
#  block3a_activation (Activation  (None, 13, 13, 144)  0          ['block3a_bn[0][0]']
#  )
#
#  block3a_se_squeeze (GlobalAver  (None, 144)         0           ['block3a_activation[0][0]']
#  agePooling2D)
#
#  block3a_se_reshape (Reshape)   (None, 1, 1, 144)    0           ['block3a_se_squeeze[0][0]']
#
#  block3a_se_reduce (Conv2D)     (None, 1, 1, 6)      870         ['block3a_se_reshape[0][0]']
#
#  block3a_se_expand (Conv2D)     (None, 1, 1, 144)    1008        ['block3a_se_reduce[0][0]']
#
#  block3a_se_excite (Multiply)   (None, 13, 13, 144)  0           ['block3a_activation[0][0]',
#                                                                   'block3a_se_expand[0][0]']
#
#  block3a_project_conv (Conv2D)  (None, 13, 13, 40)   5760        ['block3a_se_excite[0][0]']
#
#  block3a_project_bn (BatchNorma  (None, 13, 13, 40)  160         ['block3a_project_conv[0][0]']
#  lization)
#
#  block3b_expand_conv (Conv2D)   (None, 13, 13, 240)  9600        ['block3a_project_bn[0][0]']
#
#  block3b_expand_bn (BatchNormal  (None, 13, 13, 240)  960        ['block3b_expand_conv[0][0]']
#  ization)
#
#  block3b_expand_activation (Act  (None, 13, 13, 240)  0          ['block3b_expand_bn[0][0]']
#  ivation)
#
#  block3b_dwconv (DepthwiseConv2  (None, 13, 13, 240)  6000       ['block3b_expand_activation[0][0]
#  D)                                                              ']
#
#  block3b_bn (BatchNormalization  (None, 13, 13, 240)  960        ['block3b_dwconv[0][0]']
#  )
#
#  block3b_activation (Activation  (None, 13, 13, 240)  0          ['block3b_bn[0][0]']
#  )
#
#  block3b_se_squeeze (GlobalAver  (None, 240)         0           ['block3b_activation[0][0]']
#  agePooling2D)
#
#  block3b_se_reshape (Reshape)   (None, 1, 1, 240)    0           ['block3b_se_squeeze[0][0]']
#
#  block3b_se_reduce (Conv2D)     (None, 1, 1, 10)     2410        ['block3b_se_reshape[0][0]']
#
#  block3b_se_expand (Conv2D)     (None, 1, 1, 240)    2640        ['block3b_se_reduce[0][0]']
#
#  block3b_se_excite (Multiply)   (None, 13, 13, 240)  0           ['block3b_activation[0][0]',
#                                                                   'block3b_se_expand[0][0]']
#
#  block3b_project_conv (Conv2D)  (None, 13, 13, 40)   9600        ['block3b_se_excite[0][0]']
#
#  block3b_project_bn (BatchNorma  (None, 13, 13, 40)  160         ['block3b_project_conv[0][0]']
#  lization)
#
#  block3b_drop (Dropout)         (None, 13, 13, 40)   0           ['block3b_project_bn[0][0]']
#
#  block3b_add (Add)              (None, 13, 13, 40)   0           ['block3b_drop[0][0]',
#                                                                   'block3a_project_bn[0][0]']
#
#  block4a_expand_conv (Conv2D)   (None, 13, 13, 240)  9600        ['block3b_add[0][0]']
#
#  block4a_expand_bn (BatchNormal  (None, 13, 13, 240)  960        ['block4a_expand_conv[0][0]']
#  ization)
#
#  block4a_expand_activation (Act  (None, 13, 13, 240)  0          ['block4a_expand_bn[0][0]']
#  ivation)
#
#  block4a_dwconv_pad (ZeroPaddin  (None, 15, 15, 240)  0          ['block4a_expand_activation[0][0]
#  g2D)                                                            ']
#
#  block4a_dwconv (DepthwiseConv2  (None, 7, 7, 240)   2160        ['block4a_dwconv_pad[0][0]']
#  D)
#
#  block4a_bn (BatchNormalization  (None, 7, 7, 240)   960         ['block4a_dwconv[0][0]']
#  )
#
#  block4a_activation (Activation  (None, 7, 7, 240)   0           ['block4a_bn[0][0]']
#  )
#
#  block4a_se_squeeze (GlobalAver  (None, 240)         0           ['block4a_activation[0][0]']
#  agePooling2D)
#
#  block4a_se_reshape (Reshape)   (None, 1, 1, 240)    0           ['block4a_se_squeeze[0][0]']
#
#  block4a_se_reduce (Conv2D)     (None, 1, 1, 10)     2410        ['block4a_se_reshape[0][0]']
#
#  block4a_se_expand (Conv2D)     (None, 1, 1, 240)    2640        ['block4a_se_reduce[0][0]']
#
#  block4a_se_excite (Multiply)   (None, 7, 7, 240)    0           ['block4a_activation[0][0]',
#                                                                   'block4a_se_expand[0][0]']
#
#  block4a_project_conv (Conv2D)  (None, 7, 7, 80)     19200       ['block4a_se_excite[0][0]']
#
#  block4a_project_bn (BatchNorma  (None, 7, 7, 80)    320         ['block4a_project_conv[0][0]']
#  lization)
#
#  block4b_expand_conv (Conv2D)   (None, 7, 7, 480)    38400       ['block4a_project_bn[0][0]']
#
#  block4b_expand_bn (BatchNormal  (None, 7, 7, 480)   1920        ['block4b_expand_conv[0][0]']
#  ization)
#
#  block4b_expand_activation (Act  (None, 7, 7, 480)   0           ['block4b_expand_bn[0][0]']
#  ivation)
#
#  block4b_dwconv (DepthwiseConv2  (None, 7, 7, 480)   4320        ['block4b_expand_activation[0][0]
#  D)                                                              ']
#
#  block4b_bn (BatchNormalization  (None, 7, 7, 480)   1920        ['block4b_dwconv[0][0]']
#  )
#
#  block4b_activation (Activation  (None, 7, 7, 480)   0           ['block4b_bn[0][0]']
#  )
#
#  block4b_se_squeeze (GlobalAver  (None, 480)         0           ['block4b_activation[0][0]']
#  agePooling2D)
#
#  block4b_se_reshape (Reshape)   (None, 1, 1, 480)    0           ['block4b_se_squeeze[0][0]']
#
#  block4b_se_reduce (Conv2D)     (None, 1, 1, 20)     9620        ['block4b_se_reshape[0][0]']
#
#  block4b_se_expand (Conv2D)     (None, 1, 1, 480)    10080       ['block4b_se_reduce[0][0]']
#
#  block4b_se_excite (Multiply)   (None, 7, 7, 480)    0           ['block4b_activation[0][0]',
#                                                                   'block4b_se_expand[0][0]']
#
#  block4b_project_conv (Conv2D)  (None, 7, 7, 80)     38400       ['block4b_se_excite[0][0]']
#
#  block4b_project_bn (BatchNorma  (None, 7, 7, 80)    320         ['block4b_project_conv[0][0]']
#  lization)
#
#  block4b_drop (Dropout)         (None, 7, 7, 80)     0           ['block4b_project_bn[0][0]']
#
#  block4b_add (Add)              (None,
]

# %%
import numpy as np
import cv2
import glob
import os
import matplotlib.pyplot as plt
import string
from mlxtend.plotting import plot_decision_regions
#from mpl_toolkits.mplot3d import Axes3D
#from sklearn.decomposition import PCA
#from sklearn.preprocessing import StandardScaler
#from sklearn.neighbors import KNeighborsClassifier
#from sklearn.tree import DecisionTreeClassifier
#from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.utils.multiclass import unique_labels
from sklearn import metrics
#from sklearn.svm import SVC


import json
from skimage import color
from skimage.feature import hog
#from sklearn import svm
from sklearn.metrics import classification_report,accuracy_score, recall_score
from subprocess import check_output

def plot_confusion_matrix(y_true, y_pred, classes,
                          normalize=False,
                          title=None,
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if not title:
        if normalize:
            title = 'Matriz de confusión'
        else:
            title = 'Matriz de confusión, sin normalización'

    # Compute confusion matrix

    cm = metrics.confusion_matrix(y_true, y_pred)
    # Only use the labels that appear in the data
    classes = unique_labels(y_true, y_pred)
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    fig, ax = plt.subplots()
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    # We want to show all ticks...

    ax.set(xticks=np.arange(cm.shape[1]),
           yticks=np.arange(cm.shape[0]),
           # ... and label them with the respective list entries
           xticklabels=labels, yticklabels=labels,
           title=title,
           ylabel='Etiqueta verdadera',
           xlabel='Etiqueta prevista')

    # Rotate the tick labels and set their alignment.

    plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
             rotation_mode="anchor")

    # Loop over data dimensions and create text annotations.

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], fmt),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")
    fig.tight_layout()
    return cm,ax

precision=metrics.accuracy_score(y_test,predicted_classes, normalize=False)

print("Muestras:{0:.2f}".format(precision))
cm,_=plot_confusion_matrix(y_test,predicted_classes,classes=nClasses,normalize=False,title="Matriz de confusión")
plt.show()


precision=metrics.accuracy_score(y_test,predicted_classes, normalize=True)*100

print("Accuracy:{0:.2f}%".format(precision))
cm,_=plot_confusion_matrix(y_test,predicted_classes,classes=nClasses,normalize=True,title="Matriz de confusión")
plt.show()
# Out:
# Muestras:21.00
# Accuracy:21.00%

# %%
import numpy as np
import cv2
import glob
import os
import matplotlib.pyplot as plt
import string
from mlxtend.plotting import plot_decision_regions
#from mpl_toolkits.mplot3d import Axes3D
#from sklearn.decomposition import PCA
#from sklearn.preprocessing import StandardScaler
#from sklearn.neighbors import KNeighborsClassifier
#from sklearn.tree import DecisionTreeClassifier
#from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.utils.multiclass import unique_labels
from sklearn import metrics
#from sklearn.svm import SVC


import json
from skimage import color
from skimage.feature import hog
#from sklearn import svm
from sklearn.metrics import classification_report,accuracy_score, recall_score
from subprocess import check_output

def plot_confusion_matrix(y_true, y_pred, classes,
                          normalize=False,
                          title=None,
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if not title:
        if normalize:
            title = 'Matriz de confusión'
        else:
            title = 'Matriz de confusión, sin normalización'

    # Compute confusion matrix

    cm = metrics.confusion_matrix(y_true, y_pred)
    # Only use the labels that appear in the data
    classes = unique_labels(y_true, y_pred)
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    fig, ax = plt.subplots()
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    # We want to show all ticks...

    ax.set(xticks=np.arange(cm.shape[1]),
           yticks=np.arange(cm.shape[0]),
           # ... and label them with the respective list entries
           xticklabels=labels, yticklabels=labels,
           title=title,
           ylabel='Etiqueta verdadera',
           xlabel='Etiqueta prevista')

    # Rotate the tick labels and set their alignment.

    plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
             rotation_mode="anchor")

    # Loop over data dimensions and create text annotations.

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], fmt),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")
    fig.tight_layout()
    return cm,ax

precision=metrics.accuracy_score(y_test,predicted_classes, normalize=True)*100

print("Accuracy:{0:.2f}%".format(precision))
cm,_=plot_confusion_matrix(y_test,predicted_classes,classes=nClasses,normalize=True,title="Matriz de confusión")
plt.show()
# Out:
# Accuracy:21.00%

# %%
model_out_efb0.save("/content/drive/My Drive/source_dir/gradoma_final_effb0.h5py")
# Out:
# INFO:tensorflow:Assets written to: /content/drive/My Drive/source_dir/gradoma_final_effb0.h5py/assets

# %% [markdown]
# **NUEVA PRUEBA DenseNet121**

# %%
#preprocess_input = tf.keras.applications.DenseNet121.preprocess_input
rescale = tf.keras.layers.experimental.preprocessing.Rescaling(1./127.5, offset= -1)
IMG_SIZE = (100, 100)
img_height=100
img_width=100

IMG_SHAPE = IMG_SIZE + (3,)
base_model = tf.keras.applications.DenseNet121(input_shape=IMG_SHAPE,
                                               include_top=False,
                                               weights='imagenet')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29089792/29084464 [==============================] - 0s 0us/step
# 29097984/29084464 [==============================] - 0s 0us/step

# %%
base_model.trainable = False

base_model.summary()
for layer in base_model.layers:
           if layer.name == 'block5_conv1':
              break
           layer.trainable = False

# We add our classificator (top_model) to the last layer of the model
last = base_model.layers[-1].output
x = Flatten()(last)
x = Dense(1000, activation='relu', name='fc1')(x)
x = Dropout(0.3)(x)
x = Dense(5, activation='softmax', name='predictions')(x)
model_out_desnet121 = Model(base_model.input, x)
#We compile the model
# Out:
# Model: "densenet121"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, 100, 100, 3  0           []
#                                 )]
#
#  zero_padding2d (ZeroPadding2D)  (None, 106, 106, 3)  0          ['input_4[0][0]']
#
#  conv1/conv (Conv2D)            (None, 50, 50, 64)   9408        ['zero_padding2d[0][0]']
#
#  conv1/bn (BatchNormalization)  (None, 50, 50, 64)   256         ['conv1/conv[0][0]']
#
#  conv1/relu (Activation)        (None, 50, 50, 64)   0           ['conv1/bn[0][0]']
#
#  zero_padding2d_1 (ZeroPadding2  (None, 52, 52, 64)  0           ['conv1/relu[0][0]']
#  D)
#
#  pool1 (MaxPooling2D)           (None, 25, 25, 64)   0           ['zero_padding2d_1[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 25, 25, 64)  256         ['pool1[0][0]']
#  ization)
#
#  conv2_block1_0_relu (Activatio  (None, 25, 25, 64)  0           ['conv2_block1_0_bn[0][0]']
#  n)
#
#  conv2_block1_1_conv (Conv2D)   (None, 25, 25, 128)  8192        ['conv2_block1_0_relu[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 25, 25, 128)  512        ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 25, 25, 128)  0          ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 25, 25, 32)   36864       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_concat (Concatena  (None, 25, 25, 96)  0           ['pool1[0][0]',
#  te)                                                              'conv2_block1_2_conv[0][0]']
#
#  conv2_block2_0_bn (BatchNormal  (None, 25, 25, 96)  384         ['conv2_block1_concat[0][0]']
#  ization)
#
#  conv2_block2_0_relu (Activatio  (None, 25, 25, 96)  0           ['conv2_block2_0_bn[0][0]']
#  n)
#
#  conv2_block2_1_conv (Conv2D)   (None, 25, 25, 128)  12288       ['conv2_block2_0_relu[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 25, 25, 128)  512        ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 25, 25, 128)  0          ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 25, 25, 32)   36864       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_concat (Concatena  (None, 25, 25, 128)  0          ['conv2_block1_concat[0][0]',
#  te)                                                              'conv2_block2_2_conv[0][0]']
#
#  conv2_block3_0_bn (BatchNormal  (None, 25, 25, 128)  512        ['conv2_block2_concat[0][0]']
#  ization)
#
#  conv2_block3_0_relu (Activatio  (None, 25, 25, 128)  0          ['conv2_block3_0_bn[0][0]']
#  n)
#
#  conv2_block3_1_conv (Conv2D)   (None, 25, 25, 128)  16384       ['conv2_block3_0_relu[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 25, 25, 128)  512        ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 25, 25, 128)  0          ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 25, 25, 32)   36864       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_concat (Concatena  (None, 25, 25, 160)  0          ['conv2_block2_concat[0][0]',
#  te)                                                              'conv2_block3_2_conv[0][0]']
#
#  conv2_block4_0_bn (BatchNormal  (None, 25, 25, 160)  640        ['conv2_block3_concat[0][0]']
#  ization)
#
#  conv2_block4_0_relu (Activatio  (None, 25, 25, 160)  0          ['conv2_block4_0_bn[0][0]']
#  n)
#
#  conv2_block4_1_conv (Conv2D)   (None, 25, 25, 128)  20480       ['conv2_block4_0_relu[0][0]']
#
#  conv2_block4_1_bn (BatchNormal  (None, 25, 25, 128)  512        ['conv2_block4_1_conv[0][0]']
#  ization)
#
#  conv2_block4_1_relu (Activatio  (None, 25, 25, 128)  0          ['conv2_block4_1_bn[0][0]']
#  n)
#
#  conv2_block4_2_conv (Conv2D)   (None, 25, 25, 32)   36864       ['conv2_block4_1_relu[0][0]']
#
#  conv2_block4_concat (Concatena  (None, 25, 25, 192)  0          ['conv2_block3_concat[0][0]',
#  te)                                                              'conv2_block4_2_conv[0][0]']
#
#  conv2_block5_0_bn (BatchNormal  (None, 25, 25, 192)  768        ['conv2_block4_concat[0][0]']
#  ization)
#
#  conv2_block5_0_relu (Activatio  (None, 25, 25, 192)  0          ['conv2_block5_0_bn[0][0]']
#  n)
#
#  conv2_block5_1_conv (Conv2D)   (None, 25, 25, 128)  24576       ['conv2_block5_0_relu[0][0]']
#
#  conv2_block5_1_bn (BatchNormal  (None, 25, 25, 128)  512        ['conv2_block5_1_conv[0][0]']
#  ization)
#
#  conv2_block5_1_relu (Activatio  (None, 25, 25, 128)  0          ['conv2_block5_1_bn[0][0]']
#  n)
#
#  conv2_block5_2_conv (Conv2D)   (None, 25, 25, 32)   36864       ['conv2_block5_1_relu[0][0]']
#
#  conv2_block5_concat (Concatena  (None, 25, 25, 224)  0          ['conv2_block4_concat[0][0]',
#  te)                                                              'conv2_block5_2_conv[0][0]']
#
#  conv2_block6_0_bn (BatchNormal  (None, 25, 25, 224)  896        ['conv2_block5_concat[0][0]']
#  ization)
#
#  conv2_block6_0_relu (Activatio  (None, 25, 25, 224)  0          ['conv2_block6_0_bn[0][0]']
#  n)
#
#  conv2_block6_1_conv (Conv2D)   (None, 25, 25, 128)  28672       ['conv2_block6_0_relu[0][0]']
#
#  conv2_block6_1_bn (BatchNormal  (None, 25, 25, 128)  512        ['conv2_block6_1_conv[0][0]']
#  ization)
#
#  conv2_block6_1_relu (Activatio  (None, 25, 25, 128)  0          ['conv2_block6_1_bn[0][0]']
#  n)
#
#  conv2_block6_2_conv (Conv2D)   (None, 25, 25, 32)   36864       ['conv2_block6_1_relu[0][0]']
#
#  conv2_block6_concat (Concatena  (None, 25, 25, 256)  0          ['conv2_block5_concat[0][0]',
#  te)                                                              'conv2_block6_2_conv[0][0]']
#
#  pool2_bn (BatchNormalization)  (None, 25, 25, 256)  1024        ['conv2_block6_concat[0][0]']
#
#  pool2_relu (Activation)        (None, 25, 25, 256)  0           ['pool2_bn[0][0]']
#
#  pool2_conv (Conv2D)            (None, 25, 25, 128)  32768       ['pool2_relu[0][0]']
#
#  pool2_pool (AveragePooling2D)  (None, 12, 12, 128)  0           ['pool2_conv[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 12, 12, 128)  512        ['pool2_pool[0][0]']
#  ization)
#
#  conv3_block1_0_relu (Activatio  (None, 12, 12, 128)  0          ['conv3_block1_0_bn[0][0]']
#  n)
#
#  conv3_block1_1_conv (Conv2D)   (None, 12, 12, 128)  16384       ['conv3_block1_0_relu[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 12, 12, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 12, 12, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 12, 12, 32)   36864       ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_concat (Concatena  (None, 12, 12, 160)  0          ['pool2_pool[0][0]',
#  te)                                                              'conv3_block1_2_conv[0][0]']
#
#  conv3_block2_0_bn (BatchNormal  (None, 12, 12, 160)  640        ['conv3_block1_concat[0][0]']
#  ization)
#
#  conv3_block2_0_relu (Activatio  (None, 12, 12, 160)  0          ['conv3_block2_0_bn[0][0]']
#  n)
#
#  conv3_block2_1_conv (Conv2D)   (None, 12, 12, 128)  20480       ['conv3_block2_0_relu[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 12, 12, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 12, 12, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 12, 12, 32)   36864       ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_concat (Concatena  (None, 12, 12, 192)  0          ['conv3_block1_concat[0][0]',
#  te)                                                              'conv3_block2_2_conv[0][0]']
#
#  conv3_block3_0_bn (BatchNormal  (None, 12, 12, 192)  768        ['conv3_block2_concat[0][0]']
#  ization)
#
#  conv3_block3_0_relu (Activatio  (None, 12, 12, 192)  0          ['conv3_block3_0_bn[0][0]']
#  n)
#
#  conv3_block3_1_conv (Conv2D)   (None, 12, 12, 128)  24576       ['conv3_block3_0_relu[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 12, 12, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 12, 12, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 12, 12, 32)   36864       ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_concat (Concatena  (None, 12, 12, 224)  0          ['conv3_block2_concat[0][0]',
#  te)                                                              'conv3_block3_2_conv[0][0]']
#
#  conv3_block4_0_bn (BatchNormal  (None, 12, 12, 224)  896        ['conv3_block3_concat[0][0]']
#  ization)
#
#  conv3_block4_0_relu (Activatio  (None, 12, 12, 224)  0          ['conv3_block4_0_bn[0][0]']
#  n)
#
#  conv3_block4_1_conv (Conv2D)   (None, 12, 12, 128)  28672       ['conv3_block4_0_relu[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 12, 12, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 12, 12, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 12, 12, 32)   36864       ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_concat (Concatena  (None, 12, 12, 256)  0          ['conv3_block3_concat[0][0]',
#  te)                                                              'conv3_block4_2_conv[0][0]']
#
#  conv3_block5_0_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv3_block4_concat[0][0]']
#  ization)
#
#  conv3_block5_0_relu (Activatio  (None, 12, 12, 256)  0          ['conv3_block5_0_bn[0][0]']
#  n)
#
#  conv3_block5_1_conv (Conv2D)   (None, 12, 12, 128)  32768       ['conv3_block5_0_relu[0][0]']
#
#  conv3_block5_1_bn (BatchNormal  (None, 12, 12, 128)  512        ['conv3_block5_1_conv[0][0]']
#  ization)
#
#  conv3_block5_1_relu (Activatio  (None, 12, 12, 128)  0          ['conv3_block5_1_bn[0][0]']
#  n)
#
#  conv3_block5_2_conv (Conv2D)   (None, 12, 12, 32)   36864       ['conv3_block5_1_relu[0][0]']
#
#  conv3_block5_concat (Concatena  (None, 12, 12, 288)  0          ['conv3_block4_concat[0][0]',
#  te)                                                              'conv3_block5_2_conv[0][0]']
#
#  conv3_block6_0_bn (BatchNormal  (None, 12, 12, 288)  1152       ['conv3_block5_concat[0][0]']
#  ization)
#
#  conv3_block6_0_relu (Activatio  (None, 12, 12, 288)  0          ['conv3_block6_0_bn[0][0]']
#  n)
#
#  conv3_block6_1_conv (Conv2D)   (None, 12, 12, 128)  36864       ['conv3_block6_0_relu[0][0]']
#
#  conv3_block6_1_bn (BatchNormal  (None, 12, 12, 128)  512        ['conv3_block6_1_conv[0][0]']
#  ization)
#
#  conv3_block6_1_relu (Activatio  (None, 12, 12, 128)  0          ['conv3_block6_1_bn[0][0]']
#  n)
#
#  conv3_block6_2_conv (Conv2D)   (None, 12, 12, 32)   36864       ['conv3_block6_1_relu[0][0]']
#
#  conv3_block6_concat (Concatena  (None, 12, 12, 320)  0          ['conv3_block5_concat[0][0]',
#  te)                                                              'conv3_block6_2_conv[0][0]']
#
#  conv3_block7_0_bn (BatchNormal  (None, 12, 12, 320)  1280       ['conv3_block6_concat[0][0]']
#  ization)
#
#  conv3_block7_0_relu (Activatio  (None, 12, 12, 320)  0          ['conv3_block7_0_bn[0][0]']
#  n)
#
#  conv3_block7_1_conv (Conv2D)   (None, 12, 12, 128)  40960       ['conv3_block7_0_relu[0][0]']
#
#  conv3_block7_1_bn (BatchNormal  (None, 12, 12, 128)  512        ['conv3_block7_1_conv[0][0]']
#  ization)
#
#  conv3_block7_1_relu (Activatio  (None, 12, 12, 128)  0          ['conv3_block7_1_bn[0][0]']
#  n)
#
#  conv3_block7_2_conv (Conv2D)   (None, 12, 12, 32)   36864       ['conv3_block7_1_relu[0][0]']
#
#  conv3_block7_concat (Concatena  (None, 12, 12, 352)  0          ['conv3_block6_concat[0][0]',
#  te)                                                              'conv3_block7_2_conv[0][0]']
#
#  conv3_block8_0_bn (BatchNormal  (None, 12, 12, 352)  1408       ['conv3_block7_concat[0][0]']
#  ization)
#
#  conv3_block8_0_relu (Activatio  (None, 12, 12, 352)  0          ['conv3_block8_0_bn[0][0]']
#  n)
#
#  conv3_block8_1_conv (Conv2D)   (None, 12, 12, 128)  45056       ['conv3_block8_0_relu[0][0]']
#
#  conv3_block8_1_bn (BatchNormal  (None, 12, 12, 128)  512        ['conv3_block8_1_conv[0][0]']
#  ization)
#
#  conv3_block8_1_relu (Activatio  (None, 12, 12, 128)  0          ['conv3_block8_1_bn[0][0]']
#  n)
#
#  conv3_block8_2_conv (Conv2D)   (None, 12, 12, 32)   36864       ['conv3_block8_1_relu[0][0]']
#
#  conv3_block8_concat (Concatena  (None, 12, 12, 384)  0          ['conv3_block7_concat[0][0]',
#  te)                                                              'conv3_block8_2_conv[0][0]']
#
#  conv3_block9_0_bn (BatchNormal  (None, 12, 12, 384)  1536       ['conv3_block8_concat[0][0]']
#  ization)
#
#  conv3_block9_0_relu (Activatio  (None, 12, 12, 384)  0          ['conv3_block9_0_bn[0][0]']
#  n)
#
#  conv3_block9_1_conv (Conv2D)   (None, 12, 12, 128)  49152       ['conv3_block9_0_relu[0][0]']
#
#  conv3_block9_1_bn (BatchNormal  (None, 12, 12, 128)  512        ['conv3_block9_1_conv[0][0]']
#  ization)
#
#  conv3_block9_1_relu (Activatio  (None, 12, 12, 128)  0          ['conv3_block9_1_bn[0][0]']
#  n)
#
#  conv3_block9_2_conv (Conv2D)   (None, 12, 12, 32)   36864       ['conv3_block9_1_relu[0][0]']
#
#  conv3_block9_concat (Concatena  (None, 12, 12, 416)  0          ['conv3_block8_concat[0][0]',
#  te)                                                              'conv3_block9_2_conv[0][0]']
#
#  conv3_block10_0_bn (BatchNorma  (None, 12, 12, 416)  1664       ['conv3_block9_concat[0][0]']
#  lization)
#
#  conv3_block10_0_relu (Activati  (None, 12, 12, 416)  0          ['conv3_block10_0_bn[0][0]']
#  on)
#
#  conv3_block10_1_conv (Conv2D)  (None, 12, 12, 128)  53248       ['conv3_block10_0_relu[0][0]']
#
#  conv3_block10_1_bn (BatchNorma  (None, 12, 12, 128)  512        ['conv3_block10_1_conv[0][0]']
#  lization)
#
#  conv3_block10_1_relu (Activati  (None, 12, 12, 128)  0          ['conv3_block10_1_bn[0][0]']
#  on)
#
#  conv3_block10_2_conv (Conv2D)  (None, 12, 12, 32)   36864       ['conv3_block10_1_relu[0][0]']
#
#  conv3_block10_concat (Concaten  (None, 12, 12, 448)  0          ['conv3_block9_concat[0][0]',
#  ate)                                                             'conv3_block10_2_conv[0][0]']
#
#  conv3_block11_0_bn (BatchNorma  (None, 12, 12, 448)  1792       ['conv3_block10_concat[0][0]']
#  lization)
#
#  conv3_block11_0_relu (Activati  (None, 12, 12, 448)  0          ['conv3_block11_0_bn[0][0]']
#  on)
#
#  conv3_block11_1_conv (Conv2D)  (None, 12, 12, 128)  57344       ['conv3_block11_0_relu[0][0]']
#
#  conv3_block11_1_bn (BatchNorma  (None, 12, 12, 128)  512        ['conv3_block11_1_conv[0][0]']
#  lization)
#
#  conv3_block11_1_relu (Activati  (None, 12, 12, 128)  0          ['conv3_block11_1_bn[0][0]']
#  on)
#
#  conv3_block11_2_conv (Conv2D)  (None, 12, 12, 32)   36864       ['conv3_block11_1_relu[0][0]']
#
#  conv3_block11_concat (Concaten  (None, 12, 12, 480)  0          ['conv3_block10_concat[0][0]',
#  ate)                                                             'conv3_block11_2_conv[0][0]']
#
#  conv3_block12_0_bn (BatchNorma  (None, 12, 12, 480)  1920       ['conv3_block11_concat[0][0]']
#  lization)
#
#  conv3_block12_0_relu (Activati  (None, 12, 12, 480)  0          ['conv3_block12_0_bn[0][0]']
#  on)
#
#  conv3_block12_1_conv (Conv2D)  (None, 12, 12, 128)  61440       ['conv3_block12_0_relu[0][0]']
#
#  conv3_block12_1_bn (BatchNorma  (None, 12, 12, 128)  512        ['conv3_block12_1_conv[0][0]']
#  lization)
#
#  conv3_block12_1_relu (Activati  (None, 12, 12, 128)  0          ['conv3_block12_1_bn[0][0]']
#  on)
#
#  conv3_block12_2_conv (Conv2D)  (None, 12, 12, 32)   36864       ['conv3_block12_1_relu[0][0]']
#
#  conv3_block12_concat (Concaten  (None, 12, 12, 512)  0          ['conv3_block11_concat[0][0]',
#  ate)                                                             'conv3_block12_2_conv[0][0]']
#
#  pool3_bn (BatchNormalization)  (None, 12, 12, 512)  2048        ['conv3_block12_concat[0][0]']
#
#  pool3_relu (Activation)        (None, 12, 12, 512)  0           ['pool3_bn[0][0]']
#
#  pool3_conv (Conv2D)            (None, 12, 12, 256)  131072      ['pool3_relu[0][0]']
#
#  pool3_pool (AveragePooling2D)  (None, 6, 6, 256)    0           ['pool3_conv[0][0]']
#
#  conv4_block1_0_bn (BatchNormal  (None, 6, 6, 256)   1024        ['pool3_pool[0][0]']
#  ization)
#
#  conv4_block1_0_relu (Activatio  (None, 6, 6, 256)   0           ['conv4_block1_0_bn[0][0]']
#  n)
#
#  conv4_block1_1_conv (Conv2D)   (None, 6, 6, 128)    32768       ['conv4_block1_0_relu[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 6, 6, 128)   512         ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 6, 6, 128)   0           ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 6, 6, 32)     36864       ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_concat (Concatena  (None, 6, 6, 288)   0           ['pool3_pool[0][0]',
#  te)                                                              'conv4_block1_2_conv[0][0]']
#
#  conv4_block2_0_bn (BatchNormal  (None, 6, 6, 288)   1152        ['conv4_block1_concat[0][0]']
#  ization)
#
#  conv4_block2_0_relu (Activatio  (None, 6, 6, 288)   0           ['conv4_block2_0_bn[0][0]']
#  n)
#
#  conv4_block2_1_conv (Conv2D)   (None, 6, 6, 128)    36864       ['conv4_block2_0_relu[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 6, 6, 128)   512         ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 6, 6, 128)   0           ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 6, 6, 32)     36864       ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_concat (Concatena  (None, 6, 6, 320)   0           ['conv4_block1_concat[0][0]',
#  te)                                                              'conv4_block2_2_conv[0][0]']
#
#  conv4_block3_0_bn (BatchNormal  (None, 6, 6, 320)   1280        ['conv4_block2_concat[0][0]']
#  ization)
#
#  conv4_block3_0_relu (Activatio  (None, 6, 6, 320)   0           ['conv4_block3_0_bn[0][0]']
#  n)
#
#  conv4_block3_1_conv (Conv2D)   (None, 6, 6, 128)    40960       ['conv4_block3_0_relu[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 6, 6, 128)   512         ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 6, 6, 128)   0           ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 6, 6, 32)     36864       ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_concat (Concatena  (None, 6, 6, 352)   0           ['conv4_block2_concat[0][0]',
#  te)                                                              'conv4_block3_2_conv[0][0]']
#
#  conv4_block4_0_bn (BatchNormal  (None, 6, 6, 352)   1408        ['conv4_block3_concat[0][0]']
#  ization)
#
#  conv4_block4_0_relu (Activatio  (None, 6, 6, 352)   0           ['conv4_block4_0_bn[0][0]']
#  n)
#
#  conv4_block4_1_conv (Conv2D)   (None, 6, 6, 128)    45056       ['conv4_block4_0_relu[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 6, 6, 128)   512         ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 6, 6, 128)   0           ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 6, 6, 32)     36864       ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_concat (Concatena  (None, 6, 6, 384)   0           ['conv4_block3_concat[0][0]',
#  te)                                                              'conv4_block4_2_conv[0][0]']
#
#  conv4_block5_0_bn (BatchNormal  (None, 6, 6, 384)   1536        ['conv4_block4_concat[0][0]']
#  ization)
#
#  conv4_block5_0_relu (Activatio  (None, 6, 6, 384)   0           ['conv4_block5_0_bn[0][0]']
#  n)
#
#  conv4_block5_1_conv (Conv2D)   (None, 6, 6, 128)    49152       ['conv4_block5_0_relu[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 6, 6, 128)   512         ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 6, 6, 128)   0           ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 6, 6, 32)     36864       ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_concat (Concatena  (None, 6, 6, 416)   0           ['conv4_block4_concat[0][0]',
#  te)                                                              'conv4_block5_2_conv[0][0]']
#
#  conv4_block6_0_bn (BatchNormal  (None, 6, 6, 416)   1664        ['conv4_block5_concat[0][0]']
#  ization)
#
#  conv4_block6_0_relu (Activatio  (None, 6, 6, 416)   0           ['conv4_block6_0_bn[0][0]']
#  n)
#
#  conv4_block6_1_conv (Conv2D)   (None, 6, 6, 128)    53248       ['conv4_block6_0_relu[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 6, 6, 128)   512         ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 6, 6, 128)   0           ['conv4_block6_1_bn[0][0]']
# ...
#  te)                                                              'conv5_block8_2_conv[0][0]']
#
#  conv5_block9_0_bn (BatchNormal  (None, 3, 3, 768)   3072        ['conv5_block8_concat[0][0]']
#  ization)
#
#  conv5_block9_0_relu (Activatio  (None, 3, 3, 768)   0           ['conv5_block9_0_bn[0][0]']
#  n)
#
#  conv5_block9_1_conv (Conv2D)   (None, 3, 3, 128)    98304       ['conv5_block9_0_relu[0][0]']
#
#  conv5_block9_1_bn (BatchNormal  (None, 3, 3, 128)   512         ['conv5_block9_1_conv[0][0]']
#  ization)
#
#  conv5_block9_1_relu (Activatio  (None, 3, 3, 128)   0           ['conv5_block9_1_bn[0][0]']
#  n)
#
#  conv5_block9_2_conv (Conv2D)   (None, 3, 3, 32)     36864       ['conv5_block9_1_relu[0][0]']
#
#  conv5_block9_concat (Concatena  (None, 3, 3, 800)   0           ['conv5_block8_concat[0][0]',
#  te)                                                              'conv5_block9_2_conv[0][0]']
#
#  conv5_block10_0_bn (BatchNorma  (None, 3, 3, 800)   3200        ['conv5_block9_concat[0][0]']
#  lization)
#
#  conv5_block10_0_relu (Activati  (None, 3, 3, 800)   0           ['conv5_block10_0_bn[0][0]']
#  on)
#
#  conv5_block10_1_conv (Conv2D)  (None, 3, 3, 128)    102400      ['conv5_block10_0_relu[0][0]']
#
#  conv5_block10_1_bn (BatchNorma  (None, 3, 3, 128)   512         ['conv5_block10_1_conv[0][0]']
#  lization)
#
#  conv5_block10_1_relu (Activati  (None, 3, 3, 128)   0           ['conv5_block10_1_bn[0][0]']
#  on)
#
#  conv5_block10_2_conv (Conv2D)  (None, 3, 3, 32)     36864       ['conv5_block10_1_relu[0][0]']
#
#  conv5_block10_concat (Concaten  (None, 3, 3, 832)   0           ['conv5_block9_concat[0][0]',
#  ate)                                                             'conv5_block10_2_conv[0][0]']
#
#  conv5_block11_0_bn (BatchNorma  (None, 3, 3, 832)   3328        ['conv5_block10_concat[0][0]']
#  lization)
#
#  conv5_block11_0_relu (Activati  (None, 3, 3, 832)   0           ['conv5_block11_0_bn[0][0]']
#  on)
#
#  conv5_block11_1_conv (Conv2D)  (None, 3, 3, 128)    106496      ['conv5_block11_0_relu[0][0]']
#
#  conv5_block11_1_bn (BatchNorma  (None, 3, 3, 128)   512         ['conv5_block11_1_conv[0][0]']
#  lization)
#
#  conv5_block11_1_relu (Activati  (None, 3, 3, 128)   0           ['conv5_block11_1_bn[0][0]']
#  on)
#
#  conv5_block11_2_conv (Conv2D)  (None, 3, 3, 32)     36864       ['conv5_block11_1_relu[0][0]']
#
#  conv5_block11_concat (Concaten  (None, 3, 3, 864)   0           ['conv5_block10_concat[0][0]',
#  ate)                                                             'conv5_block11_2_conv[0][0]']
#
#  conv5_block12_0_bn (BatchNorma  (None, 3, 3, 864)   3456        ['conv5_block11_concat[0][0]']
#  lization)
#
#  conv5_block12_0_relu (Activati  (None, 3, 3, 864)   0           ['conv5_block12_0_bn[0][0]']
#  on)
#
#  conv5_block12_1_conv (Conv2D)  (None, 3, 3, 128)    110592      ['conv5_block12_0_relu[0][0]']
#
#  conv5_block12_1_bn (BatchNorma  (None, 3, 3, 128)   512         ['conv5_block12_1_conv[0][0]']
#  lization)
#
#  conv5_block12_1_relu (Activati  (None, 3, 3, 128)   0           ['conv5_block12_1_bn[0][0]']
#  on)
#
#  conv5_block12_2_conv (Conv2D)  (None, 3, 3, 32)     36864       ['conv5_block12_1_relu[0][0]']
#
#  conv5_block12_concat (Concaten  (None, 3, 3, 896)   0           ['conv5_block11_concat[0][0]',
#  ate)                                                             'conv5_block12_2_conv[0][0]']
#
#  conv5_block13_0_bn (BatchNorma  (None, 3, 3, 896)   3584        ['conv5_block12_concat[0][0]']
#  lization)
#
#  conv5_block13_0_relu (Activati  (None, 3, 3, 896)   0           ['conv5_block13_0_bn[0][0]']
#  on)
#
#  conv5_block13_1_conv (Conv2D)  (None, 3, 3, 128)    114688      ['conv5_block13_0_relu[0][0]']
#
#  conv5_block13_1_bn (BatchNorma  (None, 3, 3, 128)   512         ['conv5_block13_1_conv[0][0]']
#  lization)
#
#  conv5_block13_1_relu (Activati  (None, 3, 3, 128)   0           ['conv5_block13_1_bn[0][0]']
#  on)
#
#  conv5_block13_2_conv (Conv2D)  (None, 3, 3, 32)     36864       ['conv5_block13_1_relu[0][0]']
#
#  conv5_block13_concat (Concaten  (None, 3, 3, 928)   0           ['conv5_block12_concat[0][0]',
#  ate)                                                             'conv5_block13_2_conv[0][0]']
#
#  conv5_block14_0_bn (BatchNorma  (None, 3, 3, 928)   3712        ['conv5_block13_concat[0][0]']
#  lization)
#
#  conv5_block14_0_relu (Activati  (None, 3, 3, 928)   0           ['conv5_block14_0_bn[0][0]']
#  on)
#
#  conv5_block14_1_conv (Conv2D)  (None, 3, 3, 128)    118784      ['conv5_block14_0_relu[0][0]']
#
#  conv5_block14_1_bn (BatchNorma  (None, 3, 3, 128)   512         ['conv5_block14_1_conv[0][0]']
#  lization)
#
#  conv5_block14_1_relu (Activati  (None, 3, 3, 128)   0           ['conv5_block14_1_bn[0][0]']
#  on)
#
#  conv5_block14_2_conv (Conv2D)  (None, 3, 3, 32)     36864       ['conv5_block14_1_relu[0][0]']
#
#  conv5_block14_concat (Concaten  (None, 3, 3, 960)   0           ['conv5_block13_concat[0][0]',
#  ate)                                                             'conv5_block14_2_conv[0][0]']
#
#  conv5_block15_0_bn (BatchNorma  (None, 3, 3, 960)   3840        ['conv5_block14_concat[0][0]']
#  lization)
#
#  conv5_block15_0_relu (Activati  (None, 3, 3, 960)   0           ['conv5_block15_0_bn[0][0]']
#  on)
#
#  conv5_block15_1_conv (Conv2D)  (None, 3, 3, 128)    122880      ['conv5_block15_0_relu[0][0]']
#
#  conv5_block15_1_bn (BatchNorma  (None, 3, 3, 128)   512         ['conv5_block15_1_conv[0][0]']
#  lization)
#
#  conv5_block15_1_relu (Activati  (None, 3, 3, 128)   0           ['conv5_block15_1_bn[0][0]']
#  on)
#
#  conv5_block15_2_conv (Conv2D)  (None, 3, 3, 32)     36864       ['conv5_block15_1_relu[0][0]']
#
#  conv5_block15_concat (Concaten  (None, 3, 3, 992)   0           ['conv5_block14_concat[0][0]',
#  ate)                                                             'conv5_block15_2_conv[0][0]']
#
#  conv5_block16_0_bn (BatchNorma  (None, 3, 3, 992)   3968        ['conv5_block15_concat[0][0]']
#  lization)
#
#  conv5_block16_0_relu (Activati  (None, 3, 3, 992)   0           ['conv5_block16_0_bn[0][0]']
#  on)
#
#  conv5_block16_1_conv (Conv2D)  (None, 3, 3, 128)    126976      ['conv5_block16_0_relu[0][0]']
#
#  conv5_block16_1_bn (BatchNorma  (None, 3, 3, 128)   512         ['conv5_block16_1_conv[0][0]']
#  lization)
#
#  conv5_block16_1_relu (Activati  (None, 3, 3, 128)   0           ['conv5_block16_1_bn[0][0]']
#  on)
#
#  conv5_block16_2_conv (Conv2D)  (None, 3, 3, 32)     36864       ['conv5_block16_1_relu[0][0]']
#
#  conv5_block16_concat (Concaten  (None, 3, 3, 1024)  0           ['conv5_block15_concat[0][0]',
#  ate)                                                             'conv5_block16_2_conv[0][0]']
#
#  bn (BatchNormalization)        (None, 3, 3, 1024)   4096        ['conv5_block16_concat[0][0]']
#
#  relu (Activation)              (None, 3, 3, 1024)   0           ['bn[0][0]']
#
# ==================================================================================================
# Total params: 7,037,504
# Trainable params: 0
# Non-trainable params: 7,037,504
# __________________________________________________________________________________________________

# %%
model_out_desnet121.compile(loss=keras.losses.categorical_crossentropy, optimizer=tf.keras.optimizers.Adam(learning_rate=INIT_LR, decay=INIT_LR / 100),metrics=['accuracy'])
model_out_desnet121.summary()
callback = tf.keras.callbacks.EarlyStopping(monitor='loss', min_delta=0.0001, patience=3)

grado_train_dropout = model_out_desnet121.fit(train_x, train_label, batch_size=batch_size,epochs=epochs,verbose=1,validation_data=(valid_X, valid_label),callbacks=[callback])
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, 100, 100, 3  0           []
#                                 )]
#
#  zero_padding2d (ZeroPadding2D)  (None,
100
# 5/5 [==============================] - 12s 2s/step - loss: 0.0101 - accuracy: 1.0000 - val_loss: 0.4224 - val_accuracy: 0.8875
# Epoch 11/100
# 5/5 [==============================] - 12s 2s/step - loss: 0.0083 - accuracy: 1.0000 - val_loss: 0.4123 - val_accuracy: 0.8875
# Epoch 12/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.0072 - accuracy: 1.0000 - val_loss: 0.4049 - val_accuracy: 0.8875
# Epoch 13/100
# 5/5 [==============================] - 12s 2s/step - loss: 0.0109 - accuracy: 0.9969 - val_loss: 0.4037 - val_accuracy: 0.8875
# Epoch 14/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.4062 - val_accuracy: 0.8875
# Epoch 15/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.4070 - val_accuracy: 0.8875
# Epoch 16/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.4030 - val_accuracy: 0.8875
# Epoch 17/100
# 5/5 [==============================] - 12s 2s/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.4015 - val_accuracy: 0.9125
# Epoch 18/100
# 5/5 [==============================] - 12s 2s/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.4016 - val_accuracy: 0.9125
# Epoch 19/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.4045 - val_accuracy: 0.9125
# Epoch 20/100
# 5/5 [==============================] - 12s 2s/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.4069 - val_accuracy: 0.9125
# Epoch 21/100
# 5/5 [==============================] - 12s 2s/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.4102 - val_accuracy: 0.8875
# Epoch 22/100
# 5/5 [==============================] - 11s 2s/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.4134 - val_accuracy: 0.8875
# Epoch 23/100
# 5/5 [==============================] - 12s 2s/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.4161 - val_accuracy: 0.8875
# Epoch 24/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.4185 - val_accuracy: 0.8875
# Epoch 25/100
# 5/5 [==============================] - 12s 2s/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.4206 - val_accuracy: 0.8875

# %%
acc = grado_train_dropout.history['accuracy']
val_acc = grado_train_dropout.history['val_accuracy']

loss = grado_train_dropout.history['loss']
val_loss = grado_train_dropout.history['val_loss']

plt.figure(figsize=(10, 10))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Exactitud Entrenamiento ')
plt.plot(val_acc, label='Exactitud Validación')
plt.legend(loc='lower right')
plt.ylabel('Exactitud')
plt.ylim([min(plt.ylim()),1])
plt.title('Exactitud Entrenamiento y Validación ')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Pérdida Entrenamiento')
plt.plot(val_loss, label='Pérdida Validación')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,1.0])
plt.title(' Pérdida Entrenamiento y Validación ')
plt.xlabel('epoch')
plt.show()

# %%
predicted_classes = model_out_desnet121.predict(x_test)
predicted_classes = np.argmax(np.round(predicted_classes),axis=1)
predicted_classes.shape, y_test.shape
# Out:
# ((100,), (100,))

# %%
from sklearn.metrics import classification_report
target_names = ["Class {}".format(i) for i in range(nClasses)]
print(classification_report(y_test, predicted_classes, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#      Class 0       1.00      0.90      0.95        21
#      Class 1       0.95      0.95      0.95        19
#      Class 2       0.89      1.00      0.94        17
#      Class 3       1.00      0.96      0.98        23
#      Class 4       0.95      1.00      0.98        20
#
#     accuracy                           0.96       100
#    macro avg       0.96      0.96      0.96       100
# weighted avg       0.96      0.96      0.96       100

# %%
import numpy as np
import cv2
import glob
import os
import matplotlib.pyplot as plt
import string
from mlxtend.plotting import plot_decision_regions
#from mpl_toolkits.mplot3d import Axes3D
#from sklearn.decomposition import PCA
#from sklearn.preprocessing import StandardScaler
#from sklearn.neighbors import KNeighborsClassifier
#from sklearn.tree import DecisionTreeClassifier
#from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.utils.multiclass import unique_labels
from sklearn import metrics
#from sklearn.svm import SVC


import json
from skimage import color
from skimage.feature import hog
#from sklearn import svm
from sklearn.metrics import classification_report,accuracy_score, recall_score
from subprocess import check_output

def plot_confusion_matrix(y_true, y_pred, classes,
                          normalize=False,
                          title=None,
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if not title:
        if normalize:
            title = 'Matriz de confusión'
        else:
            title = 'Matriz de confusión, sin normalización'

    # Compute confusion matrix

    cm = metrics.confusion_matrix(y_true, y_pred)
    # Only use the labels that appear in the data
    classes = unique_labels(y_true, y_pred)
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    fig, ax = plt.subplots()
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    # We want to show all ticks...

    ax.set(xticks=np.arange(cm.shape[1]),
           yticks=np.arange(cm.shape[0]),
           # ... and label them with the respective list entries
           xticklabels=labels, yticklabels=labels,
           title=title,
           ylabel='Etiqueta verdadera',
           xlabel='Etiqueta prevista')

    # Rotate the tick labels and set their alignment.

    plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
             rotation_mode="anchor")

    # Loop over data dimensions and create text annotations.

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], fmt),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")
    fig.tight_layout()
    return cm,ax

precision=metrics.accuracy_score(y_test,predicted_classes, normalize=False)

print("Muestras:{0:.2f}".format(precision))
cm,_=plot_confusion_matrix(y_test,predicted_classes,classes=nClasses,normalize=False,title="Matriz de confusión")
plt.show()

precision=metrics.accuracy_score(y_test,predicted_classes, normalize=True)*100

print("Accuracy:{0:.2f}%".format(precision))
cm,_=plot_confusion_matrix(y_test,predicted_classes,classes=nClasses,normalize=True,title="Matriz de confusión")
plt.show()
# Out:
# Muestras:96.00
# Accuracy:96.00%

# %%
import numpy as np
import cv2
import glob
import os
import matplotlib.pyplot as plt
import string
from mlxtend.plotting import plot_decision_regions
#from mpl_toolkits.mplot3d import Axes3D
#from sklearn.decomposition import PCA
#from sklearn.preprocessing import StandardScaler
#from sklearn.neighbors import KNeighborsClassifier
#from sklearn.tree import DecisionTreeClassifier
#from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.utils.multiclass import unique_labels
from sklearn import metrics
#from sklearn.svm import SVC


import json
from skimage import color
from skimage.feature import hog
#from sklearn import svm
from sklearn.metrics import classification_report,accuracy_score, recall_score
from subprocess import check_output

def plot_confusion_matrix(y_true, y_pred, classes,
                          normalize=False,
                          title=None,
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if not title:
        if normalize:
            title = 'Matriz de confusión'
        else:
            title = 'Matriz de confusión, sin normalización'

    # Compute confusion matrix

    cm = metrics.confusion_matrix(y_true, y_pred)
    # Only use the labels that appear in the data
    classes = unique_labels(y_true, y_pred)
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    fig, ax = plt.subplots()
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    # We want to show all ticks...

    ax.set(xticks=np.arange(cm.shape[1]),
           yticks=np.arange(cm.shape[0]),
           # ... and label them with the respective list entries
           xticklabels=labels, yticklabels=labels,
           title=title,
           ylabel='Etiqueta verdadera',
           xlabel='Etiqueta prevista')

    # Rotate the tick labels and set their alignment.

    plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
             rotation_mode="anchor")

    # Loop over data dimensions and create text annotations.

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], fmt),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")
    fig.tight_layout()
    return cm,ax

precision=metrics.accuracy_score(y_test,predicted_classes, normalize=True)*100

print("Accuracy:{0:.2f}%".format(precision))
cm,_=plot_confusion_matrix(y_test,predicted_classes,classes=nClasses,normalize=True,title="Matriz de confusión")
plt.show()
# Out:
# Accuracy:96.00%

# %%
model_out_desnet121.save("/content/drive/My Drive/source_dir/gradoma_final_desnet121.h5py")
# Out:
# INFO:tensorflow:Assets written to: /content/drive/My Drive/source_dir/gradoma_final_desnet121.h5py/assets
# /usr/local/lib/python3.7/dist-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# /usr/local/lib/python3.7/dist-packages/keras/saving/saved_model/layer_serialization.py:112: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   return generic_utils.serialize_keras_object(obj)

# %% [markdown]
# ***NUEVA PRUEBA InceptionResNetV2***

# %%
#preprocess_input = tf.keras.applications.InceptionResNetV2.preprocess_input
rescale = tf.keras.layers.experimental.preprocessing.Rescaling(1./127.5, offset= -1)
IMG_SIZE = (100, 100)
img_height=100
img_width=100

IMG_SHAPE = IMG_SIZE + (3,)
base_model = tf.keras.applications.InceptionResNetV2(input_shape=IMG_SHAPE,
                                               include_top=False,
                                               weights='imagenet')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_resnet_v2/inception_resnet_v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 219062272/219055592 [==============================] - 2s 0us/step
# 219070464/219055592 [==============================] - 2s 0us/step

# %%
base_model.trainable = False

base_model.summary()
for layer in base_model.layers:
           if layer.name == 'block5_conv1':
              break
           layer.trainable = False
# We add our classificator (top_model) to the last layer of the model
last = base_model.layers[-1].output
x = Flatten()(last)
x = Dense(1000, activation='relu', name='fc1')(x)
x = Dropout(0.3)(x)
x = Dense(5, activation='softmax', name='predictions')(x)
model_out_inceResv2 = Model(base_model.input, x)
#We compile the model
# Out:
# Model: "inception_resnet_v2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_5 (InputLayer)           [(None, 100, 100, 3  0           []
#                                 )]
#
#  conv2d_3 (Conv2D)              (None, 49, 49, 32)   864         ['input_5[0][0]']
#
#  batch_normalization (BatchNorm  (None, 49, 49, 32)  96          ['conv2d_3[0][0]']
#  alization)
#
#  activation (Activation)        (None, 49, 49, 32)   0           ['batch_normalization[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 47, 47, 32)   9216        ['activation[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 47, 47, 32)  96          ['conv2d_4[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 47, 47, 32)   0           ['batch_normalization_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 47, 47, 64)   18432       ['activation_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 47, 47, 64)  192         ['conv2d_5[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 47, 47, 64)   0           ['batch_normalization_2[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 23, 23, 64)  0           ['activation_2[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 23, 23, 80)   5120        ['max_pooling2d_3[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 23, 23, 80)  240         ['conv2d_6[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 23, 23, 80)   0           ['batch_normalization_3[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 21, 21, 192)  138240      ['activation_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 21, 21, 192)  576        ['conv2d_7[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 21, 21, 192)  0           ['batch_normalization_4[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 10, 10, 192)  0          ['activation_4[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 10, 10, 64)   12288       ['max_pooling2d_4[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 10, 10, 64)  192         ['conv2d_11[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 10, 10, 64)   0           ['batch_normalization_8[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 10, 10, 48)   9216        ['max_pooling2d_4[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 10, 10, 96)   55296       ['activation_8[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 10, 10, 48)  144         ['conv2d_9[0][0]']
#  rmalization)
#
#  batch_normalization_9 (BatchNo  (None, 10, 10, 96)  288         ['conv2d_12[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 10, 10, 48)   0           ['batch_normalization_6[0][0]']
#
#  activation_9 (Activation)      (None, 10, 10, 96)   0           ['batch_normalization_9[0][0]']
#
#  average_pooling2d (AveragePool  (None, 10, 10, 192)  0          ['max_pooling2d_4[0][0]']
#  ing2D)
#
#  conv2d_8 (Conv2D)              (None, 10, 10, 96)   18432       ['max_pooling2d_4[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 10, 10, 64)   76800       ['activation_6[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 10, 10, 96)   82944       ['activation_9[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 10, 10, 64)   12288       ['average_pooling2d[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 10, 10, 96)  288         ['conv2d_8[0][0]']
#  rmalization)
#
#  batch_normalization_7 (BatchNo  (None, 10, 10, 64)  192         ['conv2d_10[0][0]']
#  rmalization)
#
#  batch_normalization_10 (BatchN  (None, 10, 10, 96)  288         ['conv2d_13[0][0]']
#  ormalization)
#
#  batch_normalization_11 (BatchN  (None, 10, 10, 64)  192         ['conv2d_14[0][0]']
#  ormalization)
#
#  activation_5 (Activation)      (None, 10, 10, 96)   0           ['batch_normalization_5[0][0]']
#
#  activation_7 (Activation)      (None, 10, 10, 64)   0           ['batch_normalization_7[0][0]']
#
#  activation_10 (Activation)     (None, 10, 10, 96)   0           ['batch_normalization_10[0][0]']
#
#  activation_11 (Activation)     (None, 10, 10, 64)   0           ['batch_normalization_11[0][0]']
#
#  mixed_5b (Concatenate)         (None, 10, 10, 320)  0           ['activation_5[0][0]',
#                                                                   'activation_7[0][0]',
#                                                                   'activation_10[0][0]',
#                                                                   'activation_11[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 10, 10, 32)   10240       ['mixed_5b[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 10, 10, 32)  96          ['conv2d_18[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 10, 10, 32)   0           ['batch_normalization_15[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 10, 10, 32)   10240       ['mixed_5b[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 10, 10, 48)   13824       ['activation_15[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 10, 10, 32)  96          ['conv2d_16[0][0]']
#  ormalization)
#
#  batch_normalization_16 (BatchN  (None, 10, 10, 48)  144         ['conv2d_19[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 10, 10, 32)   0           ['batch_normalization_13[0][0]']
#
#  activation_16 (Activation)     (None, 10, 10, 48)   0           ['batch_normalization_16[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 10, 10, 32)   10240       ['mixed_5b[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 10, 10, 32)   9216        ['activation_13[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 10, 10, 64)   27648       ['activation_16[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 10, 10, 32)  96          ['conv2d_15[0][0]']
#  ormalization)
#
#  batch_normalization_14 (BatchN  (None, 10, 10, 32)  96          ['conv2d_17[0][0]']
#  ormalization)
#
#  batch_normalization_17 (BatchN  (None, 10, 10, 64)  192         ['conv2d_20[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 10, 10, 32)   0           ['batch_normalization_12[0][0]']
#
#  activation_14 (Activation)     (None, 10, 10, 32)   0           ['batch_normalization_14[0][0]']
#
#  activation_17 (Activation)     (None, 10, 10, 64)   0           ['batch_normalization_17[0][0]']
#
#  block35_1_mixed (Concatenate)  (None, 10, 10, 128)  0           ['activation_12[0][0]',
#                                                                   'activation_14[0][0]',
#                                                                   'activation_17[0][0]']
#
#  block35_1_conv (Conv2D)        (None, 10, 10, 320)  41280       ['block35_1_mixed[0][0]']
#
#  block35_1 (Lambda)             (None, 10, 10, 320)  0           ['mixed_5b[0][0]',
#                                                                   'block35_1_conv[0][0]']
#
#  block35_1_ac (Activation)      (None, 10, 10, 320)  0           ['block35_1[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 10, 10, 32)   10240       ['block35_1_ac[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 10, 10, 32)  96          ['conv2d_24[0][0]']
#  ormalization)
#
#  activation_21 (Activation)     (None, 10, 10, 32)   0           ['batch_normalization_21[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 10, 10, 32)   10240       ['block35_1_ac[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 10, 10, 48)   13824       ['activation_21[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 10, 10, 32)  96          ['conv2d_22[0][0]']
#  ormalization)
#
#  batch_normalization_22 (BatchN  (None, 10, 10, 48)  144         ['conv2d_25[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 10, 10, 32)   0           ['batch_normalization_19[0][0]']
#
#  activation_22 (Activation)     (None, 10, 10, 48)   0           ['batch_normalization_22[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 10, 10, 32)   10240       ['block35_1_ac[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 10, 10, 32)   9216        ['activation_19[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 10, 10, 64)   27648       ['activation_22[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 10, 10, 32)  96          ['conv2d_21[0][0]']
#  ormalization)
#
#  batch_normalization_20 (BatchN  (None, 10, 10, 32)  96          ['conv2d_23[0][0]']
#  ormalization)
#
#  batch_normalization_23 (BatchN  (None, 10, 10, 64)  192         ['conv2d_26[0][0]']
#  ormalization)
#
#  activation_18 (Activation)     (None, 10, 10, 32)   0           ['batch_normalization_18[0][0]']
#
#  activation_20 (Activation)     (None, 10, 10, 32)   0           ['batch_normalization_20[0][0]']
#
#  activation_23 (Activation)     (None, 10, 10, 64)   0           ['batch_normalization_23[0][0]']
#
#  block35_2_mixed (Concatenate)  (None, 10, 10, 128)  0           ['activation_18[0][0]',
#                                                                   'activation_20[0][0]',
#                                                                   'activation_23[0][0]']
#
#  block35_2_conv (Conv2D)        (None, 10, 10, 320)  41280       ['block35_2_mixed[0][0]']
#
#  block35_2 (Lambda)             (None, 10, 10, 320)  0           ['block35_1_ac[0][0]',
#                                                                   'block35_2_conv[0][0]']
#
#  block35_2_ac (Activation)      (None, 10, 10, 320)  0           ['block35_2[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 10, 10, 32)   10240       ['block35_2_ac[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 10, 10, 32)  96          ['conv2d_30[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 10, 10, 32)   0           ['batch_normalization_27[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 10, 10, 32)   10240       ['block35_2_ac[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 10, 10, 48)   13824       ['activation_27[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 10, 10, 32)  96          ['conv2d_28[0][0]']
#  ormalization)
#
#  batch_normalization_28 (BatchN  (None, 10, 10, 48)  144         ['conv2d_31[0][0]']
#  ormalization)
#
#  activation_25 (Activation)     (None, 10, 10, 32)   0           ['batch_normalization_25[0][0]']
#
#  activation_28 (Activation)     (None, 10, 10, 48)   0           ['batch_normalization_28[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 10, 10, 32)   10240       ['block35_2_ac[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 10, 10, 32)   9216        ['activation_25[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 10, 10, 64)   27648       ['activation_28[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 10, 10, 32)  96          ['conv2d_27[0][0]']
#  ormalization)
#
#  batch_normalization_26 (BatchN  (None, 10, 10, 32)  96          ['conv2d_29[0][0]']
#  ormalization)
#
#  batch_normalization_29 (BatchN  (None, 10, 10, 64)  192         ['conv2d_32[0][0]']
#  ormalization)
#
#  activation_24 (Activation)     (None, 10, 10, 32)   0           ['batch_normalization_24[0][0]']
#
#  activation_26 (Activation)     (None, 10, 10, 32)   0           ['batch_normalization_26[0][0]']
#
#  activation_29 (Activation)     (None, 10, 10, 64)   0           ['batch_normalization_29[0][0]']
#
#  block35_3_mixed (Concatenate)  (None, 10, 10, 128)  0           ['activation_24[0][0]',
#                                                                   'activation_26[0][0]',
#                                                                   'activation_29[0][0]']
#
#  block35_3_conv (Conv2D)        (None, 10, 10, 320)  41280       ['block35_3_mixed[0][0]']
#
#  block35_3 (Lambda)             (None, 10, 10, 320)  0           ['block35_2_ac[0][0]',
#                                                                   'block35_3_conv[0][0]']
#
#  block35_3_ac (Activation)      (None, 10, 10, 320)  0           ['block35_3[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 10, 10, 32)   10240       ['block35_3_ac[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 10, 10, 32)  96          ['conv2d_36[0][0]']
#  ormalization)
#
#  activation_33 (Activation)     (None, 10, 10, 32)   0           ['batch_normalization_33[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 10, 10, 32)   10240       ['block35_3_ac[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 10, 10, 48)   13824       ['activation_33[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 10, 10, 32)  96          ['conv2d_34[0][0]']
#  ormalization)
#
#  batch_normalization_34 (BatchN  (None, 10, 10, 48)  144         ['conv2d_37[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 10, 10, 32)   0           ['batch_normalization_31[0][0]']
#
#  activation_34 (Activation)     (None, 10, 10, 48)   0           ['batch_normalization_34[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 10, 10, 32)   10240       ['block35_3_ac[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 10, 10, 32)   9216        ['activation_31[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 10, 10, 64)   27648       ['activation_34[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 10, 10, 32)  96          ['conv2d_33[0][0]']
#  ormalization)
#
#  batch_normalization_32 (BatchN  (None, 10, 10, 32)  96          ['conv2d_35[0][0]']
#  ormalization)
#
#  batch_normalization_35 (BatchN  (None, 10, 10, 64)  192         ['conv2d_38[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 10, 10, 32)   0           ['batch_normalization_30[0][0]']
#
#  activation_32 (Activation)     (None, 10, 10, 32)   0           ['batch_normalization_32[0][0]']
#
#  activation_35 (Activation)     (None, 10, 10, 64)   0           ['batch_normalization_35[0][0]']
#
#  block35_4_mixed (Concatenate)  (None, 10, 10, 128)  0           ['activation_30[0][0]',
#                                                                   'activation_32[0][0]',
#                                                                   'activation_35[0][0]']
#
#  block35_4_conv (Conv2D)        (None, 10, 10, 320)  41280       ['block35_4_mixed[0][0]']
#
#  block35_4 (Lambda)             (None, 10, 10, 320)  0           ['block35_3_ac[0][0]',
#                                                                   'block35_4_conv[0][0]']
#
#  block35_4_ac (Activation)      (None, 10, 10, 320)  0           ['block35_4[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 10, 10, 32)   10240       ['block35_4_ac[0][0]']
#
#  batch_normalization_39 (BatchN  (None, 10, 10, 32)  96          ['conv2d_42[0][0]']
#  ormalization)
#
#  activation_39 (Activation)     (None, 10, 10, 32)   0           ['batch_normalization_39[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 10, 10, 32)   10240       ['block35_4_ac[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 10, 10, 48)   13824       ['activation_39[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 10, 10, 32)  96          ['conv2d_40[0][0]']
#  ormalization)
#
#  batch_normalization_40 (BatchN  (None, 10, 10, 48)  144         ['conv2d_43[0][0]']
#  ormalization)
#
#  activation_37 (Activation)     (None, 10, 10, 32)   0           ['batch_normalization_37[0][0]']
#
#  activation_40 (Activation)     (None, 10, 10, 48)   0           ['batch_normalization_40[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 10, 10, 32)   10240       ['block35_4_ac[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 10, 10, 32)   9216        ['activation_37[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 10, 10, 64)   27648       ['activation_40[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 10, 10, 32)  96          ['conv2d_39[0][0]']
#  ormalization)
#
#  batch_normalization_38 (BatchN  (None, 10, 10, 32)  96          ['conv2d_41[0][0]']
#  ormalization)
#
#  batch_normalization_41 (BatchN  (None, 10, 10, 64)  192         ['conv2d_44[0][0]']
#  ormalization)
#
#  activation_36 (Activation)     (None, 10, 10, 32)   0           ['batch_normalization_36[0][0]']
#
#  activation_38 (Activation)     (None, 10, 10, 32)   0           ['batch_normalization_38[0][0]']
#
#  activation_41 (Activation)     (None, 10, 10, 64)   0           ['batch_normalization_41[0][0]']
#
#  block35_5_mixed (Concatenate)  (None, 10, 10, 128)  0           ['activation_36[0][0]',
#                                                                   'activation_38[0][0]',
#                                                                   'activation_41[0][0]']
#
#  block35_5_conv (Conv2D)        (None, 10, 10, 320)  41280       ['block35_5_mixed[0][0]']
#
#  block35_5 (Lambda)             (None, 10, 10, 320)  0           ['block35_4_ac[0][0]',
#                                                                   'block35_5_conv[0][0]']
#
#  block35_5_ac (Activation)      (None, 10, 10, 320)  0           ['block35_5[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 10, 10, 32)   10240       ['block35_5_ac[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 10, 10, 32)  96          ['conv2d_48[0][0]']
#  ormalization)
#
#  activation_45 (Activation)     (None, 10, 10, 32)   0           ['batch_normalization_45[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 10, 10, 32)   10240       ['block35_5_ac[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 10, 10, 48)   13824       ['activation_45[0][0]']
#
#  batch_normalization_43 (BatchN  (None, 10, 10, 32)  96          ['conv2d_46[0][0]']
#  ormalization)
#
#  batch_normalization_46 (BatchN  (None, 10, 10, 48)  144         ['conv2d_49[0][0]']
#  ormalization)
#
#  activation_43 (Activation)     (None, 10, 10, 32)   0           ['batch_normalization_43[0][0]']
#
#  activation_46 (Activation)     (None, 10, 10, 48)   0           ['batch_normalization_46[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 10, 10, 32)   10240       ['block35_5_ac[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 10, 10, 32)   9216        ['activation_43[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 10, 10, 64)   27648       ['activation_46[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 10, 10, 32)  96          ['conv2d_45[0][0]']
#  ormalization)
#
#  batch_normalization_44 (BatchN  (None, 10, 10, 32)  96          ['conv2d_47[0][0]']
#  ormalization)
#
#  batch_normalization_47 (BatchN  (None, 10, 10, 64)  192         ['conv2d_50[0][0]']
#  ormalization)
#
#  activation_42 (Activation)     (None, 10, 10, 32)   0           ['batch_normalization_42[0][0]']
#
#  activation_44 (Activation)     (None, 10, 10, 32)   0           ['batch_normalization_44[0][0]']
#
#  activation_47 (Activation)     (None, 10, 10, 64)   0           ['batch_normalization_47[0][0]']
#
#  block35_6_mixed (Concatenate)  (None, 10, 10, 128)  0           ['activation_42[0][0]',
#                                                                   'activation_44[0][0]',
#                                                                   'activation_47[0][0]']
#
#  block35_6_conv (Conv2D)        (None, 10, 10, 320)  41280       ['block35_6_mixed[0][0]']
#
#  block35_6 (Lambda)             (None, 10, 10, 320)  0           ['block35_5_ac[0][0]',
#                                                                   'block35_6_conv[0][0]']
#
#  block35_6_ac (Activation)      (None, 10, 10, 320)  0           ['block35_6[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 10, 10, 32)   10240       ['block35_6_ac[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 10, 10, 32)  96          ['conv2d_54[0][0]']
#  ormalization)
#
#  activation_51 (Activation)     (None, 10, 10, 32)   0           ['batch_normalization_51[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 10, 10, 32)   10240       ['block35_6_ac[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 10, 10, 48)   13824       ['activation_51[0][0]']
#
#  batch_normalization_49 (BatchN  (None, 10, 10, 32)  96          ['conv2d_52[0][0]']
#  ormalization)
#
#  batch_normalization_52 (BatchN  (None, 10, 10, 48)  144         ['conv2d_55[0][0]']
#  ormalization)
#
#  activation_49 (Activation)     (None, 10, 10, 32)   0           ['batch_normalization_49[0][0]']
#
#  activation_52 (Activation)     (None, 10, 10, 48)   0           ['batch_normalization_52[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 10, 10, 32)   10240       ['block35_6_ac[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 10, 10, 32)   9216        ['activation_49[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 10, 10, 64)   27648       ['activation_52[0][0]']
#
#  batch_normalization_48 (BatchN  (None, 10, 10, 32)  96          ['conv2d_51[0][0]']
#  ormalization)
#
#  batch_normalization_50 (BatchN  (None, 10, 10, 32)  96          ['conv2d_53[0][0]']
#  ormalization)
#
#  batch_normalization_53 (BatchN  (None, 10, 10, 64)  192         ['conv2d_56[0][0]']
#  ormalization)
#
#  activation_48 (Activation)     (None, 10, 10, 32)   0           ['batch_normalization_48[0][0]']
#
#  activation_50 (Activation)     (None, 10, 10, 32)   0           ['batch_normalization_50[0][0]']
#
#  activation_53 (Activation)     (None, 10, 10, 64)   0           ['batch_normalization_53[0][0]']
#
#  block35_7_mixed (Concatenate)  (None, 10, 10, 128)  0           ['activation_48[0][0]',
#                                                                   'activation_50[0][0]',
#                                                                   'activation_53[0][0]']
#
#  block35_7_conv (Conv2D)        (None, 10, 10, 320)  41280       ['block35_7_mixed[0][0]']
#
#  block35_7 (Lambda)             (None, 10, 10, 320)  0           ['block35_6_ac[0][0]',
#                                                                   'block35_7_conv[0][0]']
#
#  block35_7_ac (Activation)      (None, 10, 10, 320)  0           ['block35_7[0][0]']
#
#  conv2d_60 (Conv2D)             (None, 10, 10, 32)   10240       ['block35_7_ac[0][0]']
#
#  batch_normalization_57 (BatchN  (None, 10, 10, 32)  96          ['conv2d_60[0][0]']
#  ormalization)
#
#  activation_57 (Activation)     (None, 10, 10, 32)   0           ['batch_normalization_57[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 10, 10, 32)   10240       ['block35_7_ac[0][0]']
#
#  conv2d_61 (Conv2D)             (None, 10, 10, 48)   13824       ['activation_57[0][0]']
#
# ...
#
#  conv2d_191 (Conv2D)            (None, 1, 1, 192)    399360      ['block8_6_ac[0][0]']
#
#  batch_normalization_188 (Batch  (None, 1, 1, 192)   576         ['conv2d_191[0][0]']
#  Normalization)
#
#  activation_188 (Activation)    (None, 1, 1, 192)    0           ['batch_normalization_188[0][0]']
#
#  conv2d_192 (Conv2D)            (None, 1, 1, 224)    129024      ['activation_188[0][0]']
#
#  batch_normalization_189 (Batch  (None, 1, 1, 224)   672         ['conv2d_192[0][0]']
#  Normalization)
#
#  activation_189 (Activation)    (None, 1, 1, 224)    0           ['batch_normalization_189[0][0]']
#
#  conv2d_190 (Conv2D)            (None, 1, 1, 192)    399360      ['block8_6_ac[0][0]']
#
#  conv2d_193 (Conv2D)            (None, 1, 1, 256)    172032      ['activation_189[0][0]']
#
#  batch_normalization_187 (Batch  (None, 1, 1, 192)   576         ['conv2d_190[0][0]']
#  Normalization)
#
#  batch_normalization_190 (Batch  (None, 1, 1, 256)   768         ['conv2d_193[0][0]']
#  Normalization)
#
#  activation_187 (Activation)    (None, 1, 1, 192)    0           ['batch_normalization_187[0][0]']
#
#  activation_190 (Activation)    (None, 1, 1, 256)    0           ['batch_normalization_190[0][0]']
#
#  block8_7_mixed (Concatenate)   (None, 1, 1, 448)    0           ['activation_187[0][0]',
#                                                                   'activation_190[0][0]']
#
#  block8_7_conv (Conv2D)         (None, 1, 1, 2080)   933920      ['block8_7_mixed[0][0]']
#
#  block8_7 (Lambda)              (None, 1, 1, 2080)   0           ['block8_6_ac[0][0]',
#                                                                   'block8_7_conv[0][0]']
#
#  block8_7_ac (Activation)       (None, 1, 1, 2080)   0           ['block8_7[0][0]']
#
#  conv2d_195 (Conv2D)            (None, 1, 1, 192)    399360      ['block8_7_ac[0][0]']
#
#  batch_normalization_192 (Batch  (None, 1, 1, 192)   576         ['conv2d_195[0][0]']
#  Normalization)
#
#  activation_192 (Activation)    (None, 1, 1, 192)    0           ['batch_normalization_192[0][0]']
#
#  conv2d_196 (Conv2D)            (None, 1, 1, 224)    129024      ['activation_192[0][0]']
#
#  batch_normalization_193 (Batch  (None, 1, 1, 224)   672         ['conv2d_196[0][0]']
#  Normalization)
#
#  activation_193 (Activation)    (None, 1, 1, 224)    0           ['batch_normalization_193[0][0]']
#
#  conv2d_194 (Conv2D)            (None, 1, 1, 192)    399360      ['block8_7_ac[0][0]']
#
#  conv2d_197 (Conv2D)            (None, 1, 1, 256)    172032      ['activation_193[0][0]']
#
#  batch_normalization_191 (Batch  (None, 1, 1, 192)   576         ['conv2d_194[0][0]']
#  Normalization)
#
#  batch_normalization_194 (Batch  (None, 1, 1, 256)   768         ['conv2d_197[0][0]']
#  Normalization)
#
#  activation_191 (Activation)    (None, 1, 1, 192)    0           ['batch_normalization_191[0][0]']
#
#  activation_194 (Activation)    (None, 1, 1, 256)    0           ['batch_normalization_194[0][0]']
#
#  block8_8_mixed (Concatenate)   (None, 1, 1, 448)    0           ['activation_191[0][0]',
#                                                                   'activation_194[0][0]']
#
#  block8_8_conv (Conv2D)         (None, 1, 1, 2080)   933920      ['block8_8_mixed[0][0]']
#
#  block8_8 (Lambda)              (None, 1, 1, 2080)   0           ['block8_7_ac[0][0]',
#                                                                   'block8_8_conv[0][0]']
#
#  block8_8_ac (Activation)       (None, 1, 1, 2080)   0           ['block8_8[0][0]']
#
#  conv2d_199 (Conv2D)            (None, 1, 1, 192)    399360      ['block8_8_ac[0][0]']
#
#  batch_normalization_196 (Batch  (None, 1, 1, 192)   576         ['conv2d_199[0][0]']
#  Normalization)
#
#  activation_196 (Activation)    (None, 1, 1, 192)    0           ['batch_normalization_196[0][0]']
#
#  conv2d_200 (Conv2D)            (None, 1, 1, 224)    129024      ['activation_196[0][0]']
#
#  batch_normalization_197 (Batch  (None, 1, 1, 224)   672         ['conv2d_200[0][0]']
#  Normalization)
#
#  activation_197 (Activation)    (None, 1, 1, 224)    0           ['batch_normalization_197[0][0]']
#
#  conv2d_198 (Conv2D)            (None, 1, 1, 192)    399360      ['block8_8_ac[0][0]']
#
#  conv2d_201 (Conv2D)            (None, 1, 1, 256)    172032      ['activation_197[0][0]']
#
#  batch_normalization_195 (Batch  (None, 1, 1, 192)   576         ['conv2d_198[0][0]']
#  Normalization)
#
#  batch_normalization_198 (Batch  (None, 1, 1, 256)   768         ['conv2d_201[0][0]']
#  Normalization)
#
#  activation_195 (Activation)    (None, 1, 1, 192)    0           ['batch_normalization_195[0][0]']
#
#  activation_198 (Activation)    (None, 1, 1, 256)    0           ['batch_normalization_198[0][0]']
#
#  block8_9_mixed (Concatenate)   (None, 1, 1, 448)    0           ['activation_195[0][0]',
#                                                                   'activation_198[0][0]']
#
#  block8_9_conv (Conv2D)         (None, 1, 1, 2080)   933920      ['block8_9_mixed[0][0]']
#
#  block8_9 (Lambda)              (None, 1, 1, 2080)   0           ['block8_8_ac[0][0]',
#                                                                   'block8_9_conv[0][0]']
#
#  block8_9_ac (Activation)       (None, 1, 1, 2080)   0           ['block8_9[0][0]']
#
#  conv2d_203 (Conv2D)            (None, 1, 1, 192)    399360      ['block8_9_ac[0][0]']
#
#  batch_normalization_200 (Batch  (None, 1, 1, 192)   576         ['conv2d_203[0][0]']
#  Normalization)
#
#  activation_200 (Activation)    (None, 1, 1, 192)    0           ['batch_normalization_200[0][0]']
#
#  conv2d_204 (Conv2D)            (None, 1, 1, 224)    129024      ['activation_200[0][0]']
#
#  batch_normalization_201 (Batch  (None, 1, 1, 224)   672         ['conv2d_204[0][0]']
#  Normalization)
#
#  activation_201 (Activation)    (None, 1, 1, 224)    0           ['batch_normalization_201[0][0]']
#
#  conv2d_202 (Conv2D)            (None, 1, 1, 192)    399360      ['block8_9_ac[0][0]']
#
#  conv2d_205 (Conv2D)            (None, 1, 1, 256)    172032      ['activation_201[0][0]']
#
#  batch_normalization_199 (Batch  (None, 1, 1, 192)   576         ['conv2d_202[0][0]']
#  Normalization)
#
#  batch_normalization_202 (Batch  (None, 1, 1, 256)   768         ['conv2d_205[0][0]']
#  Normalization)
#
#  activation_199 (Activation)    (None, 1, 1, 192)    0           ['batch_normalization_199[0][0]']
#
#  activation_202 (Activation)    (None, 1, 1, 256)    0           ['batch_normalization_202[0][0]']
#
#  block8_10_mixed (Concatenate)  (None, 1, 1, 448)    0           ['activation_199[0][0]',
#                                                                   'activation_202[0][0]']
#
#  block8_10_conv (Conv2D)        (None, 1, 1, 2080)   933920      ['block8_10_mixed[0][0]']
#
#  block8_10 (Lambda)             (None, 1, 1, 2080)   0           ['block8_9_ac[0][0]',
#                                                                   'block8_10_conv[0][0]']
#
#  conv_7b (Conv2D)               (None, 1, 1, 1536)   3194880     ['block8_10[0][0]']
#
#  conv_7b_bn (BatchNormalization  (None, 1, 1, 1536)  4608        ['conv_7b[0][0]']
#  )
#
#  conv_7b_ac (Activation)        (None, 1, 1, 1536)   0           ['conv_7b_bn[0][0]']
#
# ==================================================================================================
# Total params: 54,336,736
# Trainable params: 0
# Non-trainable params: 54,336,736
# __________________________________________________________________________________________________

# %%
model_out_inceResv2.compile(loss=keras.losses.categorical_crossentropy, optimizer=tf.keras.optimizers.Adam(learning_rate=INIT_LR, decay=INIT_LR / 100),metrics=['accuracy'])
model_out_inceResv2.summary()
callback = tf.keras.callbacks.EarlyStopping(monitor='loss', min_delta=0.0001, patience=3)

grado_train_dropout = model_out_inceResv2.fit(train_x, train_label, batch_size=batch_size,epochs=epochs,verbose=1,validation_data=(valid_X, valid_label),callbacks=[callback])
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_5 (InputLayer)           [(None, 100, 100, 3  0           []
#                                 )]
#
#  conv2d_3 (Conv2D)              (None, 49, 49, 32)   864         ['input_5[0][0]']
#
#  batch_normalization (BatchNorm  (None, 49, 49, 32)  96          ['conv2d_3[0][0]']
#  alization)
#
#  activation (Activation)        (None, 49, 49, 32)   0           ['batch_normalization[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 47, 47, 32)   9216        ['activation[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 47, 47, 32)  96          ['conv2d_4[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 47, 47, 32)   0           ['batch_normalization_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 47, 47, 64)   18432       ['activation_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 47, 47, 64)  192         ['conv2d_5[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 47, 47, 64)   0           ['batch_normalization_2[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 23, 23, 64)  0           ['activation_2[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 23, 23, 80)   5120        ['max_pooling2d_3[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 23, 23, 80)  240         ['conv2d_6[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 23, 23, 80)   0           ['batch_normalization_3[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 21, 21, 192)  138240      ['activation_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 21, 21, 192)  576        ['conv2d_7[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 21, 21, 192)  0           ['batch_normalization_4[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 10, 10, 192)  0          ['activation_4[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 10, 10, 64)   12288       ['max_pooling2d_4[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 10, 10, 64)  192         ['conv2d_11[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 10, 10, 64)   0           ['batch_normalization_8[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 10, 10, 48)   9216        ['max_pooling2d_4[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 10, 10, 96)   55296       ['activation_8[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 10, 10, 48)  144         ['conv2d_9[0][0]']
#  rmalization)
#
#  batch_normalization_9 (BatchNo  (None, 10, 10, 96)  288         ['conv2d_12[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 10, 10, 48)   0           ['batch_normalization_6[0][0]']
#
#  activation_9 (Activation)      (None, 10, 10, 96)   0           ['batch_normalization_9[0][0]']
#
#  average_pooling2d (AveragePool  (None, 10, 10, 192)  0          ['max_pooling2d_4[0][0]']
#  ing2D)
#
#  conv2d_8 (Conv2D)              (None, 10, 10, 96)   18432       ['max_pooling2d_4[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 10, 10, 64)   76800       ['activation_6[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 10, 10, 96)   82944       ['activation_9[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 10, 10, 64)   12288       ['average_pooling2d[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 10, 10, 96)  288         ['conv2d_8[0][0]']
#  rmalization)
#
#  batch_normalization_7 (BatchNo  (None, 10, 10, 64)  192         ['conv2d_10[0][0]']
#  rmalization)
#
#  batch_normalization_10 (BatchN  (None, 10, 10, 96)  288         ['conv2d_13[0][0]']
#  ormalization)
#
#  batch_normalization_11 (BatchN  (None, 10, 10, 64)  192         ['conv2d_14[0][0]']
#  ormalization)
#
#  activation_5 (Activation)      (None, 10, 10, 96)   0           ['batch_normalization_5[0][0]']
#
#  activation_7 (Activation)      (None, 10, 10, 64)   0           ['batch_normalization_7[0][0]']
#
#  activation_10 (Activation)     (None, 10, 10, 96)   0           ['batch_normalization_10[0][0]']
#
#  activation_11 (Activation)     (None, 10, 10, 64)   0           ['batch_normalization_11[0][0]']
#
#  mixed_5b (Concatenate)         (None, 10, 10, 320)  0           ['activation_5[0][0]',
#                                                                   'activation_7[0][0]',
#                                                                   'activation_10[0][0]',
#                                                                   'activation_11[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 10, 10, 32)   10240       ['mixed_5b[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 10, 10, 32)  96          ['conv2d_18[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 10, 10, 32)   0           ['batch_normalization_15[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 10, 10, 32)   10240       ['mixed_5b[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 10, 10, 48)   13824       ['activation_15[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 10, 10, 32)  96          ['conv2d_16[0][0]']
#  ormalization)
#
#  batch_normalization_16 (BatchN  (None, 10, 10, 48)  144         ['conv2d_19[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 10, 10, 32)   0           ['batch_normalization_13[0][0]']
#
#  activation_16 (Activation)     (None, 10, 10, 48)   0           ['batch_normalization_16[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 10, 10, 32)   10240       ['mixed_5b[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 10, 10, 32)   9216        ['activation_13[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 10, 10, 64)   27648       ['activation_16[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 10, 10, 32)  96          ['conv2d_15[0][0]']
#  ormalization)
#
#  batch_normalization_14 (BatchN  (None, 10, 10, 32)  96          ['conv2d_17[0][0]']
#  ormalization)
#
#  batch_normalization_17 (BatchN  (None, 10, 10, 64)  192         ['conv2d_20[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 10, 10, 32)   0           ['batch_normalization_12[0][0]']
#
#  activation_14 (Activation)     (None, 10, 10, 32)   0           ['batch_normalization_14[0][0]']
#
#  activation_17 (Activation)     (None, 10, 10, 64)   0           ['batch_normalization_17[0][0]']
#
#  block35_1_mixed (Concatenate)  (None, 10, 10, 128)  0           ['activation_12[0][0]',
#                                                                   'activation_14[0][0]',
#                                                                   'activation_17[0][0]']
#
#  block35_1_conv (Conv2D)        (None, 10, 10, 320)  41280       ['block35_1_mixed[0][0]']
#
#  block35_1 (Lambda)             (None, 10, 10, 320)  0           ['mixed_5b[0][0]',
#                                                                   'block35_1_conv[0][0]']
#
#  block35_1_ac (Activation)      (None, 10, 10, 320)  0           ['block35_1[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 10, 10, 32)   10240       ['block35_1_ac[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 10, 10, 32)  96          ['conv2d_24[0][0]']
#  ormalization)
#
#  activation_21 (Activation)     (None, 10, 10, 32)   0           ['batch_normalization_21[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 10, 10, 32)   10240       ['block35_1_ac[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 10, 10, 48)   13824       ['activation_21[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 10, 10, 32)  96          ['conv2d_22[0][0]']
#  ormalization)
#
#  batch_normalization_22 (BatchN  (None, 10, 10, 48)  144         ['conv2d_25[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 10, 10, 32)   0           ['batch_normalization_19[0][0]']
#
#  activation_22 (Activation)     (None, 10, 10, 48)   0           ['batch_normalization_22[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 10, 10, 32)   10240       ['block35_1_ac[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 10, 10, 32)   9216        ['activation_19[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 10, 10, 64)   27648       ['activation_22[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 10, 10, 32)  96          ['conv2d_21[0][0]']
#  ormalization)
#
#  batch_normalization_20 (BatchN  (None, 10, 10, 32)  96          ['conv2d_23[0][0]']
#  ormalization)
#
#  batch_normalization_23 (BatchN  (None, 10, 10, 64)  192         ['conv2d_26[0][0]']
#  ormalization)
#
#  activation_18 (Activation)     (None, 10, 10, 32)   0           ['batch_normalization_18[0][0]']
#
#  activation_20 (Activation)     (None, 10, 10, 32)   0           ['batch_normalization_20[0][0]']
#
#  activation_23 (Activation)     (None, 10, 10, 64)   0           ['batch_normalization_23[0][0]']
#
#  block35_2_mixed (Concatenate)  (None, 10, 10, 128)  0           ['activation_18[0][0]',
#                                                                   'activation_20[0][0]',
#                                                                   'activation_23[0][0]']
#
#  block35_2_conv (Conv2D)        (None, 10, 10, 320)  41280       ['block35_2_mixed[0][0]']
#
#  block35_2 (Lambda)             (None, 10, 10, 320)  0           ['block35_1_ac[0][0]',
#                                                                   'block35_2_conv[0][0]']
#
#  block35_2_ac (Activation)      (None, 10, 10, 320)  0           ['block35_2[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 10, 10, 32)   10240       ['block35_2_ac[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 10, 10, 32)  96          ['conv2d_30[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 10, 10, 32)   0           ['batch_normalization_27[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 10, 10, 32)   10240       ['block35_2_ac[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 10, 10, 48)   13824       ['activation_27[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 10, 10, 32)  96          ['conv2d_28[0][0]']
#  ormalization)
#
#  batch_normalization_28 (BatchN  (None, 10, 10, 48)  144         ['conv2d_31[0][0]']
#  ormalization)
#
#  activation_25 (Activation)     (None, 10, 10, 32)   0           ['batch_normalization_25[0][0]']
#
#  activation_28 (Activation)     (None, 10, 10, 48)   0           ['batch_normalization_28[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 10, 10, 32)   10240       ['block35_2_ac[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 10, 10, 32)   9216        ['activation_25[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 10, 10, 64)   27648       ['activation_28[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 10, 10, 32)  96          ['conv2d_27[0][0]']
#  ormalization)
#
#  batch_normalization_26 (BatchN  (None, 10, 10, 32)  96          ['conv2d_29[0][0]']
#  ormalization)
#
#  batch_normalization_29 (BatchN  (None, 10, 10, 64)  192         ['conv2d_32[0][0]']
#  ormalization)
#
#  activation_24 (Activation)     (None, 10, 10, 32)   0           ['batch_normalization_24[0][0]']
#
#  activation_26 (Activation)     (None, 10, 10, 32)   0           ['batch_normalization_26[0][0]']
#
#  activation_29 (Activation)     (None, 10, 10, 64)   0           ['batch_normalization_29[0][0]']
#
#  block35_3_mixed (Concatenate)  (None, 10, 10, 128)  0           ['activation_24[0][0]',
#                                                                   'activation_26[0][0]',
#                                                                   'activation_29[0][0]']
#
#  block35_3_conv (Conv2D)        (None, 10, 10, 320)  41280       ['block35_3_mixed[0][0]']
#
#  block35_3 (Lambda)             (None, 10, 10, 320)  0           ['block35_2_ac[0][0]',
#                                                                   'block35_3_conv[0][0]']
#
#  block35_3_ac (Activation)      (None, 10, 10, 320)  0           ['block35_3[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 10, 10, 32)   10240       ['block35_3_ac[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 10, 10, 32)  96          ['conv2d_36[0][0]']
#  ormalization)
#
#  activation_33 (Activation)     (None, 10, 10, 32)   0           ['batch_normalization_33[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 10, 10, 32)   10240       ['block35_3_ac[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 10, 10, 48)   13824       ['activation_33[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 10, 10, 32)  96          ['conv2d_34[0][0]']
#  ormalization)
#
#  batch_normalization_34 (BatchN  (None, 10, 10, 48)  144         ['conv2d_37[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 10, 10, 32)   0           ['batch_normalization_31[0][0]']
#
#  activation_34 (Activation)     (None, 10, 10, 48)   0           ['batch_normalization_34[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 10, 10, 32)   10240       ['block35_3_ac[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 10, 10, 32)   9216        ['activation_31[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 10, 10, 64)   27648       ['activation_34[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 10, 10, 32)  96          ['conv2d_33[0][0]']
#  ormalization)
#
#  batch_normalization_32 (BatchN  (None, 10, 10, 32)  96          ['conv2d_35[0][0]']
#  ormalization)
#
#  batch_normalization_35 (BatchN  (None, 10, 10, 64)  192         ['conv2d_38[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 10, 10, 32)   0           ['batch_normalization_30[0][0]']
#
#  activation_32 (Activation)     (None, 10, 10, 32)   0           ['batch_normalization_32[0][0]']
#
#  activation_35 (Activation)     (None, 10, 10, 64)   0           ['batch_normalization_35[0][0]']
#
#  block35_4_mixed (Concatenate)  (None, 10, 10, 128)  0           ['activation_30[0][0]',
#                                                                   'activation_32[0][0]',
#                                                                   'activation_35[0][0]']
#
#  block35_4_conv (Conv2D)        (None, 10, 10, 320)  41280       ['block35_4_mixed[0][0]']
#
#  block35_4 (Lambda)             (None, 10, 10, 320)  0           ['block35_3_ac[0][0]',
#                                                                   'block35_4_conv[0][0]']
#
#  block35_4_ac (Activation)      (None, 10, 10, 320)  0           ['block35_4[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 10, 10, 32)   10240       ['block35_4_ac[0][0]']
#
#  batch_normalization_39 (BatchN  (None, 10, 10, 32)  96          ['conv2d_42[0][0]']
#  ormalization)
#
#  activation_39 (Activation)     (None, 10, 10, 32)   0           ['batch_normalization_39[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 10, 10, 32)   10240       ['block35_4_ac[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 10, 10, 48)   13824       ['activation_39[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 10, 10, 32)  96          ['conv2d_40[0][0]']
#  ormalization)
#
#  batch_normalization_40 (BatchN  (None, 10, 10, 48)  144         ['conv2d_43[0][0]']
#  ormalization)
#
#  activation_37 (Activation)     (None, 10, 10, 32)   0           ['batch_normalization_37[0][0]']
#
#  activation_40 (Activation)     (None, 10, 10, 48)   0           ['batch_normalization_40[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 10, 10, 32)   10240       ['block35_4_ac[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 10, 10, 32)   9216        ['activation_37[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 10, 10, 64)   27648       ['activation_40[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 10, 10, 32)  96          ['conv2d_39[0][0]']
#  ormalization)
#
#  batch_normalization_38 (BatchN  (None, 10, 10, 32)  96          ['conv2d_41[0][0]']
#  ormalization)
#
#  batch_normalization_41 (BatchN  (None, 10, 10, 64)  192         ['conv2d_44[0][0]']
#  ormalization)
#
#  activation_36 (Activation)     (None, 10, 10, 32)   0           ['batch_normalization_36[0][0]']
#
#  activation_38 (Activation)     (None, 10, 10, 32)   0           ['batch_normalization_38[0][0]']
#
#  activation_41 (Activation)     (None, 10, 10, 64)   0           ['batch_normalization_41[0][0]']
#
#  block35_5_mixed (Concatenate)  (None, 10, 10, 128)  0           ['activation_36[0][0]',
#                                                                   'activation_38[0][0]',
#                                                                   'activation_41[0][0]']
#
#  block35_5_conv (Conv2D)        (None, 10, 10, 320)  41280       ['block35_5_mixed[0][0]']
#
#  block35_5 (Lambda)             (None, 10, 10, 320)  0           ['block35_4_ac[0][0]',
#                                                                   'block35_5_conv[0][0]']
#
#  block35_5_ac (Activation)      (None, 10, 10, 320)  0           ['block35_5[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 10, 10, 32)   10240       ['block35_5_ac[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 10, 10, 32)  96          ['conv2d_48[0][0]']
#  ormalization)
#
#  activation_45 (Activation)     (None, 10, 10, 32)   0           ['batch_normalization_45[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 10, 10, 32)   10240       ['block35_5_ac[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 10, 10, 48)   13824       ['activation_45[0][0]']
#
#  batch_normalization_43 (BatchN  (None, 10, 10, 32)  96          ['conv2d_46[0][0]']
#  ormalization)
#
#  batch_normalization_46 (BatchN  (None, 10, 10, 48)  144         ['conv2d_49[0][0]']
#  ormalization)
#
#  activation_43 (Activation)     (None, 10, 10, 32)   0           ['batch_normalization_43[0][0]']
#
#  activation_46 (Activation)     (None, 10, 10, 48)   0           ['batch_normalization_46[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 10, 10, 32)   10240       ['block35_5_ac[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 10, 10, 32)   9216        ['activation_43[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 10, 10, 64)   27648       ['activation_46[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 10, 10, 32)  96          ['conv2d_45[0][0]']
#  ormalization)
#
#  batch_normalization_44 (BatchN  (None, 10, 10, 32)  96          ['conv2d_47[0][0]']
#  ormalization)
#
#  batch_normalization_47 (BatchN  (None, 10, 10, 64)  192         ['conv2d_50[0][0]']
#  ormalization)
#
#  activation_42 (Activation)     (None, 10, 10, 32)   0           ['batch_normalization_42[0][0]']
#
#  activation_44 (Activation)     (None, 10, 10, 32)   0           ['batch_normalization_44[0][0]']
#
#  activation_47 (Activation)     (None, 10, 10, 64)   0           ['batch_normalization_47[0][0]']
#
#  block35_6_mixed (Concatenate)  (None, 10, 10, 128)  0           ['activation_42[0][0]',
#                                                                   'activation_44[0][0]',
#                                                                   'activation_47[0][0]']
#
#  block35_6_conv (Conv2D)        (None, 10, 10, 320)  41280       ['block35_6_mixed[0][0]']
#
#  block35_6 (Lambda)             (None, 10, 10, 320)  0           ['block35_5_ac[0][0]',
#                                                                   'block35_6_conv[0][0]']
#
#  block35_6_ac (Activation)      (None, 10, 10, 320)  0           ['block35_6[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 10, 10, 32)   10240       ['block35_6_ac[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 10, 10, 32)  96          ['conv2d_54[0][0]']
#  ormalization)
#
#  activation_51 (Activation)     (None, 10, 10, 32)   0           ['batch_normalization_51[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 10, 10, 32)   10240       ['block35_6_ac[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 10, 10, 48)   13824       ['activation_51[0][0]']
#
#  batch_normalization_49 (BatchN  (None, 10, 10, 32)  96          ['conv2d_52[0][0]']
#  ormalization)
#
#  batch_normalization_52 (BatchN  (None, 10, 10, 48)  144         ['conv2d_55[0][0]']
#  ormalization)
#
#  activation_49 (Activation)     (None, 10, 10, 32)   0           ['batch_normalization_49[0][0]']
#
#  activation_52 (Activation)     (None, 10, 10, 48)   0           ['batch_normalization_52[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 10, 10, 32)   10240       ['block35_6_ac[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 10, 10, 32)   9216        ['activation_49[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 10, 10, 64)   27648       ['activation_52[0][0]']
#
#  batch_normalization_48 (BatchN  (None, 10, 10, 32)  96          ['conv2d_51[0][0]']
#  ormalization)
#
#  batch_normalization_50 (BatchN  (None, 10, 10, 32)  96          ['conv2d_53[0][0]']
#  ormalization)
#
#  batch_normalization_53 (BatchN  (None, 10, 10, 64)  192         ['conv2d_56[0][0]']
#  ormalization)
#
#  activation_48 (Activation)     (None, 10, 10, 32)   0           ['batch_normalization_48[0][0]']
#
#  activation_50 (Activation)     (None, 10, 10, 32)   0           ['batch_normalization_50[0][0]']
#
#  activation_53 (Activation)     (None, 10, 10, 64)   0           ['batch_normalization_53[0][0]']
#
#  block35_7_mixed (Concatenate)  (None, 10, 10, 128)  0           ['activation_48[0][0]',
#                                                                   'activation_50[0][0]',
#                                                                   'activation_53[0][0]']
#
#  block35_7_conv (Conv2D)        (None, 10, 10, 320)  41280       ['block35_7_mixed[0][0]']
#
#  block35_7 (Lambda)             (None, 10, 10, 320)  0           ['block35_6_ac[0][0]',
#                                                                   'block35_7_conv[0][0]']
#
#  block35_7_ac (Activation)      (None, 10, 10, 320)  0           ['block35_7[0][0]']
#
#  conv2d_60 (Conv2D)             (None, 10, 10, 32)   10240       ['block35_7_ac[0][0]']
#
#  batch_normalization_57 (BatchN  (None, 10, 10, 32)  96          ['conv2d_60[0][0]']
#  ormalization)
#
#  activation_57 (Activation)     (None, 10, 10, 32)   0           ['batch_normalization_57[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 10, 10, 32)   10240       ['block35_7_ac[0][0]']
#
#  conv2d_61 (Conv2D)             (None, 10, 10, 48)   13824       ['activation_57[0][0]']
#
# ...
#  block8_9_mixed (Concatenate)   (None, 1, 1, 448)    0           ['activation_195[0][0]',
#                                                                   'activation_198[0][0]']
#
#  block8_9_conv (Conv2D)         (None, 1, 1, 2080)   933920      ['block8_9_mixed[0][0]']
#
#  block8_9 (Lambda)              (None, 1, 1, 2080)   0           ['block8_8_ac[0][0]',
#                                                                   'block8_9_conv[0][0]']
#
#  block8_9_ac (Activation)       (None, 1, 1, 2080)   0           ['block8_9[0][0]']
#
#  conv2d_203 (Conv2D)            (None, 1, 1, 192)    399360      ['block8_9_ac[0][0]']
#
#  batch_normalization_200 (Batch  (None, 1, 1, 192)   576         ['conv2d_203[0][0]']
#  Normalization)
#
#  activation_200 (Activation)    (None, 1, 1, 192)    0           ['batch_normalization_200[0][0]']
#
#  conv2d_204 (Conv2D)            (None, 1, 1, 224)    129024      ['activation_200[0][0]']
#
#  batch_normalization_201 (Batch  (None, 1, 1, 224)   672         ['conv2d_204[0][0]']
#  Normalization)
#
#  activation_201 (Activation)    (None, 1, 1, 224)    0           ['batch_normalization_201[0][0]']
#
#  conv2d_202 (Conv2D)            (None, 1, 1, 192)    399360      ['block8_9_ac[0][0]']
#
#  conv2d_205 (Conv2D)            (None, 1, 1, 256)    172032      ['activation_201[0][0]']
#
#  batch_normalization_199 (Batch  (None, 1, 1, 192)   576         ['conv2d_202[0][0]']
#  Normalization)
#
#  batch_normalization_202 (Batch  (None, 1, 1, 256)   768         ['conv2d_205[0][0]']
#  Normalization)
#
#  activation_199 (Activation)    (None, 1, 1, 192)    0           ['batch_normalization_199[0][0]']
#
#  activation_202 (Activation)    (None, 1, 1, 256)    0           ['batch_normalization_202[0][0]']
#
#  block8_10_mixed (Concatenate)  (None, 1, 1, 448)    0           ['activation_199[0][0]',
#                                                                   'activation_202[0][0]']
#
#  block8_10_conv (Conv2D)        (None, 1, 1, 2080)   933920      ['block8_10_mixed[0][0]']
#
#  block8_10 (Lambda)             (None, 1, 1, 2080)   0           ['block8_9_ac[0][0]',
#                                                                   'block8_10_conv[0][0]']
#
#  conv_7b (Conv2D)               (None, 1, 1, 1536)   3194880     ['block8_10[0][0]']
#
#  conv_7b_bn (BatchNormalization  (None, 1, 1, 1536)  4608        ['conv_7b[0][0]']
#  )
#
#  conv_7b_ac (Activation)        (None, 1, 1, 1536)   0           ['conv_7b_bn[0][0]']
#
#  flatten_5 (Flatten)            (None, 1536)         0           ['conv_7b_ac[0][0]']
#
#  fc1 (Dense)                    (None, 1000)         1537000     ['flatten_5[0][0]']
#
#  dropout_8 (Dropout)            (None, 1000)         0           ['fc1[0][0]']
#
#  predictions (Dense)            (None, 5)            5005        ['dropout_8[0][0]']
#
# ==================================================================================================
# Total params: 55,878,741
# Trainable params: 1,542,005
# Non-trainable params: 54,336,736
# __________________________________________________________________________________________________
# Epoch 1/100
# 5/5 [==============================] - 29s 4s/step - loss: 1.6685 - accuracy: 0.2625 - val_loss: 1.4681 - val_accuracy: 0.4000
# Epoch 2/100
# 5/5 [==============================] - 12s 3s/step - loss: 1.2290 - accuracy: 0.5219 - val_loss: 1.2053 - val_accuracy: 0.6375
# Epoch 3/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.9061 - accuracy: 0.7000 - val_loss: 1.0503 - val_accuracy: 0.6750
# Epoch 4/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.7365 - accuracy: 0.7969 - val_loss: 0.9420 - val_accuracy: 0.7000
# Epoch 5/100
# 5/5 [==============================] - 13s 3s/step - loss: 0.6082 - accuracy: 0.8500 - val_loss: 0.8729 - val_accuracy: 0.7625
# Epoch 6/100
# 5/5 [==============================] - 13s 3s/step - loss: 0.4879 - accuracy: 0.9062 - val_loss: 0.8192 - val_accuracy: 0.7750
# Epoch 7/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.4235 - accuracy: 0.9219 - val_loss: 0.7815 - val_accuracy: 0.7875
# Epoch 8/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.3822 - accuracy: 0.9375 - val_loss: 0.7560 - val_accuracy: 0.8000
# Epoch 9/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.3364 - accuracy: 0.9469 - val_loss: 0.7386 - val_accuracy: 0.8125
# Epoch 10/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.2885 - accuracy: 0.9531 - val_loss: 0.7268 - val_accuracy: 0.8000
# Epoch 11/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.2616 - accuracy: 0.9594 - val_loss: 0.7122 - val_accuracy: 0.7875
# Epoch 12/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.2498 - accuracy: 0.9719 - val_loss: 0.7004 - val_accuracy: 0.7875
# Epoch 13/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.2248 - accuracy: 0.9719 - val_loss: 0.6906 - val_accuracy: 0.7875
# Epoch 14/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.
100

# %%
from sklearn.metrics import confusion_matrix

matriz=confusion_matrix(y_test, predicted_classes)
print(matriz)
# Out:
# [[16  4  1  0  0]
#  [ 4 11  3  1  0]
#  [ 1  0 16  0  0]
#  [ 1  0  3 19  0]
#  [ 0  0  1  0 19]]

# %%
import numpy as np
import cv2
import glob
import os
import matplotlib.pyplot as plt
import string
from mlxtend.plotting import plot_decision_regions
#from mpl_toolkits.mplot3d import Axes3D
#from sklearn.decomposition import PCA
#from sklearn.preprocessing import StandardScaler
#from sklearn.neighbors import KNeighborsClassifier
#from sklearn.tree import DecisionTreeClassifier
#from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.utils.multiclass import unique_labels
from sklearn import metrics
#from sklearn.svm import SVC


import json
from skimage import color
from skimage.feature import hog
#from sklearn import svm
from sklearn.metrics import classification_report,accuracy_score, recall_score
from subprocess import check_output

def plot_confusion_matrix(y_true, y_pred, classes,
                          normalize=False,
                          title=None,
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if not title:
        if normalize:
            title = 'Matriz de confusión'
        else:
            title = 'Matriz de confusión, sin normalización'

    # Compute confusion matrix

    cm = metrics.confusion_matrix(y_true, y_pred)
    # Only use the labels that appear in the data
    classes = unique_labels(y_true, y_pred)
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    fig, ax = plt.subplots()
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    # We want to show all ticks...

    ax.set(xticks=np.arange(cm.shape[1]),
           yticks=np.arange(cm.shape[0]),
           # ... and label them with the respective list entries
           xticklabels=labels, yticklabels=labels,
           title=title,
           ylabel='Etiqueta verdadera',
           xlabel='Etiqueta prevista')

    # Rotate the tick labels and set their alignment.

    plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
             rotation_mode="anchor")

    # Loop over data dimensions and create text annotations.

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], fmt),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")
    fig.tight_layout()
    return cm,ax

precision=metrics.accuracy_score(y_test,predicted_classes, normalize=False)

print("Accuracy:{0:.2f}".format(precision))
cm,_=plot_confusion_matrix(y_test,predicted_classes,classes=nClasses,normalize=False,title="Matriz de confusión")
plt.show()
# Out:
# Accuracy:81.00

# %%
import numpy as np
import cv2
import glob
import os
import matplotlib.pyplot as plt
import string
from mlxtend.plotting import plot_decision_regions
#from mpl_toolkits.mplot3d import Axes3D
#from sklearn.decomposition import PCA
#from sklearn.preprocessing import StandardScaler
#from sklearn.neighbors import KNeighborsClassifier
#from sklearn.tree import DecisionTreeClassifier
#from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.utils.multiclass import unique_labels
from sklearn import metrics
#from sklearn.svm import SVC


import json
from skimage import color
from skimage.feature import hog
#from sklearn import svm
from sklearn.metrics import classification_report,accuracy_score, recall_score
from subprocess import check_output

def plot_confusion_matrix(y_true, y_pred, classes,
                          normalize=False,
                          title=None,
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if not title:
        if normalize:
            title = 'Matriz de confusión'
        else:
            title = 'Matriz de confusión, sin normalización'

    # Compute confusion matrix

    cm = metrics.confusion_matrix(y_true, y_pred)
    # Only use the labels that appear in the data
    classes = unique_labels(y_true, y_pred)
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    fig, ax = plt.subplots()
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    # We want to show all ticks...

    ax.set(xticks=np.arange(cm.shape[1]),
           yticks=np.arange(cm.shape[0]),
           # ... and label them with the respective list entries
           xticklabels=labels, yticklabels=labels,
           title=title,
           ylabel='Etiqueta verdadera',
           xlabel='Etiqueta prevista')

    # Rotate the tick labels and set their alignment.

    plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
             rotation_mode="anchor")

    # Loop over data dimensions and create text annotations.

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], fmt),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")
    fig.tight_layout()
    return cm,ax

precision=metrics.accuracy_score(y_test,predicted_classes, normalize=True)

print("Accuracy:{0:.2f}%".format(precision))
cm,_=plot_confusion_matrix(y_test,predicted_classes,classes=nClasses,normalize=True,title="Matriz de confusión")
plt.show()
# Out:
# Accuracy:0.81%

# %%
model_out_inceResv2.save("/content/drive/My Drive/source_dir/gradoma_final_inceResv2.h5py")
# Out:
# INFO:tensorflow:Assets written to: /content/drive/My Drive/source_dir/gradoma_final_inceResv2.h5py/assets

# %% [markdown]
# ***PRUEBA DenseNet201***

# %%
#preprocess_input = tf.keras.applications.InceptionResNetV2.preprocess_input
rescale = tf.keras.layers.experimental.preprocessing.Rescaling(1./127.5, offset= -1)
IMG_SIZE = (100, 100)
img_height=100
img_width=100

IMG_SHAPE = IMG_SIZE + (3,)
base_model = tf.keras.applications.DenseNet201(input_shape=IMG_SHAPE,
                                               include_top=False,
                                               weights='imagenet')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet201_weights_tf_dim_ordering_tf_kernels_notop.h5
# 74842112/74836368 [==============================] - 1s 0us/step
# 74850304/74836368 [==============================] - 1s 0us/step

# %%
base_model.trainable = False

base_model.summary()
for layer in base_model.layers:
           if layer.name == 'block5_conv1':
              break
           layer.trainable = False
# We add our classificator (top_model) to the last layer of the model
last = base_model.layers[-1].output
x = Flatten()(last)
x = Dense(1000, activation='relu', name='fc1')(x)
x = Dropout(0.3)(x)
x = Dense(5, activation='softmax', name='predictions')(x)
model_out_desnet201 = Model(base_model.input, x)
#We compile the model
model_out_desnet201.compile(loss=keras.losses.categorical_crossentropy, optimizer=tf.keras.optimizers.Adam(learning_rate=INIT_LR, decay=INIT_LR / 100),metrics=['accuracy'])
model_out_desnet201.summary()
callback = tf.keras.callbacks.EarlyStopping(monitor='loss', min_delta=0.0001, patience=3)

grado_train_dropout = model_out_desnet201.fit(train_x, train_label, batch_size=batch_size,epochs=epochs,verbose=1,validation_data=(valid_X, valid_label),callbacks=[callback])
# Out:
# Model: "densenet201"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_6 (InputLayer)           [(None, 100, 100, 3  0           []
#                                 )]
#
#  zero_padding2d_2 (ZeroPadding2  (None, 106, 106, 3)  0          ['input_6[0][0]']
#  D)
#
#  conv1/conv (Conv2D)            (None, 50, 50, 64)   9408        ['zero_padding2d_2[0][0]']
#
#  conv1/bn (BatchNormalization)  (None, 50, 50, 64)   256         ['conv1/conv[0][0]']
#
#  conv1/relu (Activation)        (None, 50, 50, 64)   0           ['conv1/bn[0][0]']
#
#  zero_padding2d_3 (ZeroPadding2  (None, 52, 52, 64)  0           ['conv1/relu[0][0]']
#  D)
#
#  pool1 (MaxPooling2D)           (None, 25, 25, 64)   0           ['zero_padding2d_3[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 25, 25, 64)  256         ['pool1[0][0]']
#  ization)
#
#  conv2_block1_0_relu (Activatio  (None, 25, 25, 64)  0           ['conv2_block1_0_bn[0][0]']
#  n)
#
#  conv2_block1_1_conv (Conv2D)   (None, 25, 25, 128)  8192        ['conv2_block1_0_relu[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 25, 25, 128)  512        ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 25, 25, 128)  0          ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 25, 25, 32)   36864       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_concat (Concatena  (None, 25, 25, 96)  0           ['pool1[0][0]',
#  te)                                                              'conv2_block1_2_conv[0][0]']
#
#  conv2_block2_0_bn (BatchNormal  (None, 25, 25, 96)  384         ['conv2_block1_concat[0][0]']
#  ization)
#
#  conv2_block2_0_relu (Activatio  (None, 25, 25, 96)  0           ['conv2_block2_0_bn[0][0]']
#  n)
#
#  conv2_block2_1_conv (Conv2D)   (None, 25, 25, 128)  12288       ['conv2_block2_0_relu[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 25, 25, 128)  512        ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 25, 25, 128)  0          ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 25, 25, 32)   36864       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_concat (Concatena  (None, 25, 25, 128)  0          ['conv2_block1_concat[0][0]',
#  te)                                                              'conv2_block2_2_conv[0][0]']
#
#  conv2_block3_0_bn (BatchNormal  (None, 25, 25, 128)  512        ['conv2_block2_concat[0][0]']
#  ization)
#
#  conv2_block3_0_relu (Activatio  (None, 25, 25, 128)  0          ['conv2_block3_0_bn[0][0]']
#  n)
#
#  conv2_block3_1_conv (Conv2D)   (None, 25, 25, 128)  16384       ['conv2_block3_0_relu[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 25, 25, 128)  512        ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 25, 25, 128)  0          ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 25, 25, 32)   36864       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_concat (Concatena  (None, 25, 25, 160)  0          ['conv2_block2_concat[0][0]',
#  te)                                                              'conv2_block3_2_conv[0][0]']
#
#  conv2_block4_0_bn (BatchNormal  (None, 25, 25, 160)  640        ['conv2_block3_concat[0][0]']
#  ization)
#
#  conv2_block4_0_relu (Activatio  (None, 25, 25, 160)  0          ['conv2_block4_0_bn[0][0]']
#  n)
#
#  conv2_block4_1_conv (Conv2D)   (None, 25, 25, 128)  20480       ['conv2_block4_0_relu[0][0]']
#
#  conv2_block4_1_bn (BatchNormal  (None, 25, 25, 128)  512        ['conv2_block4_1_conv[0][0]']
#  ization)
#
#  conv2_block4_1_relu (Activatio  (None, 25, 25, 128)  0          ['conv2_block4_1_bn[0][0]']
#  n)
#
#  conv2_block4_2_conv (Conv2D)   (None, 25, 25, 32)   36864       ['conv2_block4_1_relu[0][0]']
#
#  conv2_block4_concat (Concatena  (None, 25, 25, 192)  0          ['conv2_block3_concat[0][0]',
#  te)                                                              'conv2_block4_2_conv[0][0]']
#
#  conv2_block5_0_bn (BatchNormal  (None, 25, 25, 192)  768        ['conv2_block4_concat[0][0]']
#  ization)
#
#  conv2_block5_0_relu (Activatio  (None, 25, 25, 192)  0          ['conv2_block5_0_bn[0][0]']
#  n)
#
#  conv2_block5_1_conv (Conv2D)   (None, 25, 25, 128)  24576       ['conv2_block5_0_relu[0][0]']
#
#  conv2_block5_1_bn (BatchNormal  (None, 25, 25, 128)  512        ['conv2_block5_1_conv[0][0]']
#  ization)
#
#  conv2_block5_1_relu (Activatio  (None, 25, 25, 128)  0          ['conv2_block5_1_bn[0][0]']
#  n)
#
#  conv2_block5_2_conv (Conv2D)   (None, 25, 25, 32)   36864       ['conv2_block5_1_relu[0][0]']
#
#  conv2_block5_concat (Concatena  (None, 25, 25, 224)  0          ['conv2_block4_concat[0][0]',
#  te)                                                              'conv2_block5_2_conv[0][0]']
#
#  conv2_block6_0_bn (BatchNormal  (None, 25, 25, 224)  896        ['conv2_block5_concat[0][0]']
#  ization)
#
#  conv2_block6_0_relu (Activatio  (None, 25, 25, 224)  0          ['conv2_block6_0_bn[0][0]']
#  n)
#
#  conv2_block6_1_conv (Conv2D)   (None, 25, 25, 128)  28672       ['conv2_block6_0_relu[0][0]']
#
#  conv2_block6_1_bn (BatchNormal  (None, 25, 25, 128)  512        ['conv2_block6_1_conv[0][0]']
#  ization)
#
#  conv2_block6_1_relu (Activatio  (None, 25, 25, 128)  0          ['conv2_block6_1_bn[0][0]']
#  n)
#
#  conv2_block6_2_conv (Conv2D)   (None, 25, 25, 32)   36864       ['conv2_block6_1_relu[0][0]']
#
#  conv2_block6_concat (Concatena  (None, 25, 25, 256)  0          ['conv2_block5_concat[0][0]',
#  te)                                                              'conv2_block6_2_conv[0][0]']
#
#  pool2_bn (BatchNormalization)  (None, 25, 25, 256)  1024        ['conv2_block6_concat[0][0]']
#
#  pool2_relu (Activation)        (None, 25, 25, 256)  0           ['pool2_bn[0][0]']
#
#  pool2_conv (Conv2D)            (None, 25, 25, 128)  32768       ['pool2_relu[0][0]']
#
#  pool2_pool (AveragePooling2D)  (None, 12, 12, 128)  0           ['pool2_conv[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 12, 12, 128)  512        ['pool2_pool[0][0]']
#  ization)
#
#  conv3_block1_0_relu (Activatio  (None, 12, 12, 128)  0          ['conv3_block1_0_bn[0][0]']
#  n)
#
#  conv3_block1_1_conv (Conv2D)   (None, 12, 12, 128)  16384       ['conv3_block1_0_relu[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 12, 12, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 12, 12, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 12, 12, 32)   36864       ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_concat (Concatena  (None, 12, 12, 160)  0          ['pool2_pool[0][0]',
#  te)                                                              'conv3_block1_2_conv[0][0]']
#
#  conv3_block2_0_bn (BatchNormal  (None, 12, 12, 160)  640        ['conv3_block1_concat[0][0]']
#  ization)
#
#  conv3_block2_0_relu (Activatio  (None, 12, 12, 160)  0          ['conv3_block2_0_bn[0][0]']
#  n)
#
#  conv3_block2_1_conv (Conv2D)   (None, 12, 12, 128)  20480       ['conv3_block2_0_relu[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 12, 12, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 12, 12, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 12, 12, 32)   36864       ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_concat (Concatena  (None, 12, 12, 192)  0          ['conv3_block1_concat[0][0]',
#  te)                                                              'conv3_block2_2_conv[0][0]']
#
#  conv3_block3_0_bn (BatchNormal  (None, 12, 12, 192)  768        ['conv3_block2_concat[0][0]']
#  ization)
#
#  conv3_block3_0_relu (Activatio  (None, 12, 12, 192)  0          ['conv3_block3_0_bn[0][0]']
#  n)
#
#  conv3_block3_1_conv (Conv2D)   (None, 12, 12, 128)  24576       ['conv3_block3_0_relu[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 12, 12, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 12, 12, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 12, 12, 32)   36864       ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_concat (Concatena  (None, 12, 12, 224)  0          ['conv3_block2_concat[0][0]',
#  te)                                                              'conv3_block3_2_conv[0][0]']
#
#  conv3_block4_0_bn (BatchNormal  (None, 12, 12, 224)  896        ['conv3_block3_concat[0][0]']
#  ization)
#
#  conv3_block4_0_relu (Activatio  (None, 12, 12, 224)  0          ['conv3_block4_0_bn[0][0]']
#  n)
#
#  conv3_block4_1_conv (Conv2D)   (None, 12, 12, 128)  28672       ['conv3_block4_0_relu[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 12, 12, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 12, 12, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 12, 12, 32)   36864       ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_concat (Concatena  (None, 12, 12, 256)  0          ['conv3_block3_concat[0][0]',
#  te)                                                              'conv3_block4_2_conv[0][0]']
#
#  conv3_block5_0_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv3_block4_concat[0][0]']
#  ization)
#
#  conv3_block5_0_relu (Activatio  (None, 12, 12, 256)  0          ['conv3_block5_0_bn[0][0]']
#  n)
#
#  conv3_block5_1_conv (Conv2D)   (None, 12, 12, 128)  32768       ['conv3_block5_0_relu[0][0]']
#
#  conv3_block5_1_bn (BatchNormal  (None, 12, 12, 128)  512        ['conv3_block5_1_conv[0][0]']
#  ization)
#
#  conv3_block5_1_relu (Activatio  (None, 12, 12, 128)  0          ['conv3_block5_1_bn[0][0]']
#  n)
#
#  conv3_block5_2_conv (Conv2D)   (None, 12, 12, 32)   36864       ['conv3_block5_1_relu[0][0]']
#
#  conv3_block5_concat (Concatena  (None, 12, 12, 288)  0          ['conv3_block4_concat[0][0]',
#  te)                                                              'conv3_block5_2_conv[0][0]']
#
#  conv3_block6_0_bn (BatchNormal  (None, 12, 12, 288)  1152       ['conv3_block5_concat[0][0]']
#  ization)
#
#  conv3_block6_0_relu (Activatio  (None, 12, 12, 288)  0          ['conv3_block6_0_bn[0][0]']
#  n)
#
#  conv3_block6_1_conv (Conv2D)   (None, 12, 12, 128)  36864       ['conv3_block6_0_relu[0][0]']
#
#  conv3_block6_1_bn (BatchNormal  (None, 12, 12, 128)  512        ['conv3_block6_1_conv[0][0]']
#  ization)
#
#  conv3_block6_1_relu (Activatio  (None, 12, 12, 128)  0          ['conv3_block6_1_bn[0][0]']
#  n)
#
#  conv3_block6_2_conv (Conv2D)   (None, 12, 12, 32)   36864       ['conv3_block6_1_relu[0][0]']
#
#  conv3_block6_concat (Concatena  (None, 12, 12, 320)  0          ['conv3_block5_concat[0][0]',
#  te)                                                              'conv3_block6_2_conv[0][0]']
#
#  conv3_block7_0_bn (BatchNormal  (None, 12, 12, 320)  1280       ['conv3_block6_concat[0][0]']
#  ization)
#
#  conv3_block7_0_relu (Activatio  (None, 12, 12, 320)  0          ['conv3_block7_0_bn[0][0]']
#  n)
#
#  conv3_block7_1_conv (Conv2D)   (None, 12, 12, 128)  40960       ['conv3_block7_0_relu[0][0]']
#
#  conv3_block7_1_bn (BatchNormal  (None, 12, 12, 128)  512        ['conv3_block7_1_conv[0][0]']
#  ization)
#
#  conv3_block7_1_relu (Activatio  (None, 12, 12, 128)  0          ['conv3_block7_1_bn[0][0]']
#  n)
#
#  conv3_block7_2_conv (Conv2D)   (None, 12, 12, 32)   36864       ['conv3_block7_1_relu[0][0]']
#
#  conv3_block7_concat (Concatena  (None, 12, 12, 352)  0          ['conv3_block6_concat[0][0]',
#  te)                                                              'conv3_block7_2_conv[0][0]']
#
#  conv3_block8_0_bn (BatchNormal  (None, 12, 12, 352)  1408       ['conv3_block7_concat[0][0]']
#  ization)
#
#  conv3_block8_0_relu (Activatio  (None, 12, 12, 352)  0          ['conv3_block8_0_bn[0][0]']
#  n)
#
#  conv3_block8_1_conv (Conv2D)   (None, 12, 12, 128)  45056       ['conv3_block8_0_relu[0][0]']
#
#  conv3_block8_1_bn (BatchNormal  (None, 12, 12, 128)  512        ['conv3_block8_1_conv[0][0]']
#  ization)
#
#  conv3_block8_1_relu (Activatio  (None, 12, 12, 128)  0          ['conv3_block8_1_bn[0][0]']
#  n)
#
#  conv3_block8_2_conv (Conv2D)   (None, 12, 12, 32)   36864       ['conv3_block8_1_relu[0][0]']
#
#  conv3_block8_concat (Concatena  (None, 12, 12, 384)  0          ['conv3_block7_concat[0][0]',
#  te)                                                              'conv3_block8_2_conv[0][0]']
#
#  conv3_block9_0_bn (BatchNormal  (None, 12, 12, 384)  1536       ['conv3_block8_concat[0][0]']
#  ization)
#
#  conv3_block9_0_relu (Activatio  (None, 12, 12, 384)  0          ['conv3_block9_0_bn[0][0]']
#  n)
#
#  conv3_block9_1_conv (Conv2D)   (None, 12, 12, 128)  49152       ['conv3_block9_0_relu[0][0]']
#
#  conv3_block9_1_bn (BatchNormal  (None, 12, 12, 128)  512        ['conv3_block9_1_conv[0][0]']
#  ization)
#
#  conv3_block9_1_relu (Activatio  (None, 12, 12, 128)  0          ['conv3_block9_1_bn[0][0]']
#  n)
#
#  conv3_block9_2_conv (Conv2D)   (None, 12, 12, 32)   36864       ['conv3_block9_1_relu[0][0]']
#
#  conv3_block9_concat (Concatena  (None, 12, 12, 416)  0          ['conv3_block8_concat[0][0]',
#  te)                                                              'conv3_block9_2_conv[0][0]']
#
#  conv3_block10_0_bn (BatchNorma  (None, 12, 12, 416)  1664       ['conv3_block9_concat[0][0]']
#  lization)
#
#  conv3_block10_0_relu (Activati  (None, 12, 12, 416)  0          ['conv3_block10_0_bn[0][0]']
#  on)
#
#  conv3_block10_1_conv (Conv2D)  (None, 12, 12, 128)  53248       ['conv3_block10_0_relu[0][0]']
#
#  conv3_block10_1_bn (BatchNorma  (None, 12, 12, 128)  512        ['conv3_block10_1_conv[0][0]']
#  lization)
#
#  conv3_block10_1_relu (Activati  (None, 12, 12, 128)  0          ['conv3_block10_1_bn[0][0]']
#  on)
#
#  conv3_block10_2_conv (Conv2D)  (None, 12, 12, 32)   36864       ['conv3_block10_1_relu[0][0]']
#
#  conv3_block10_concat (Concaten  (None, 12, 12, 448)  0          ['conv3_block9_concat[0][0]',
#  ate)                                                             'conv3_block10_2_conv[0][0]']
#
#  conv3_block11_0_bn (BatchNorma  (None, 12, 12, 448)  1792       ['conv3_block10_concat[0][0]']
#  lization)
#
#  conv3_block11_0_relu (Activati  (None, 12, 12, 448)  0          ['conv3_block11_0_bn[0][0]']
#  on)
#
#  conv3_block11_1_conv (Conv2D)  (None, 12, 12, 128)  57344       ['conv3_block11_0_relu[0][0]']
#
#  conv3_block11_1_bn (BatchNorma  (None, 12, 12, 128)  512        ['conv3_block11_1_conv[0][0]']
#  lization)
#
#  conv3_block11_1_relu (Activati  (None, 12, 12, 128)  0          ['conv3_block11_1_bn[0][0]']
#  on)
#
#  conv3_block11_2_conv (Conv2D)  (None, 12, 12, 32)   36864       ['conv3_block11_1_relu[0][0]']
#
#  conv3_block11_concat (Concaten  (None, 12, 12, 480)  0          ['conv3_block10_concat[0][0]',
#  ate)                                                             'conv3_block11_2_conv[0][0]']
#
#  conv3_block12_0_bn (BatchNorma  (None, 12, 12, 480)  1920       ['conv3_block11_concat[0][0]']
#  lization)
#
#  conv3_block12_0_relu (Activati  (None, 12, 12, 480)  0          ['conv3_block12_0_bn[0][0]']
#  on)
#
#  conv3_block12_1_conv (Conv2D)  (None, 12, 12, 128)  61440       ['conv3_block12_0_relu[0][0]']
#
#  conv3_block12_1_bn (BatchNorma  (None, 12, 12, 128)  512        ['conv3_block12_1_conv[0][0]']
#  lization)
#
#  conv3_block12_1_relu (Activati  (None, 12, 12, 128)  0          ['conv3_block12_1_bn[0][0]']
#  on)
#
#  conv3_block12_2_conv (Conv2D)  (None, 12, 12, 32)   36864       ['conv3_block12_1_relu[0][0]']
#
#  conv3_block12_concat (Concaten  (None, 12, 12, 512)  0          ['conv3_block11_concat[0][0]',
#  ate)                                                             'conv3_block12_2_conv[0][0]']
#
#  pool3_bn (BatchNormalization)  (None, 12, 12, 512)  2048        ['conv3_block12_concat[0][0]']
#
#  pool3_relu (Activation)        (None, 12, 12, 512)  0           ['pool3_bn[0][0]']
#
#  pool3_conv (Conv2D)            (None, 12, 12, 256)  131072      ['pool3_relu[0][0]']
#
#  pool3_pool (AveragePooling2D)  (None, 6, 6, 256)    0           ['pool3_conv[0][0]']
#
#  conv4_block1_0_bn (BatchNormal  (None, 6, 6, 256)   1024        ['pool3_pool[0][0]']
#  ization)
#
#  conv4_block1_0_relu (Activatio  (None, 6, 6, 256)   0           ['conv4_block1_0_bn[0][0]']
#  n)
#
#  conv4_block1_1_conv (Conv2D)   (None, 6, 6, 128)    32768       ['conv4_block1_0_relu[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 6, 6, 128)   512         ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 6, 6, 128)   0           ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 6, 6, 32)     36864       ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_concat (Concatena  (None, 6, 6, 288)   0           ['pool3_pool[0][0]',
#  te)                                                              'conv4_block1_2_conv[0][0]']
#
#  conv4_block2_0_bn (BatchNormal  (None, 6, 6, 288)   1152        ['conv4_block1_concat[0][0]']
#  ization)
#
#  conv4_block2_0_relu (Activatio  (None, 6, 6, 288)   0           ['conv4_block2_0_bn[0][0]']
#  n)
#
#  conv4_block2_1_conv (Conv2D)   (None, 6, 6, 128)    36864       ['conv4_block2_0_relu[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 6, 6, 128)   512         ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 6, 6, 128)   0           ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 6, 6, 32)     36864       ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_concat (Concatena  (None, 6, 6, 320)   0           ['conv4_block1_concat[0][0]',
#  te)                                                              'conv4_block2_2_conv[0][0]']
#
#  conv4_block3_0_bn (BatchNormal  (None, 6, 6, 320)   1280        ['conv4_block2_concat[0][0]']
#  ization)
#
#  conv4_block3_0_relu (Activatio  (None, 6, 6, 320)   0           ['conv4_block3_0_bn[0][0]']
#  n)
#
#  conv4_block3_1_conv (Conv2D)   (None, 6, 6, 128)    40960       ['conv4_block3_0_relu[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 6, 6, 128)   512         ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 6, 6, 128)   0           ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 6, 6, 32)     36864       ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_concat (Concatena  (None, 6, 6, 352)   0           ['conv4_block2_concat[0][0]',
#  te)                                                              'conv4_block3_2_conv[0][0]']
#
#  conv4_block4_0_bn (BatchNormal  (None, 6, 6, 352)   1408        ['conv4_block3_concat[0][0]']
#  ization)
#
#  conv4_block4_0_relu (Activatio  (None, 6, 6, 352)   0           ['conv4_block4_0_bn[0][0]']
#  n)
#
#  conv4_block4_1_conv (Conv2D)   (None, 6, 6, 128)    45056       ['conv4_block4_0_relu[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 6, 6, 128)   512         ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 6, 6, 128)   0           ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 6, 6, 32)     36864       ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_concat (Concatena  (None, 6, 6, 384)   0           ['conv4_block3_concat[0][0]',
#  te)                                                              'conv4_block4_2_conv[0][0]']
#
#  conv4_block5_0_bn (BatchNormal  (None, 6, 6, 384)   1536        ['conv4_block4_concat[0][0]']
#  ization)
#
#  conv4_block5_0_relu (Activatio  (None, 6, 6, 384)   0           ['conv4_block5_0_bn[0][0]']
#  n)
#
#  conv4_block5_1_conv (Conv2D)   (None, 6, 6, 128)    49152       ['conv4_block5_0_relu[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 6, 6, 128)   512         ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 6, 6, 128)   0           ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 6, 6, 32)     36864       ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_concat (Concatena  (None, 6, 6, 416)   0           ['conv4_block4_concat[0][0]',
#  te)                                                              'conv4_block5_2_conv[0][0]']
#
#  conv4_block6_0_bn (BatchNormal  (None, 6, 6, 416)   1664        ['conv4_block5_concat[0][0]']
#  ization)
#
#  conv4_block6_0_relu (Activatio  (None, 6, 6, 416)   0           ['conv4_block6_0_bn[0][0]']
#  n)
#
#  conv4_block6_1_conv (Conv2D)   (None, 6, 6, 128)    53248       ['conv4_block6_0_relu[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 6, 6, 128)   512         ['conv4_block6_1_conv[0][0]']
#  ization)
#
# ...
#  conv5_block27_0_bn (BatchNorma  (None, 3, 3, 1728)  6912        ['conv5_block26_concat[0][0]']
#  lization)
#
#  conv5_block27_0_relu (Activati  (None, 3, 3, 1728)  0           ['conv5_block27_0_bn[0][0]']
#  on)
#
#  conv5_block27_1_conv (Conv2D)  (None, 3, 3, 128)    221184      ['conv5_block27_0_relu[0][0]']
#
#  conv5_block27_1_bn (BatchNorma  (None, 3, 3, 128)   512         ['conv5_block27_1_conv[0][0]']
#  lization)
#
#  conv5_block27_1_relu (Activati  (None, 3, 3, 128)   0           ['conv5_block27_1_bn[0][0]']
#  on)
#
#  conv5_block27_2_conv (Conv2D)  (None, 3, 3, 32)     36864       ['conv5_block27_1_relu[0][0]']
#
#  conv5_block27_concat (Concaten  (None, 3, 3, 1760)  0           ['conv5_block26_concat[0][0]',
#  ate)                                                             'conv5_block27_2_conv[0][0]']
#
#  conv5_block28_0_bn (BatchNorma  (None, 3, 3, 1760)  7040        ['conv5_block27_concat[0][0]']
#  lization)
#
#  conv5_block28_0_relu (Activati  (None, 3, 3, 1760)  0           ['conv5_block28_0_bn[0][0]']
#  on)
#
#  conv5_block28_1_conv (Conv2D)  (None, 3, 3, 128)    225280      ['conv5_block28_0_relu[0][0]']
#
#  conv5_block28_1_bn (BatchNorma  (None, 3, 3, 128)   512         ['conv5_block28_1_conv[0][0]']
#  lization)
#
#  conv5_block28_1_relu (Activati  (None, 3, 3, 128)   0           ['conv5_block28_1_bn[0][0]']
#  on)
#
#  conv5_block28_2_conv (Conv2D)  (None, 3, 3, 32)     36864       ['conv5_block28_1_relu[0][0]']
#
#  conv5_block28_concat (Concaten  (None, 3, 3, 1792)  0           ['conv5_block27_concat[0][0]',
#  ate)                                                             'conv5_block28_2_conv[0][0]']
#
#  conv5_block29_0_bn (BatchNorma  (None, 3, 3, 1792)  7168        ['conv5_block28_concat[0][0]']
#  lization)
#
#  conv5_block29_0_relu (Activati  (None, 3, 3, 1792)  0           ['conv5_block29_0_bn[0][0]']
#  on)
#
#  conv5_block29_1_conv (Conv2D)  (None, 3, 3, 128)    229376      ['conv5_block29_0_relu[0][0]']
#
#  conv5_block29_1_bn (BatchNorma  (None, 3, 3, 128)   512         ['conv5_block29_1_conv[0][0]']
#  lization)
#
#  conv5_block29_1_relu (Activati  (None, 3, 3, 128)   0           ['conv5_block29_1_bn[0][0]']
#  on)
#
#  conv5_block29_2_conv (Conv2D)  (None, 3, 3, 32)     36864       ['conv5_block29_1_relu[0][0]']
#
#  conv5_block29_concat (Concaten  (None, 3, 3, 1824)  0           ['conv5_block28_concat[0][0]',
#  ate)                                                             'conv5_block29_2_conv[0][0]']
#
#  conv5_block30_0_bn (BatchNorma  (None, 3, 3, 1824)  7296        ['conv5_block29_concat[0][0]']
#  lization)
#
#  conv5_block30_0_relu (Activati  (None, 3, 3, 1824)  0           ['conv5_block30_0_bn[0][0]']
#  on)
#
#  conv5_block30_1_conv (Conv2D)  (None, 3, 3, 128)    233472      ['conv5_block30_0_relu[0][0]']
#
#  conv5_block30_1_bn (BatchNorma  (None, 3, 3, 128)   512         ['conv5_block30_1_conv[0][0]']
#  lization)
#
#  conv5_block30_1_relu (Activati  (None, 3, 3, 128)   0           ['conv5_block30_1_bn[0][0]']
#  on)
#
#  conv5_block30_2_conv (Conv2D)  (None, 3, 3, 32)     36864       ['conv5_block30_1_relu[0][0]']
#
#  conv5_block30_concat (Concaten  (None, 3, 3, 1856)  0           ['conv5_block29_concat[0][0]',
#  ate)                                                             'conv5_block30_2_conv[0][0]']
#
#  conv5_block31_0_bn (BatchNorma  (None, 3, 3, 1856)  7424        ['conv5_block30_concat[0][0]']
#  lization)
#
#  conv5_block31_0_relu (Activati  (None, 3, 3, 1856)  0           ['conv5_block31_0_bn[0][0]']
#  on)
#
#  conv5_block31_1_conv (Conv2D)  (None, 3, 3, 128)    237568      ['conv5_block31_0_relu[0][0]']
#
#  conv5_block31_1_bn (BatchNorma  (None, 3, 3, 128)   512         ['conv5_block31_1_conv[0][0]']
#  lization)
#
#  conv5_block31_1_relu (Activati  (None, 3, 3, 128)   0           ['conv5_block31_1_bn[0][0]']
#  on)
#
#  conv5_block31_2_conv (Conv2D)  (None, 3, 3, 32)     36864       ['conv5_block31_1_relu[0][0]']
#
#  conv5_block31_concat (Concaten  (None, 3, 3, 1888)  0           ['conv5_block30_concat[0][0]',
#  ate)                                                             'conv5_block31_2_conv[0][0]']
#
#  conv5_block32_0_bn (BatchNorma  (None, 3, 3, 1888)  7552        ['conv5_block31_concat[0][0]']
#  lization)
#
#  conv5_block32_0_relu (Activati  (None, 3, 3, 1888)  0           ['conv5_block32_0_bn[0][0]']
#  on)
#
#  conv5_block32_1_conv (Conv2D)  (None, 3, 3, 128)    241664      ['conv5_block32_0_relu[0][0]']
#
#  conv5_block32_1_bn (BatchNorma  (None, 3, 3, 128)   512         ['conv5_block32_1_conv[0][0]']
#  lization)
#
#  conv5_block32_1_relu (Activati  (None, 3, 3, 128)   0           ['conv5_block32_1_bn[0][0]']
#  on)
#
#  conv5_block32_2_conv (Conv2D)  (None, 3, 3, 32)     36864       ['conv5_block32_1_relu[0][0]']
#
#  conv5_block32_concat (Concaten  (None, 3, 3, 1920)  0           ['conv5_block31_concat[0][0]',
#  ate)                                                             'conv5_block32_2_conv[0][0]']
#
#  bn (BatchNormalization)        (None, 3, 3, 1920)   7680        ['conv5_block32_concat[0][0]']
#
#  relu (Activation)              (None, 3, 3, 1920)   0           ['bn[0][0]']
#
#  flatten_6 (Flatten)            (None, 17280)        0           ['relu[0][0]']
#
#  fc1 (Dense)                    (None, 1000)         17281000    ['flatten_6[0][0]']
#
#  dropout_9 (Dropout)            (None, 1000)         0           ['fc1[0][0]']
#
#  predictions (Dense)            (None, 5)            5005        ['dropout_9[0][0]']
#
# ==================================================================================================
# Total params: 35,607,989
# Trainable params: 17,286,005
# Non-trainable params: 18,321,984
# __________________________________________________________________________________________________
# Epoch 1/100
# 5/5 [==============================] - 34s 5s/step - loss: 1.1672 - accuracy: 0.5781 - val_loss: 0.4548 - val_accuracy: 0.8375
# Epoch 2/100
# 5/5 [==============================] - 18s 4s/step - loss: 0.2172 - accuracy: 0.9312 - val_loss: 0.3427 - val_accuracy: 0.8625
# Epoch 3/100
# 5/5 [==============================] - 18s 4s/step - loss: 0.0687 - accuracy: 0.9719 - val_loss: 0.3518 - val_accuracy: 0.8625
# Epoch 4/100
# 5/5 [==============================] - 18s 4s/step - loss: 0.0220 - accuracy: 1.0000 - val_loss: 0.3677 - val_accuracy: 0.8625
# Epoch 5/100
# 5/5 [==============================] - 18s 4s/step - loss: 0.0194 - accuracy: 1.0000 - val_loss: 0.3444 - val_accuracy: 0.9000
# Epoch 6/100
# 5/5 [==============================] - 18s 4s/step - loss: 0.0099 - accuracy: 1.0000 - val_loss: 0.3238 - val_accuracy: 0.9000
# Epoch 7/100
# 5/5 [==============================] - 18s 4s/step - loss: 0.0141 - accuracy: 0.9969 - val_loss: 0.3067 - val_accuracy: 0.9000
# Epoch 8/100
# 5/5 [==============================] - 18s 4s/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.3019 - val_accuracy: 0.9000
# Epoch 9/100
# 5/5 [==============================] - 18s 4s/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.3128 - val_accuracy: 0.9000
# Epoch 10/100
# 5/5 [==============================] - 18s 4s/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.3293 - val_accuracy: 0.8875
# Epoch 11/100
# 5/5 [==============================] - 18s 4s/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.3360 - val_accuracy: 0.9000
# Epoch 12/100
# 5/5 [==============================] - 18s 4s/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.3254 - val_accuracy: 0.8875
# Epoch 13/100
# 5/5 [==============================] - 18s 4s/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.3172 - val_accuracy: 0.9000
# Epoch 14/100
# 5/5 [==============================] - 18s 4s/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.3154 - val_accuracy: 0.9000
# Epoch 15/100
# 5/5 [==============================] - 18s 4s/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.3171 - val_accuracy: 0.9000
# Epoch 16/100
# 5/5 [==============================] - 18s 4s/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.3241 - val_accuracy: 0.9000
# Epoch 17/100
# 5/5 [==============================] - 18s 4s/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.3280 - val_accuracy: 0.9000
# Epoch 18/100
# 5/5 [==============================] - 19s 4s/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.3323 - val_accuracy: 0.9000
# Epoch 19/100
# 5/5 [==============================] - 18s 4s/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.3322 - val_accuracy: 0.9000
# Epoch 20/100
# 5/5 [==============================] - 18s 4s/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.3340 - val_accuracy: 0.9000
# Epoch 21/100
# 5/5 [==============================] - 18s 4s/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.3327 - val_accuracy: 0.9000
# Epoch 22/100
# 5/5 [==============================] - 18s 4s/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.3449 - val_accuracy: 0.8875
# Epoch 23/100
# 5/5 [==============================] - 19s 4s/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.3499 - val_accuracy: 0.8875

# %%
acc = grado_train_dropout.history['accuracy']
val_acc = grado_train_dropout.history['val_accuracy']

loss = grado_train_dropout.history['loss']
val_loss = grado_train_dropout.history['val_loss']

plt.figure(figsize=(10, 10))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Exactitud Entrenamiento ')
plt.plot(val_acc, label='Exactitud Validación')
plt.legend(loc='lower right')
plt.ylabel('Exactitud')
plt.ylim([min(plt.ylim()),1])
plt.title('Exactitud Entrenamiento y Validación ')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Pérdida Entrenamiento')
plt.plot(val_loss, label='Pérdida Validación')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,1.0])
plt.title(' Pérdida Entrenamiento y Validación ')
plt.xlabel('epoch')
plt.show()

# %%
test_eval = model_out_desnet201.evaluate(x_test, test_Y_one_hot, verbose=1)

print('Test loss:', test_eval[0])
print('Test accuracy:', test_eval[1])
# Out:
# 4/4 [==============================] - 5s 1s/step - loss: 0.2607 - accuracy: 0.9300
# Test loss: 0.26066523790359497
# Test accuracy: 0.9300000071525574

# %%
from sklearn.metrics import classification_report
target_names = ["Class {}".format(i) for i in range(nClasses)]
print(classification_report(y_test, predicted_classes, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#      Class 0       0.73      0.76      0.74        21
#      Class 1       0.73      0.58      0.65        19
#      Class 2       0.67      0.94      0.78        17
#      Class 3       0.95      0.83      0.88        23
#      Class 4       1.00      0.95      0.97        20
#
#     accuracy                           0.81       100
#    macro avg       0.82      0.81      0.81       100
# weighted avg       0.82      0.81      0.81       100

# %%
from sklearn.metrics import confusion_matrix

matriz=confusion_matrix(y_test, predicted_classes)
print(matriz)
# Out:
# [[16  4  1  0  0]
#  [ 4 11  3  1  0]
#  [ 1  0 16  0  0]
#  [ 1  0  3 19  0]
#  [ 0  0  1  0 19]]

# %%
import numpy as np
import cv2
import glob
import os
import matplotlib.pyplot as plt
import string
from mlxtend.plotting import plot_decision_regions
#from mpl_toolkits.mplot3d import Axes3D
#from sklearn.decomposition import PCA
#from sklearn.preprocessing import StandardScaler
#from sklearn.neighbors import KNeighborsClassifier
#from sklearn.tree import DecisionTreeClassifier
#from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.utils.multiclass import unique_labels
from sklearn import metrics
#from sklearn.svm import SVC


import json
from skimage import color
from skimage.feature import hog
#from sklearn import svm
from sklearn.metrics import classification_report,accuracy_score, recall_score
from subprocess import check_output

def plot_confusion_matrix(y_true, y_pred, classes,
                          normalize=False,
                          title=None,
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if not title:
        if normalize:
            title = 'Matriz de confusión'
        else:
            title = 'Matriz de confusión, sin normalización'

    # Compute confusion matrix

    cm = metrics.confusion_matrix(y_true, y_pred)
    # Only use the labels that appear in the data
    classes = unique_labels(y_true, y_pred)
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    fig, ax = plt.subplots()
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    # We want to show all ticks...

    ax.set(xticks=np.arange(cm.shape[1]),
           yticks=np.arange(cm.shape[0]),
           # ... and label them with the respective list entries
           xticklabels=labels, yticklabels=labels,
           title=title,
           ylabel='Etiqueta verdadera',
           xlabel='Etiqueta prevista')

    # Rotate the tick labels and set their alignment.

    plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
             rotation_mode="anchor")

    # Loop over data dimensions and create text annotations.

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], fmt),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")
    fig.tight_layout()
    return cm,ax

precision=metrics.accuracy_score(y_test,predicted_classes, normalize=False)

print("Accuracy:{0:.2f}".format(precision))
cm,_=plot_confusion_matrix(y_test,predicted_classes,classes=nClasses,normalize=False,title="Matriz de confusión no nomalizada")
plt.show()


precision=metrics.accuracy_score(y_test,predicted_classes, normalize=True)*100

print("Accuracy:{0:.2f}%".format(precision))
cm,_=plot_confusion_matrix(y_test,predicted_classes,classes=nClasses,normalize=True,title="Matriz de confusión normalizada")
plt.show()
# Out:
# Accuracy:81.00
# Accuracy:81.00%

# %% [markdown]
# PRUEBA XCEPTION

# %%
#preprocess_input = tf.keras.applications.Xception.preprocess_input
rescale = tf.keras.layers.experimental.preprocessing.Rescaling(1./127.5, offset= -1)
IMG_SIZE = (100, 100)
img_height=100
img_width=100

IMG_SHAPE = IMG_SIZE + (3,)
base_model_Xception = tf.keras.applications.Xception(input_shape=IMG_SHAPE,
                                               include_top=False,
                                               weights='imagenet')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83689472/83683744 [==============================] - 1s 0us/step
# 83697664/83683744 [==============================] - 1s 0us/step

# %%
base_model_Xception.trainable = False

base_model_Xception.summary()
for layer in base_model_Xception.layers:
           if layer.name == 'block5_conv1':
              break
           layer.trainable = False
# We add our classificator (top_model) to the last layer of the model
last = base_model_Xception.layers[-1].output
x = Flatten()(last)
x = Dense(1000, activation='relu', name='fc1')(x)
x = Dropout(0.3)(x)
x = Dense(5, activation='softmax', name='predictions')(x)
model_out_Xception = Model(base_model_Xception.input, x)
#We compile the model
#We compile the model
model_out_Xception.compile(loss=keras.losses.categorical_crossentropy, optimizer=tf.keras.optimizers.Adam(learning_rate=INIT_LR, decay=INIT_LR / 100),metrics=['accuracy'])
model_out_Xception.summary()
callback = tf.keras.callbacks.EarlyStopping(monitor='loss', min_delta=0.0001, patience=3)

grado_train_dropout = model_out_Xception.fit(train_x, train_label, batch_size=batch_size,epochs=epochs,verbose=1,validation_data=(valid_X, valid_label),callbacks=[callback])
# Out:
# Model: "xception"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_7 (InputLayer)           [(None, 100, 100, 3  0           []
#                                 )]
#
#  block1_conv1 (Conv2D)          (None, 49, 49, 32)   864         ['input_7[0][0]']
#
#  block1_conv1_bn (BatchNormaliz  (None, 49, 49, 32)  128         ['block1_conv1[0][0]']
#  ation)
#
#  block1_conv1_act (Activation)  (None, 49, 49, 32)   0           ['block1_conv1_bn[0][0]']
#
#  block1_conv2 (Conv2D)          (None, 47, 47, 64)   18432       ['block1_conv1_act[0][0]']
#
#  block1_conv2_bn (BatchNormaliz  (None, 47, 47, 64)  256         ['block1_conv2[0][0]']
#  ation)
#
#  block1_conv2_act (Activation)  (None, 47, 47, 64)   0           ['block1_conv2_bn[0][0]']
#
#  block2_sepconv1 (SeparableConv  (None, 47, 47, 128)  8768       ['block1_conv2_act[0][0]']
#  2D)
#
#  block2_sepconv1_bn (BatchNorma  (None, 47, 47, 128)  512        ['block2_sepconv1[0][0]']
#  lization)
#
#  block2_sepconv2_act (Activatio  (None, 47, 47, 128)  0          ['block2_sepconv1_bn[0][0]']
#  n)
#
#  block2_sepconv2 (SeparableConv  (None, 47, 47, 128)  17536      ['block2_sepconv2_act[0][0]']
#  2D)
#
#  block2_sepconv2_bn (BatchNorma  (None, 47, 47, 128)  512        ['block2_sepconv2[0][0]']
#  lization)
#
#  conv2d_206 (Conv2D)            (None, 24, 24, 128)  8192        ['block1_conv2_act[0][0]']
#
#  block2_pool (MaxPooling2D)     (None, 24, 24, 128)  0           ['block2_sepconv2_bn[0][0]']
#
#  batch_normalization_203 (Batch  (None, 24, 24, 128)  512        ['conv2d_206[0][0]']
#  Normalization)
#
#  add (Add)                      (None, 24, 24, 128)  0           ['block2_pool[0][0]',
#                                                                   'batch_normalization_203[0][0]']
#
#  block3_sepconv1_act (Activatio  (None, 24, 24, 128)  0          ['add[0][0]']
#  n)
#
#  block3_sepconv1 (SeparableConv  (None, 24, 24, 256)  33920      ['block3_sepconv1_act[0][0]']
#  2D)
#
#  block3_sepconv1_bn (BatchNorma  (None, 24, 24, 256)  1024       ['block3_sepconv1[0][0]']
#  lization)
#
#  block3_sepconv2_act (Activatio  (None, 24, 24, 256)  0          ['block3_sepconv1_bn[0][0]']
#  n)
#
#  block3_sepconv2 (SeparableConv  (None, 24, 24, 256)  67840      ['block3_sepconv2_act[0][0]']
#  2D)
#
#  block3_sepconv2_bn (BatchNorma  (None, 24, 24, 256)  1024       ['block3_sepconv2[0][0]']
#  lization)
#
#  conv2d_207 (Conv2D)            (None, 12, 12, 256)  32768       ['add[0][0]']
#
#  block3_pool (MaxPooling2D)     (None, 12, 12, 256)  0           ['block3_sepconv2_bn[0][0]']
#
#  batch_normalization_204 (Batch  (None, 12, 12, 256)  1024       ['conv2d_207[0][0]']
#  Normalization)
#
#  add_1 (Add)                    (None, 12, 12, 256)  0           ['block3_pool[0][0]',
#                                                                   'batch_normalization_204[0][0]']
#
#  block4_sepconv1_act (Activatio  (None, 12, 12, 256)  0          ['add_1[0][0]']
#  n)
#
#  block4_sepconv1 (SeparableConv  (None, 12, 12, 728)  188672     ['block4_sepconv1_act[0][0]']
#  2D)
#
#  block4_sepconv1_bn (BatchNorma  (None, 12, 12, 728)  2912       ['block4_sepconv1[0][0]']
#  lization)
#
#  block4_sepconv2_act (Activatio  (None, 12, 12, 728)  0          ['block4_sepconv1_bn[0][0]']
#  n)
#
#  block4_sepconv2 (SeparableConv  (None, 12, 12, 728)  536536     ['block4_sepconv2_act[0][0]']
#  2D)
#
#  block4_sepconv2_bn (BatchNorma  (None, 12, 12, 728)  2912       ['block4_sepconv2[0][0]']
#  lization)
#
#  conv2d_208 (Conv2D)            (None, 6, 6, 728)    186368      ['add_1[0][0]']
#
#  block4_pool (MaxPooling2D)     (None, 6, 6, 728)    0           ['block4_sepconv2_bn[0][0]']
#
#  batch_normalization_205 (Batch  (None, 6, 6, 728)   2912        ['conv2d_208[0][0]']
#  Normalization)
#
#  add_2 (Add)                    (None, 6, 6, 728)    0           ['block4_pool[0][0]',
#                                                                   'batch_normalization_205[0][0]']
#
#  block5_sepconv1_act (Activatio  (None, 6, 6, 728)   0           ['add_2[0][0]']
#  n)
#
#  block5_sepconv1 (SeparableConv  (None, 6, 6, 728)   536536      ['block5_sepconv1_act[0][0]']
#  2D)
#
#  block5_sepconv1_bn (BatchNorma  (None, 6, 6, 728)   2912        ['block5_sepconv1[0][0]']
#  lization)
#
#  block5_sepconv2_act (Activatio  (None, 6, 6, 728)   0           ['block5_sepconv1_bn[0][0]']
#  n)
#
#  block5_sepconv2 (SeparableConv  (None, 6, 6, 728)   536536      ['block5_sepconv2_act[0][0]']
#  2D)
#
#  block5_sepconv2_bn (BatchNorma  (None, 6, 6, 728)   2912        ['block5_sepconv2[0][0]']
#  lization)
#
#  block5_sepconv3_act (Activatio  (None, 6, 6, 728)   0           ['block5_sepconv2_bn[0][0]']
#  n)
#
#  block5_sepconv3 (SeparableConv  (None, 6, 6, 728)   536536      ['block5_sepconv3_act[0][0]']
#  2D)
#
#  block5_sepconv3_bn (BatchNorma  (None, 6, 6, 728)   2912        ['block5_sepconv3[0][0]']
#  lization)
#
#  add_3 (Add)                    (None, 6, 6, 728)    0           ['block5_sepconv3_bn[0][0]',
#                                                                   'add_2[0][0]']
#
#  block6_sepconv1_act (Activatio  (None, 6, 6, 728)   0           ['add_3[0][0]']
#  n)
#
#  block6_sepconv1 (SeparableConv  (None, 6, 6, 728)   536536      ['block6_sepconv1_act[0][0]']
#  2D)
#
#  block6_sepconv1_bn (BatchNorma  (None, 6, 6, 728)   2912        ['block6_sepconv1[0][0]']
#  lization)
#
#  block6_sepconv2_act (Activatio  (None, 6, 6, 728)   0           ['block6_sepconv1_bn[0][0]']
#  n)
#
#  block6_sepconv2 (SeparableConv  (None, 6, 6, 728)   536536      ['block6_sepconv2_act[0][0]']
#  2D)
#
#  block6_sepconv2_bn (BatchNorma  (None, 6, 6, 728)   2912        ['block6_sepconv2[0][0]']
#  lization)
#
#  block6_sepconv3_act (Activatio  (None, 6, 6, 728)   0           ['block6_sepconv2_bn[0][0]']
#  n)
#
#  block6_sepconv3 (SeparableConv  (None, 6, 6, 728)   536536      ['block6_sepconv3_act[0][0]']
#  2D)
#
#  block6_sepconv3_bn (BatchNorma  (None, 6, 6, 728)   2912        ['block6_sepconv3[0][0]']
#  lization)
#
#  add_4 (Add)                    (None, 6, 6, 728)    0           ['block6_sepconv3_bn[0][0]',
#                                                                   'add_3[0][0]']
#
#  block7_sepconv1_act (Activatio  (None, 6, 6, 728)   0           ['add_4[0][0]']
#  n)
#
#  block7_sepconv1 (SeparableConv  (None, 6, 6, 728)   536536      ['block7_sepconv1_act[0][0]']
#  2D)
#
#  block7_sepconv1_bn (BatchNorma  (None, 6, 6, 728)   2912        ['block7_sepconv1[0][0]']
#  lization)
#
#  block7_sepconv2_act (Activatio  (None, 6, 6, 728)   0           ['block7_sepconv1_bn[0][0]']
#  n)
#
#  block7_sepconv2 (SeparableConv  (None, 6, 6, 728)   536536      ['block7_sepconv2_act[0][0]']
#  2D)
#
#  block7_sepconv2_bn (BatchNorma  (None, 6, 6, 728)   2912        ['block7_sepconv2[0][0]']
#  lization)
#
#  block7_sepconv3_act (Activatio  (None, 6, 6, 728)   0           ['block7_sepconv2_bn[0][0]']
#  n)
#
#  block7_sepconv3 (SeparableConv  (None, 6, 6, 728)   536536      ['block7_sepconv3_act[0][0]']
#  2D)
#
#  block7_sepconv3_bn (BatchNorma  (None, 6, 6, 728)   2912        ['block7_sepconv3[0][0]']
#  lization)
#
#  add_5 (Add)                    (None, 6, 6, 728)    0           ['block7_sepconv3_bn[0][0]',
#                                                                   'add_4[0][0]']
#
#  block8_sepconv1_act (Activatio  (None, 6, 6, 728)   0           ['add_5[0][0]']
#  n)
#
#  block8_sepconv1 (SeparableConv  (None, 6, 6, 728)   536536      ['block8_sepconv1_act[0][0]']
#  2D)
#
#  block8_sepconv1_bn (BatchNorma  (None, 6, 6, 728)   2912        ['block8_sepconv1[0][0]']
#  lization)
#
#  block8_sepconv2_act (Activatio  (None, 6, 6, 728)   0           ['block8_sepconv1_bn[0][0]']
#  n)
#
#  block8_sepconv2 (SeparableConv  (None, 6, 6, 728)   536536      ['block8_sepconv2_act[0][0]']
#  2D)
#
#  block8_sepconv2_bn (BatchNorma  (None, 6, 6, 728)   2912        ['block8_sepconv2[0][0]']
#  lization)
#
#  block8_sepconv3_act (Activatio  (None, 6, 6, 728)   0           ['block8_sepconv2_bn[0][0]']
#  n)
#
#  block8_sepconv3 (SeparableConv  (None, 6, 6, 728)   536536      ['block8_sepconv3_act[0][0]']
#  2D)
#
#  block8_sepconv3_bn (BatchNorma  (None, 6, 6, 728)   2912        ['block8_sepconv3[0][0]']
#  lization)
#
#  add_6 (Add)                    (None, 6, 6, 728)    0           ['block8_sepconv3_bn[0][0]',
#                                                                   'add_5[0][0]']
#
#  block9_sepconv1_act (Activatio  (None, 6, 6, 728)   0           ['add_6[0][0]']
#  n)
#
#  block9_sepconv1 (SeparableConv  (None, 6, 6, 728)   536536      ['block9_sepconv1_act[0][0]']
#  2D)
#
#  block9_sepconv1_bn (BatchNorma  (None, 6, 6, 728)   2912        ['block9_sepconv1[0][0]']
#  lization)
#
#  block9_sepconv2_act (Activatio  (None, 6, 6, 728)   0           ['block9_sepconv1_bn[0][0]']
#  n)
#
#  block9_sepconv2 (SeparableConv  (None, 6, 6, 728)   536536      ['block9_sepconv2_act[0][0]']
#  2D)
#
#  block9_sepconv2_bn (BatchNorma  (None, 6, 6, 728)   2912        ['block9_sepconv2[0][0]']
#  lization)
#
#  block9_sepconv3_act (Activatio  (None, 6, 6, 728)   0           ['block9_sepconv2_bn[0][0]']
#  n)
#
#  block9_sepconv3 (SeparableConv  (None, 6, 6, 728)   536536      ['block9_sepconv3_act[0][0]']
#  2D)
#
#  block9_sepconv3_bn (BatchNorma  (None, 6, 6, 728)   2912        ['block9_sepconv3[0][0]']
#  lization)
#
#  add_7 (Add)                    (None, 6, 6, 728)    0           ['block9_sepconv3_bn[0][0]',
#                                                                   'add_6[0][0]']
#
#  block10_sepconv1_act (Activati  (None, 6, 6, 728)   0           ['add_7[0][0]']
#  on)
#
#  block10_sepconv1 (SeparableCon  (None, 6, 6, 728)   536536      ['block10_sepconv1_act[0][0]']
#  v2D)
#
#  block10_sepconv1_bn (BatchNorm  (None, 6, 6, 728)   2912        ['block10_sepconv1[0][0]']
#  alization)
#
#  block10_sepconv2_act (Activati  (None, 6, 6, 728)   0           ['block10_sepconv1_bn[0][0]']
#  on)
#
#  block10_sepconv2 (SeparableCon  (None, 6, 6, 728)   536536      ['block10_sepconv2_act[0][0]']
#  v2D)
#
#  block10_sepconv2_bn (BatchNorm  (None, 6, 6, 728)   2912        ['block10_sepconv2[0][0]']
#  alization)
#
#  block10_sepconv3_act (Activati  (None, 6, 6, 728)   0           ['block10_sepconv2_bn[0][0]']
#  on)
#
#  block10_sepconv3 (SeparableCon  (None, 6, 6, 728)   536536      ['block10_sepconv3_act[0][0]']
#  v2D)
#
#  block10_sepconv3_bn (BatchNorm  (None, 6, 6, 728)   2912        ['block10_sepconv3[0][0]']
#  alization)
#
#  add_8 (Add)                    (None, 6, 6, 728)    0           ['block10_sepconv3_bn[0][0]',
#                                                                   'add_7[0][0]']
#
#  block11_sepconv1_act (Activati  (None, 6, 6, 728)   0           ['add_8[0][0]']
#  on)
#
#  block11_sepconv1 (SeparableCon  (None, 6, 6, 728)   536536      ['block11_sepconv1_act[0][0]']
#  v2D)
#
#  block11_sepconv1_bn (BatchNorm  (None, 6, 6, 728)   2912        ['block11_sepconv1[0][0]']
#  alization)
#
#  block11_sepconv2_act (Activati  (None, 6, 6, 728)   0           ['block11_sepconv1_bn[0][0]']
#  on)
#
#  block11_sepconv2 (SeparableCon  (None, 6, 6, 728)   536536      ['block11_sepconv2_act[0][0]']
#  v2D)
#
#  block11_sepconv2_bn (BatchNorm  (None, 6, 6, 728)   2912        ['block11_sepconv2[0][0]']
#  alization)
#
#  block11_sepconv3_act (Activati  (None, 6, 6, 728)   0           ['block11_sepconv2_bn[0][0]']
#  on)
#
#  block11_sepconv3 (SeparableCon  (None, 6, 6, 728)   536536      ['block11_sepconv3_act[0][0]']
#  v2D)
#
#  block11_sepconv3_bn (BatchNorm  (None, 6, 6, 728)   2912        ['block11_sepconv3[0][0]']
#  alization)
#
#  add_9 (Add)                    (None, 6, 6, 728)    0           ['block11_sepconv3_bn[0][0]',
#                                                                   'add_8[0][0]']
#
#  block12_sepconv1_act (Activati  (None, 6, 6, 728)   0           ['add_9[0][0]']
#  on)
#
#  block12_sepconv1 (SeparableCon  (None, 6, 6, 728)   536536      ['block12_sepconv1_act[0][0]']
#  v2D)
#
#  block12_sepconv1_bn (BatchNorm  (None, 6, 6, 728)   2912        ['block12_sepconv1[0][0]']
#  alization)
#
#  block12_sepconv2_act (Activati  (None, 6, 6, 728)   0           ['block12_sepconv1_bn[0][0]']
#  on)
#
#  block12_sepconv2 (SeparableCon  (None, 6, 6, 728)   536536      ['block12_sepconv2_act[0][0]']
#  v2D)
#
#  block12_sepconv2_bn (BatchNorm  (None, 6, 6, 728)   2912        ['block12_sepconv2[0][0]']
#  alization)
#
#  block12_sepconv3_act (Activati  (None, 6, 6, 728)   0           ['block12_sepconv2_bn[0][0]']
#  on)
#
#  block12_sepconv3 (SeparableCon  (None, 6, 6, 728)   536536      ['block12_sepconv3_act[0][0]']
#  v2D)
#
#  block12_sepconv3_bn (BatchNorm  (None, 6, 6, 728)   2912        ['block12_sepconv3[0][0]']
#  alization)
#
#  add_10 (Add)                   (None, 6, 6, 728)    0           ['block12_sepconv3_bn[0][0]',
#                                                                   'add_9[0][0]']
#
#  block13_sepconv1_act (Activati  (None, 6, 6, 728)   0           ['add_10[0][0]']
#  on)
#
#  block13_sepconv1 (SeparableCon  (None, 6, 6, 728)   536536      ['block13_sepconv1_act[0][0]']
#  v2D)
#
#  block13_sepconv1_bn (BatchNorm  (None, 6, 6, 728)   2912        ['block13_sepconv1[0][0]']
#  alization)
#
#  block13_sepconv2_act (Activati  (None, 6, 6, 728)   0           ['block13_sepconv1_bn[0][0]']
#  on)
#
#  block13_sepconv2 (SeparableCon  (None, 6, 6, 1024)  752024      ['block13_sepconv2_act[0][0]']
#  v2D)
#
#  block13_sepconv2_bn (BatchNorm  (None, 6, 6, 1024)  4096        ['block13_sepconv2[0][0]']
#  alization)
#
#  conv2d_209 (Conv2D)            (None, 3, 3, 1024)   745472      ['add_10[0][0]']
#
#  block13_pool (MaxPooling2D)    (None, 3, 3, 1024)   0           ['block13_sepconv2_bn[0][0]']
#
#  batch_normalization_206 (Batch  (None, 3, 3, 1024)  4096        ['conv2d_209[0][0]']
#  Normalization)
#
#  add_11 (Add)                   (None, 3, 3, 1024)   0           ['block13_pool[0][0]',
#                                                                   'batch_normalization_206[0][0]']
#
#  block14_sepconv1 (SeparableCon  (None, 3, 3, 1536)  1582080     ['add_11[0][0]']
#  v2D)
#
#  block14_sepconv1_bn (BatchNorm  (None, 3, 3, 1536)  6144        ['block14_sepconv1[0][0]']
#  alization)
#
#  block14_sepconv1_act (Activati  (None, 3, 3, 1536)  0           ['block14_sepconv1_bn[0][0]']
#  on)
#
#  block14_sepconv2 (SeparableCon  (None, 3, 3, 2048)  3159552     ['block14_sepconv1_act[0][0]']
#  v2D)
#
#  block14_sepconv2_bn (BatchNorm  (None, 3, 3, 2048)  8192        ['block14_sepconv2[0][0]']
#  alization)
#
#  block14_sepconv2_act (Activati  (None, 3, 3, 2048)  0           ['block14_sepconv2_bn[0][0]']
#  on)
#
# ==================================================================================================
# Total params: 20,861,480
# Trainable params: 0
# Non-trainable params: 20,861,480
# __________________________________________________________________________________________________
# Model: "model_6"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_7 (InputLayer)           [(None, 100, 100, 3  0           []
#                                 )]
#
#  block1_conv1 (Conv2D)          (None, 49, 49, 32)   864         ['input_7[0][0]']
#
#  block1_conv1_bn (BatchNormaliz  (None, 49, 49, 32)  128         ['block1_conv1[0][0]']
#  ation)
#
#  block1_conv1_act (Activation)  (None, 49, 49, 32)   0           ['block1_conv1_bn[0][0]']
#
#  block1_conv2 (Conv2D)          (None, 47, 47, 64)   18432       ['block1_conv1_act[0][0]']
#
#  block1_conv2_bn (BatchNormaliz  (None, 47, 47, 64)  256         ['block1_conv2[0][0]']
#  ation)
#
#  block1_conv2_act (Activation)  (None, 47, 47, 64)   0           ['block1_conv2_bn[0][0]']
#
#  block2_sepconv1 (SeparableConv  (None, 47, 47, 128)  8768       ['block1_conv2_act[0][0]']
#  2D)
#
#  block2_sepconv1_bn (BatchNorma  (None, 47, 47, 128)  512        ['block2_sepconv1[0][0]']
#  lization)
#
#  block2_sepconv2_act (Activatio  (None, 47, 47, 128)  0          ['block2_sepconv1_bn[0][0]']
#  n)
#
#  block2_sepconv2 (SeparableConv  (None, 47, 47, 128)  17536      ['block2_sepconv2_act[0][0]']
#  2D)
#
#  block2_sepconv2_bn (BatchNorma  (None, 47, 47, 128)  512        ['block2_sepconv2[0][0]']
#  lization)
#
#  conv2d_206 (Conv2D)            (None, 24, 24, 128)  8192        ['block1_conv2_act[0][0]']
#
#  block2_pool (MaxPooling2D)     (None, 24, 24, 128)  0           ['block2_sepconv2_bn[0][0]']
#
#  batch_normalization_203 (Batch  (None, 24, 24, 128)  512        ['conv2d_206[0][0]']
#  Normalization)
#
#  add (Add)                      (None, 24, 24, 128)  0           ['block2_pool[0][0]',
#                                                                   'batch_normalization_203[0][0]']
#
#  block3_sepconv1_act (Activatio  (None, 24, 24, 128)  0          ['add[0][0]']
#  n)
#
#  block3_sepconv1 (SeparableConv  (None, 24, 24, 256)  33920      ['block3_sepconv1_act[0][0]']
#  2D)
#
#  block3_sepconv1_bn (BatchNorma  (None, 24, 24, 256)  1024       ['block3_sepconv1[0][0]']
#  lization)
#
#  block3_sepconv2_act (Activatio  (None, 24, 24, 256)  0          ['block3_sepconv1_bn[0][0]']
#  n)
#
#  block3_sepconv2 (SeparableConv  (None, 24, 24, 256)  67840      ['block3_sepconv2_act[0][0]']
#  2D)
#
#  block3_sepconv2_bn (BatchNorma  (None, 24, 24, 256)  1024       ['block3_sepconv2[0][0]']
#  lization)
#
#  conv2d_207 (Conv2D)            (None, 12, 12, 256)  32768       ['add[0][0]']
#
#  block3_pool (MaxPooling2D)     (None, 12, 12, 256)  0           ['block3_sepconv2_bn[0][0]']
#
#  batch_normalization_204 (Batch  (None, 12, 12, 256)  1024       ['conv2d_207[0][0]']
#  Normalization)
#
#  add_1 (Add)                    (None, 12, 12, 256)  0           ['block3_pool[0][0]',
#                                                                   'batch_normalization_204[0][0]']
#
#  block4_sepconv1_act (Activatio  (None, 12, 12, 256)  0          ['add_1[0][0]']
#  n)
#
#  block4_sepconv1 (SeparableConv  (None, 12, 12, 728)  188672     ['block4_sepconv1_act[0][0]']
#  2D)
#
#  block4_sepconv1_bn (BatchNorma  (None, 12, 12, 728)  2912       ['block4_sepconv1[0][0]']
#  lization)
#
#  block4_sepconv2_act (Activatio  (None, 12, 12, 728)  0          ['block4_sepconv1_bn[0][0]']
#  n)
#
#  block4_sepconv2 (SeparableConv  (None, 12, 12, 728)  536536     ['block4_sepconv2_act[0][0]']
#  2D)
#
#  block4_sepconv2_bn (BatchNorma  (None, 12, 12, 728)  2912       ['block4_sepconv2[0][0]']
#  lization)
#
#  conv2d_208 (Conv2D)            (None, 6, 6, 728)    186368      ['add_1[0][0]']
#
#  block4_pool (MaxPooling2D)     (None, 6, 6, 728)    0           ['block4_sepconv2_bn[0][0]']
# ...
#  block12_sepconv1 (SeparableCon  (None, 6, 6, 728)   536536      ['block12_sepconv1_act[0][0]']
#  v2D)
#
#  block12_sepconv1_bn (BatchNorm  (None, 6, 6, 728)   2912        ['block12_sepconv1[0][0]']
#  alization)
#
#  block12_sepconv2_act (Activati  (None, 6, 6, 728)   0           ['block12_sepconv1_bn[0][0]']
#  on)
#
#  block12_sepconv2 (SeparableCon  (None, 6, 6, 728)   536536      ['block12_sepconv2_act[0][0]']
#  v2D)
#
#  block12_sepconv2_bn (BatchNorm  (None, 6, 6, 728)   2912        ['block12_sepconv2[0][0]']
#  alization)
#
#  block12_sepconv3_act (Activati  (None, 6, 6, 728)   0           ['block12_sepconv2_bn[0][0]']
#  on)
#
#  block12_sepconv3 (SeparableCon  (None, 6, 6, 728)   536536      ['block12_sepconv3_act[0][0]']
#  v2D)
#
#  block12_sepconv3_bn (BatchNorm  (None, 6, 6, 728)   2912        ['block12_sepconv3[0][0]']
#  alization)
#
#  add_10 (Add)                   (None, 6, 6, 728)    0           ['block12_sepconv3_bn[0][0]',
#                                                                   'add_9[0][0]']
#
#  block13_sepconv1_act (Activati  (None, 6, 6, 728)   0           ['add_10[0][0]']
#  on)
#
#  block13_sepconv1 (SeparableCon  (None, 6, 6, 728)   536536      ['block13_sepconv1_act[0][0]']
#  v2D)
#
#  block13_sepconv1_bn (BatchNorm  (None, 6, 6, 728)   2912        ['block13_sepconv1[0][0]']
#  alization)
#
#  block13_sepconv2_act (Activati  (None, 6, 6, 728)   0           ['block13_sepconv1_bn[0][0]']
#  on)
#
#  block13_sepconv2 (SeparableCon  (None, 6, 6, 1024)  752024      ['block13_sepconv2_act[0][0]']
#  v2D)
#
#  block13_sepconv2_bn (BatchNorm  (None, 6, 6, 1024)  4096        ['block13_sepconv2[0][0]']
#  alization)
#
#  conv2d_209 (Conv2D)            (None, 3, 3, 1024)   745472      ['add_10[0][0]']
#
#  block13_pool (MaxPooling2D)    (None, 3, 3, 1024)   0           ['block13_sepconv2_bn[0][0]']
#
#  batch_normalization_206 (Batch  (None, 3, 3, 1024)  4096        ['conv2d_209[0][0]']
#  Normalization)
#
#  add_11 (Add)                   (None, 3, 3, 1024)   0           ['block13_pool[0][0]',
#                                                                   'batch_normalization_206[0][0]']
#
#  block14_sepconv1 (SeparableCon  (None, 3, 3, 1536)  1582080     ['add_11[0][0]']
#  v2D)
#
#  block14_sepconv1_bn (BatchNorm  (None, 3, 3, 1536)  6144        ['block14_sepconv1[0][0]']
#  alization)
#
#  block14_sepconv1_act (Activati  (None, 3, 3, 1536)  0           ['block14_sepconv1_bn[0][0]']
#  on)
#
#  block14_sepconv2 (SeparableCon  (None, 3, 3, 2048)  3159552     ['block14_sepconv1_act[0][0]']
#  v2D)
#
#  block14_sepconv2_bn (BatchNorm  (None, 3, 3, 2048)  8192        ['block14_sepconv2[0][0]']
#  alization)
#
#  block14_sepconv2_act (Activati  (None, 3, 3, 2048)  0           ['block14_sepconv2_bn[0][0]']
#  on)
#
#  flatten_7 (Flatten)            (None, 18432)        0           ['block14_sepconv2_act[0][0]']
#
#  fc1 (Dense)                    (None, 1000)         18433000    ['flatten_7[0][0]']
#
#  dropout_10 (Dropout)           (None, 1000)         0           ['fc1[0][0]']
#
#  predictions (Dense)            (None, 5)            5005        ['dropout_10[0][0]']
#
# ==================================================================================================
# Total params: 39,299,485
# Trainable params: 18,438,005
# Non-trainable params: 20,861,480
# __________________________________________________________________________________________________
# Epoch 1/100
# 5/5 [==============================] - 21s 4s/step - loss: 1.3711 - accuracy: 0.4531 - val_loss: 0.8630 - val_accuracy: 0.7500
# Epoch 2/100
# 5/5 [==============================] - 14s 3s/step - loss: 0.5212 - accuracy: 0.8719 - val_loss: 0.7052 - val_accuracy: 0.7750
# Epoch 3/100
# 5/5 [==============================] - 14s 3s/step - loss: 0.2808 - accuracy: 0.9312 - val_loss: 0.6787 - val_accuracy: 0.8250
# Epoch 4/100
# 5/5 [==============================] - 14s 3s/step - loss: 0.1919 - accuracy: 0.9563 - val_loss: 0.6112 - val_accuracy: 0.8250
# Epoch 5/100
# 5/5 [==============================] - 14s 3s/step - loss: 0.1239 - accuracy: 0.9781 - val_loss: 0.5743 - val_accuracy: 0.8375
# Epoch 6/100
# 5/5 [==============================] - 14s 3s/step - loss: 0.0987 - accuracy: 0.9844 - val_loss: 0.5623 - val_accuracy: 0.8375
# Epoch 7/100
# 5/5 [==============================] - 14s 3s/step - loss: 0.0726 - accuracy: 0.9875 - val_loss: 0.5363 - val_accuracy: 0.8625
# Epoch 8/100
# 5/5 [==============================] - 14s 3s/step - loss: 0.0597 - accuracy: 0.9969 - val_loss: 0.5289 - val_accuracy: 0.8625
# Epoch 9/100
# 5/5 [==============================] - 14s 3s/step - loss: 0.0481 - accuracy: 0.9969 - val_loss: 0.5339 - val_accuracy: 0.8625
# Epoch 10/100
# 5/5 [==============================] - 15s 3s/step - loss: 0.0375 - accuracy: 1.0000 - val_loss: 0.5408 - val_accuracy: 0.8500
# Epoch 11/100
# 5/5 [==============================] - 14s 3s/step - loss: 0.0306 - accuracy: 1.0000 - val_loss: 0.5312 - val_accuracy: 0.8500
# Epoch 12/100
# 5/5 [==============================] - 14s 3s/step - loss: 0.0285 - accuracy: 1.0000 - val_loss: 0.5091 - val_accuracy: 0.8750
# Epoch 13/100
# 5/5 [==============================] - 14s 3s/step - loss: 0.0237 - accuracy: 1.0000 - val_loss: 0.4977 - val_accuracy: 0.8625
# Epoch 14/100
# 5/5 [==============================] - 14s 3s/step - loss: 0.0206 - accuracy: 1.0000 - val_loss: 0.4822 - val_accuracy: 0.8625
# Epoch 15/100
# 5/5 [==============================] - 14s 3s/step - loss: 0.0177 - accuracy: 1.0000 - val_loss: 0.4762 - val_accuracy: 0.8625
# Epoch 16/100
# 5/5 [==============================] - 14s 3s/step - loss: 0.0173 - accuracy: 1.0000 - val_loss: 0.5142 - val_accuracy: 0.8625
# Epoch 17/100
# 5/5 [==============================] - 14s 3s/step - loss: 0.0149 - accuracy: 1.0000 - val_loss: 0.5361 - val_accuracy: 0.8625
# Epoch 18/100
# 5/5 [==============================] - 15s 3s/step - loss: 0.0147 - accuracy: 1.0000 - val_loss: 0.5211 - val_accuracy: 0.8500
# Epoch 19/100
# 5/5 [==============================] - 14s 3s/step - loss: 0.0126 - accuracy: 1.0000 - val_loss: 0.4991 - val_accuracy: 0.8500
# Epoch 20/100
# 5/5 [==============================] - 14s 3s/step - loss: 0.0112 - accuracy: 1.0000 - val_loss: 0.4861 - val_accuracy: 0.8625
# Epoch 21/100
# 5/5 [==============================] - 14s 3s/step - loss: 0.0102 - accuracy: 1.0000 - val_loss: 0.4749 - val_accuracy: 0.8750
# Epoch 22/100
# 5/5 [==============================] - 14s 3s/step - loss: 0.0094 - accuracy: 1.0000 - val_loss: 0.4671 - val_accuracy: 0.8875
# Epoch 23/100
# 5/5 [==============================] - 14s 3s/step - loss: 0.0083 - accuracy: 1.0000 - val_loss: 0.4673 - val_accuracy: 0.8875
# Epoch 24/100
# 5/5 [==============================] - 14s 3s/step - loss: 0.0083 - accuracy: 1.0000 - val_loss: 0.4724 - val_accuracy: 0.8875
# Epoch 25/100
# 5/5 [==============================] - 14s 3s/step - loss: 0.0086 - accuracy: 1.0000 - val_loss: 0.4820 - val_accuracy: 0.8750
# Epoch 26/100
# 5/5 [==============================] - 14s 3s/step - loss: 0.0077 - accuracy: 1.0000 - val_loss: 0.5008 - val_accuracy: 0.8750
# Epoch 27/100
# 5/5 [==============================] - 14s 3s/step - loss: 0.0073 - accuracy: 1.0000 - val_loss: 0.5109 - val_accuracy: 0.8750
# Epoch 28/100
# 5/5 [==============================] - 14s 3s/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 0.5132 - val_accuracy: 0.8750
# Epoch 29/100
# 5/5 [==============================] - 14s 3s/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.5127 - val_accuracy: 0.8875
# Epoch 30/100
# 5/5 [==============================] - 14s 3s/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.5130 - val_accuracy: 0.8750
# Epoch 31/100
# 5/5 [==============================] - 14s 3s/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.5086 - val_accuracy: 0.8750
# Epoch 32/100
# 5/5 [==============================] - 14s 3s/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.5022 - val_accuracy: 0.8625
# Epoch 33/100
# 5/5 [==============================] - 14s 3s/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.4990 - val_accuracy: 0.8625
# Epoch 34/100
# 5/5 [==============================] - 14s 3s/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.4984 - val_accuracy: 0.8625
# Epoch 35/100
# 5/5 [==============================] - 14s 3s/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.4985 - val_accuracy: 0.8875
# Epoch 36/100
# 5/5 [==============================] - 14s 3s/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.5000 - val_accuracy: 0.8750
# Epoch 37/100
# 5/5 [==============================] - 14s 3s/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.5375 - val_accuracy: 0.8625
# Epoch 38/100
# 5/5 [==============================] - 14s 3s/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.5569 - val_accuracy: 0.8500
# Epoch 39/100
# 5/5 [==============================] - 14s 3s/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.5528 - val_accuracy: 0.8500
# Epoch 40/100
# 5/5 [==============================] - 14s 3s/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.5343 - val_accuracy: 0.8500
# Epoch 41/100
# 5/5 [==============================] - 14s 3s/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.5210 - val_accuracy: 0.8750
# Epoch 42/100
# 5/5 [==============================] - 14s 3s/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.5144 - val_accuracy: 0.8750
# Epoch 43/100
# 5/5 [==============================] - 14s 3s/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.5094 - val_accuracy: 0.8750
# Epoch 44/100
# 5/5 [==============================] - 14s 3s/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.5089 - val_accuracy: 0.8750
# Epoch 45/100
# 5/5 [==============================] - 14s 3s/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.5107 - val_accuracy: 0.8750
# Epoch 46/100
# 5/5 [==============================] - 14s 3s/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.5353 - val_accuracy: 0.8500
# Epoch 47/100
# 5/5 [==============================] - 15s 3s/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.5534 - val_accuracy: 0.8500
# Epoch 48/100
# 5/5 [==============================] - 15s 3s/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.5584 - val_accuracy: 0.8500
# Epoch 49/100
# 5/5 [==============================] - 14s 3s/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.5526 - val_accuracy: 0.8500
# Epoch 50/100
# 5/5 [==============================] - 14s 3s/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.5386 - val_accuracy: 0.8500
# Epoch 51/100
# 5/5 [==============================] - 15s 3s/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.5266 - val_accuracy: 0.8875
# Epoch 52/100
# 5/5 [==============================] - 14s 3s/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.5168 - val_accuracy: 0.8875
# Epoch 53/100
# 5/5 [==============================] - 14s 3s/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.5128 - val_accuracy: 0.8875
# Epoch 54/100
# 5/5 [==============================] - 14s 3s/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.5139 - val_accuracy: 0.8875
# Epoch 55/100
# 5/5 [==============================] - 15s 3s/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.5140 - val_accuracy: 0.8750

# %%
acc = grado_train_dropout.history['accuracy']
val_acc = grado_train_dropout.history['val_accuracy']

loss = grado_train_dropout.history['loss']
val_loss = grado_train_dropout.history['val_loss']

plt.figure(figsize=(10, 10))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Exactitud Entrenamiento ')
plt.plot(val_acc, label='Exactitud Validación')
plt.legend(loc='lower right')
plt.ylabel('Exactitud')
plt.ylim([min(plt.ylim()),1])
plt.title('Exactitud Entrenamiento y Validación ')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Pérdida Entrenamiento')
plt.plot(val_loss, label='Pérdida Validación')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,1.0])
plt.title(' Pérdida Entrenamiento y Validación ')
plt.xlabel('epoch')
plt.show()

# %%
test_eval = model_out_Xception.evaluate(x_test, test_Y_one_hot, verbose=1)

print('Test loss:', test_eval[0])
print('Test accuracy:', test_eval[1])

predicted_classes = model_out_Xception.predict(x_test)
predicted_classes = np.argmax(np.round(predicted_classes),axis=1)
predicted_classes.shape, y_test.shape
# Out:
# 4/4 [==============================] - 4s 853ms/step - loss: 0.4783 - accuracy: 0.8500
# Test loss: 0.47826331853866577
# Test accuracy: 0.8500000238418579
# ((100,), (100,))

# %%
from sklearn.metrics import classification_report
target_names = ["Class {}".format(i) for i in range(nClasses)]
print(classification_report(y_test, predicted_classes, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#      Class 0       0.77      0.81      0.79        21
#      Class 1       0.81      0.68      0.74        19
#      Class 2       0.76      0.94      0.84        17
#      Class 3       0.91      0.91      0.91        23
#      Class 4       1.00      0.90      0.95        20
#
#     accuracy                           0.85       100
#    macro avg       0.85      0.85      0.85       100
# weighted avg       0.86      0.85      0.85       100

# %%
from sklearn.metrics import confusion_matrix

matriz=confusion_matrix(y_test, predicted_classes)
print(matriz)
# Out:
# [[17  3  1  0  0]
#  [ 4 13  2  0  0]
#  [ 1  0 16  0  0]
#  [ 0  0  2 21  0]
#  [ 0  0  0  2 18]]

# %%
import numpy as np
import cv2
import glob
import os
import matplotlib.pyplot as plt
import string
from mlxtend.plotting import plot_decision_regions
#from mpl_toolkits.mplot3d import Axes3D
#from sklearn.decomposition import PCA
#from sklearn.preprocessing import StandardScaler
#from sklearn.neighbors import KNeighborsClassifier
#from sklearn.tree import DecisionTreeClassifier
#from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.utils.multiclass import unique_labels
from sklearn import metrics
#from sklearn.svm import SVC


import json
from skimage import color
from skimage.feature import hog
#from sklearn import svm
from sklearn.metrics import classification_report,accuracy_score, recall_score
from subprocess import check_output

def plot_confusion_matrix(y_true, y_pred, classes,
                          normalize=False,
                          title=None,
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if not title:
        if normalize:
            title = 'Matriz de confusión'
        else:
            title = 'Matriz de confusión, sin normalización'

    # Compute confusion matrix

    cm = metrics.confusion_matrix(y_true, y_pred)
    # Only use the labels that appear in the data
    classes = unique_labels(y_true, y_pred)
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    fig, ax = plt.subplots()
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    # We want to show all ticks...

    ax.set(xticks=np.arange(cm.shape[1]),
           yticks=np.arange(cm.shape[0]),
           # ... and label them with the respective list entries
           xticklabels=labels, yticklabels=labels,
           title=title,
           ylabel='Etiqueta verdadera',
           xlabel='Etiqueta prevista')

    # Rotate the tick labels and set their alignment.

    plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
             rotation_mode="anchor")

    # Loop over data dimensions and create text annotations.

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], fmt),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")
    fig.tight_layout()
    return cm,ax

precision=metrics.accuracy_score(y_test,predicted_classes, normalize=False)

print("muestras:{0:.2f}".format(precision))
cm,_=plot_confusion_matrix(y_test,predicted_classes,classes=nClasses,normalize=False,title="Matriz de confusión no nomalizada")
plt.show()


precision=metrics.accuracy_score(y_test,predicted_classes, normalize=True)*100

print("Accuracy:{0:.2f}%".format(precision))
cm,_=plot_confusion_matrix(y_test,predicted_classes,classes=nClasses,normalize=True,title="Matriz de confusión normalizada")
plt.show()
# Out:
# muestras:85.00
# Accuracy:85.00%

# %%
model_out_Xception.save("/content/drive/My Drive/source_dir/gradoma_final_xception.h5py")
# Out:
# INFO:tensorflow:Assets written to: /content/drive/My Drive/source_dir/gradoma_final_xception.h5py/assets
# /usr/local/lib/python3.7/dist-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# /usr/local/lib/python3.7/dist-packages/keras/saving/saved_model/layer_serialization.py:112: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   return generic_utils.serialize_keras_object(obj)

# %% [markdown]
# MODELO RESNET50

# %%
#preprocess_input = tf.keras.applications.ResNet50.preprocess_input
rescale = tf.keras.layers.experimental.preprocessing.Rescaling(1./127.5, offset= -1)
IMG_SIZE = (100, 100)
img_height=100
img_width=100

IMG_SHAPE = IMG_SIZE + (3,)
base_model_resnet50 = tf.keras.applications.ResNet50(input_shape=IMG_SHAPE,
                                               include_top=False,
                                               weights='imagenet')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 1s 0us/step
# 94781440/94765736 [==============================] - 1s 0us/step

# %%
base_model_resnet50.trainable = False

base_model_resnet50.summary()
for layer in base_model_resnet50.layers:
           if layer.name == 'block5_conv1':
              break
           layer.trainable = False
# We add our classificator (top_model) to the last layer of the model
last = base_model_resnet50.layers[-1].output
x = Flatten()(last)
x = Dense(1000, activation='relu', name='fc1')(x)
x = Dropout(0.3)(x)
x = Dense(5, activation='softmax', name='predictions')(x)
model_out_resnet50 = Model(base_model_resnet50.input, x)
#We compile the model
#We compile the model
model_out_resnet50.compile(loss=keras.losses.categorical_crossentropy, optimizer=tf.keras.optimizers.Adam(learning_rate=INIT_LR, decay=INIT_LR / 100),metrics=['accuracy'])
model_out_resnet50.summary()
callback = tf.keras.callbacks.EarlyStopping(monitor='loss', min_delta=0.0001, patience=3)

grado_train_dropout = model_out_resnet50.fit(train_x, train_label, batch_size=batch_size,epochs=epochs,verbose=1,validation_data=(valid_X, valid_label),callbacks=[callback])
# Out:
# Model: "resnet50"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_8 (InputLayer)           [(None, 100, 100, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 106, 106, 3)  0           ['input_8[0][0]']
#
#  conv1_conv (Conv2D)            (None, 50, 50, 64)   9472        ['conv1_pad[0][0]']
#
#  conv1_bn (BatchNormalization)  (None, 50, 50, 64)   256         ['conv1_conv[0][0]']
#
#  conv1_relu (Activation)        (None, 50, 50, 64)   0           ['conv1_bn[0][0]']
#
#  pool1_pad (ZeroPadding2D)      (None, 52, 52, 64)   0           ['conv1_relu[0][0]']
#
#  pool1_pool (MaxPooling2D)      (None, 25, 25, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2D)   (None, 25, 25, 64)   4160        ['pool1_pool[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 25, 25, 64)  256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 25, 25, 64)  0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 25, 25, 64)   36928       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 25, 25, 64)  256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 25, 25, 64)  0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 25, 25, 256)  16640       ['pool1_pool[0][0]']
#
#  conv2_block1_3_conv (Conv2D)   (None, 25, 25, 256)  16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 25, 25, 256)  1024       ['conv2_block1_0_conv[0][0]']
#  ization)
#
#  conv2_block1_3_bn (BatchNormal  (None, 25, 25, 256)  1024       ['conv2_block1_3_conv[0][0]']
#  ization)
#
#  conv2_block1_add (Add)         (None, 25, 25, 256)  0           ['conv2_block1_0_bn[0][0]',
#                                                                   'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activation)  (None, 25, 25, 256)  0           ['conv2_block1_add[0][0]']
#
#  conv2_block2_1_conv (Conv2D)   (None, 25, 25, 64)   16448       ['conv2_block1_out[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 25, 25, 64)  256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 25, 25, 64)  0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 25, 25, 64)   36928       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 25, 25, 64)  256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 25, 25, 64)  0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 25, 25, 256)  16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_3_bn (BatchNormal  (None, 25, 25, 256)  1024       ['conv2_block2_3_conv[0][0]']
#  ization)
#
#  conv2_block2_add (Add)         (None, 25, 25, 256)  0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activation)  (None, 25, 25, 256)  0           ['conv2_block2_add[0][0]']
#
#  conv2_block3_1_conv (Conv2D)   (None, 25, 25, 64)   16448       ['conv2_block2_out[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 25, 25, 64)  256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 25, 25, 64)  0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 25, 25, 64)   36928       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 25, 25, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 25, 25, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  conv2_block3_3_conv (Conv2D)   (None, 25, 25, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_3_bn (BatchNormal  (None, 25, 25, 256)  1024       ['conv2_block3_3_conv[0][0]']
#  ization)
#
#  conv2_block3_add (Add)         (None, 25, 25, 256)  0           ['conv2_block2_out[0][0]',
#                                                                   'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activation)  (None, 25, 25, 256)  0           ['conv2_block3_add[0][0]']
#
#  conv3_block1_1_conv (Conv2D)   (None, 13, 13, 128)  32896       ['conv2_block3_out[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 13, 13, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 13, 13, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 13, 13, 128)  147584      ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 13, 13, 128)  512        ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 13, 13, 128)  0          ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 13, 13, 512)  131584      ['conv2_block3_out[0][0]']
#
#  conv3_block1_3_conv (Conv2D)   (None, 13, 13, 512)  66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 13, 13, 512)  2048       ['conv3_block1_0_conv[0][0]']
#  ization)
#
#  conv3_block1_3_bn (BatchNormal  (None, 13, 13, 512)  2048       ['conv3_block1_3_conv[0][0]']
#  ization)
#
#  conv3_block1_add (Add)         (None, 13, 13, 512)  0           ['conv3_block1_0_bn[0][0]',
#                                                                   'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activation)  (None, 13, 13, 512)  0           ['conv3_block1_add[0][0]']
#
#  conv3_block2_1_conv (Conv2D)   (None, 13, 13, 128)  65664       ['conv3_block1_out[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 13, 13, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 13, 13, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 13, 13, 128)  147584      ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 13, 13, 128)  512        ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 13, 13, 128)  0          ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 13, 13, 512)  66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_3_bn (BatchNormal  (None, 13, 13, 512)  2048       ['conv3_block2_3_conv[0][0]']
#  ization)
#
#  conv3_block2_add (Add)         (None, 13, 13, 512)  0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activation)  (None, 13, 13, 512)  0           ['conv3_block2_add[0][0]']
#
#  conv3_block3_1_conv (Conv2D)   (None, 13, 13, 128)  65664       ['conv3_block2_out[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 13, 13, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 13, 13, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 13, 13, 128)  147584      ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 13, 13, 128)  512        ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 13, 13, 128)  0          ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 13, 13, 512)  66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_3_bn (BatchNormal  (None, 13, 13, 512)  2048       ['conv3_block3_3_conv[0][0]']
#  ization)
#
#  conv3_block3_add (Add)         (None, 13, 13, 512)  0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activation)  (None, 13, 13, 512)  0           ['conv3_block3_add[0][0]']
#
#  conv3_block4_1_conv (Conv2D)   (None, 13, 13, 128)  65664       ['conv3_block3_out[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 13, 13, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 13, 13, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 13, 13, 128)  147584      ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 13, 13, 128)  512        ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 13, 13, 128)  0          ['conv3_block4_2_bn[0][0]']
#  n)
#
#  conv3_block4_3_conv (Conv2D)   (None, 13, 13, 512)  66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_3_bn (BatchNormal  (None, 13, 13, 512)  2048       ['conv3_block4_3_conv[0][0]']
#  ization)
#
#  conv3_block4_add (Add)         (None, 13, 13, 512)  0           ['conv3_block3_out[0][0]',
#                                                                   'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activation)  (None, 13, 13, 512)  0           ['conv3_block4_add[0][0]']
#
#  conv4_block1_1_conv (Conv2D)   (None, 7, 7, 256)    131328      ['conv3_block4_out[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 7, 7, 256)   1024        ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 7, 7, 256)   0           ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 7, 7, 256)    590080      ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 7, 7, 256)   1024        ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 7, 7, 256)   0           ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 7, 7, 1024)   525312      ['conv3_block4_out[0][0]']
#
#  conv4_block1_3_conv (Conv2D)   (None, 7, 7, 1024)   263168      ['conv4_block1_2_relu[0][0]']
#
#  conv4_block1_0_bn (BatchNormal  (None, 7, 7, 1024)  4096        ['conv4_block1_0_conv[0][0]']
#  ization)
#
#  conv4_block1_3_bn (BatchNormal  (None, 7, 7, 1024)  4096        ['conv4_block1_3_conv[0][0]']
#  ization)
#
#  conv4_block1_add (Add)         (None, 7, 7, 1024)   0           ['conv4_block1_0_bn[0][0]',
#                                                                   'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activation)  (None, 7, 7, 1024)   0           ['conv4_block1_add[0][0]']
#
#  conv4_block2_1_conv (Conv2D)   (None, 7, 7, 256)    262400      ['conv4_block1_out[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 7, 7, 256)   1024        ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 7, 7, 256)   0           ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 7, 7, 256)    590080      ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 7, 7, 256)   1024        ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 7, 7, 256)   0           ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 7, 7, 1024)   263168      ['conv4_block2_2_relu[0][0]']
#
#  conv4_block2_3_bn (BatchNormal  (None, 7, 7, 1024)  4096        ['conv4_block2_3_conv[0][0]']
#  ization)
#
#  conv4_block2_add (Add)         (None, 7, 7, 1024)   0           ['conv4_block1_out[0][0]',
#                                                                   'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activation)  (None, 7, 7, 1024)   0           ['conv4_block2_add[0][0]']
#
#  conv4_block3_1_conv (Conv2D)   (None, 7, 7, 256)    262400      ['conv4_block2_out[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 7, 7, 256)   1024        ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 7, 7, 256)   0           ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 7, 7, 256)    590080      ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 7, 7, 256)   1024        ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 7, 7, 256)   0           ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 7, 7, 1024)   263168      ['conv4_block3_2_relu[0][0]']
#
#  conv4_block3_3_bn (BatchNormal  (None, 7, 7, 1024)  4096        ['conv4_block3_3_conv[0][0]']
#  ization)
#
#  conv4_block3_add (Add)         (None, 7, 7, 1024)   0           ['conv4_block2_out[0][0]',
#                                                                   'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activation)  (None, 7, 7, 1024)   0           ['conv4_block3_add[0][0]']
#
#  conv4_block4_1_conv (Conv2D)   (None, 7, 7, 256)    262400      ['conv4_block3_out[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 7, 7, 256)   1024        ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 7, 7, 256)   0           ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 7, 7, 256)    590080      ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 7, 7, 256)   1024        ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 7, 7, 256)   0           ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 7, 7, 1024)   263168      ['conv4_block4_2_relu[0][0]']
#
#  conv4_block4_3_bn (BatchNormal  (None, 7, 7, 1024)  4096        ['conv4_block4_3_conv[0][0]']
#  ization)
#
#  conv4_block4_add (Add)         (None, 7, 7, 1024)   0           ['conv4_block3_out[0][0]',
#                                                                   'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activation)  (None, 7, 7, 1024)   0           ['conv4_block4_add[0][0]']
#
#  conv4_block5_1_conv (Conv2D)   (None, 7, 7, 256)    262400      ['conv4_block4_out[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 7, 7, 256)   1024        ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 7, 7, 256)   0           ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 7, 7, 256)    590080      ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 7, 7, 256)   1024        ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 7, 7, 256)   0           ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 7, 7, 1024)   263168      ['conv4_block5_2_relu[0][0]']
#
#  conv4_block5_3_bn (BatchNormal  (None, 7, 7, 1024)  4096        ['conv4_block5_3_conv[0][0]']
#  ization)
#
#  conv4_block5_add (Add)         (None, 7, 7, 1024)   0           ['conv4_block4_out[0][0]',
#                                                                   'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activation)  (None, 7, 7, 1024)   0           ['conv4_block5_add[0][0]']
#
#  conv4_block6_1_conv (Conv2D)   (None, 7, 7, 256)    262400      ['conv4_block5_out[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 7, 7, 256)   1024        ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 7, 7, 256)   0           ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_conv (Conv2D)   (None, 7, 7, 256)    590080      ['conv4_block6_1_relu[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 7, 7, 256)   1024        ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 7, 7, 256)   0           ['conv4_block6_2_bn[0][0]']
#  n)
#
#  conv4_block6_3_conv (Conv2D)   (None, 7, 7, 1024)   263168      ['conv4_block6_2_relu[0][0]']
#
#  conv4_block6_3_bn (BatchNormal  (None, 7, 7, 1024)  4096        ['conv4_block6_3_conv[0][0]']
#  ization)
#
#  conv4_block6_add (Add)         (None, 7, 7, 1024)   0           ['conv4_block5_out[0][0]',
#                                                                   'conv4_block6_3_bn[0][0]']
#
#  conv4_block6_out (Activation)  (None, 7, 7, 1024)   0           ['conv4_block6_add[0][0]']
#
#  conv5_block1_1_conv (Conv2D)   (None, 4, 4, 512)    524800      ['conv4_block6_out[0][0]']
#
#  conv5_block1_1_bn (BatchNormal  (None, 4, 4, 512)   2048        ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 4, 4, 512)   0           ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_conv (Conv2D)   (None, 4, 4, 512)    2359808     ['conv5_block1_1_relu[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 4, 4, 512)   2048        ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 4, 4, 512)   0           ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 4, 4, 2048)   2099200     ['conv4_block6_out[0][0]']
#
#  conv5_block1_3_conv (Conv2D)   (None, 4, 4, 2048)   1050624     ['conv5_block1_2_relu[0][0]']
#
#  conv5_block1_0_bn (BatchNormal  (None, 4, 4, 2048)  8192        ['conv5_block1_0_conv[0][0]']
#  ization)
#
#  conv5_block1_3_bn (BatchNormal  (None, 4, 4, 2048)  8192        ['conv5_block1_3_conv[0][0]']
#  ization)
#
#  conv5_block1_add (Add)         (None, 4, 4, 2048)   0           ['conv5_block1_0_bn[0][0]',
#                                                                   'conv5_block1_3_bn[0][0]']
#
#  conv5_block1_out (Activation)  (None, 4, 4, 2048)   0           ['conv5_block1_add[0][0]']
#
#  conv5_block2_1_conv (Conv2D)   (None, 4, 4, 512)    1049088     ['conv5_block1_out[0][0]']
#
#  conv5_block2_1_bn (BatchNormal  (None, 4, 4, 512)   2048        ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 4, 4, 512)   0           ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_conv (Conv2D)   (None, 4, 4, 512)    2359808     ['conv5_block2_1_relu[0][0]']
#
#  conv5_block2_2_bn (BatchNormal  (None, 4, 4, 512)   2048        ['conv5_block2_2_conv[0][0]']
#  ization)
#
#  conv5_block2_2_relu (Activatio  (None, 4, 4, 512)   0           ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 4, 4, 2048)   1050624     ['conv5_block2_2_relu[0][0]']
#
#  conv5_block2_3_bn (BatchNormal  (None, 4, 4, 2048)  8192        ['conv5_block2_3_conv[0][0]']
#  ization)
#
#  conv5_block2_add (Add)         (None, 4, 4, 2048)   0           ['conv5_block1_out[0][0]',
#                                                                   'conv5_block2_3_bn[0][0]']
#
#  conv5_block2_out (Activation)  (None, 4, 4, 2048)   0           ['conv5_block2_add[0][0]']
#
#  conv5_block3_1_conv (Conv2D)   (None, 4, 4, 512)    1049088     ['conv5_block2_out[0][0]']
#
#  conv5_block3_1_bn (BatchNormal  (None, 4, 4, 512)   2048        ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 4, 4, 512)   0           ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_conv (Conv2D)   (None, 4, 4, 512)    2359808     ['conv5_block3_1_relu[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 4, 4, 512)   2048        ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 4, 4, 512)   0           ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 4, 4, 2048)   1050624     ['conv5_block3_2_relu[0][0]']
#
#  conv5_block3_3_bn (BatchNormal  (None, 4, 4, 2048)  8192        ['conv5_block3_3_conv[0][0]']
#  ization)
#
#  conv5_block3_add (Add)         (None, 4, 4, 2048)   0           ['conv5_block2_out[0][0]',
#                                                                   'conv5_block3_3_bn[0][0]']
#
#  conv5_block3_out (Activation)  (None, 4, 4, 2048)   0           ['conv5_block3_add[0][0]']
#
# ==================================================================================================
# Total params: 23,587,712
# Trainable params: 0
# Non-trainable params: 23,587,712
# __________________________________________________________________________________________________
# Model: "model_7"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_8 (InputLayer)           [(None, 100, 100, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 106, 106, 3)  0           ['input_8[0][0]']
#
#  conv1_conv (Conv2D)            (None, 50, 50, 64)   9472        ['conv1_pad[0][0]']
#
#  conv1_bn (BatchNormalization)  (None, 50, 50, 64)   256         ['conv1_conv[0][0]']
#
#  conv1_relu (Activation)        (None, 50, 50, 64)   0           ['conv1_bn[0][0]']
#
#  pool1_pad (ZeroPadding2D)      (None, 52, 52, 64)   0           ['conv1_relu[0][0]']
#
#  pool1_pool (MaxPooling2D)      (None, 25, 25, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2D)   (None, 25, 25, 64)   4160        ['pool1_pool[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 25, 25, 64)  256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 25, 25, 64)  0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 25, 25, 64)   36928       ['conv2_block1_1_relu[0][0]']
# ...
#
#  conv4_block5_2_relu (Activatio  (None, 7, 7, 256)   0           ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 7, 7, 1024)   263168      ['conv4_block5_2_relu[0][0]']
#
#  conv4_block5_3_bn (BatchNormal  (None, 7, 7, 1024)  4096        ['conv4_block5_3_conv[0][0]']
#  ization)
#
#  conv4_block5_add (Add)         (None, 7, 7, 1024)   0           ['conv4_block4_out[0][0]',
#                                                                   'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activation)  (None, 7, 7, 1024)   0           ['conv4_block5_add[0][0]']
#
#  conv4_block6_1_conv (Conv2D)   (None, 7, 7, 256)    262400      ['conv4_block5_out[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 7, 7, 256)   1024        ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 7, 7, 256)   0           ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_conv (Conv2D)   (None, 7, 7, 256)    590080      ['conv4_block6_1_relu[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 7, 7, 256)   1024        ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 7, 7, 256)   0           ['conv4_block6_2_bn[0][0]']
#  n)
#
#  conv4_block6_3_conv (Conv2D)   (None, 7, 7, 1024)   263168      ['conv4_block6_2_relu[0][0]']
#
#  conv4_block6_3_bn (BatchNormal  (None, 7, 7, 1024)  4096        ['conv4_block6_3_conv[0][0]']
#  ization)
#
#  conv4_block6_add (Add)         (None, 7, 7, 1024)   0           ['conv4_block5_out[0][0]',
#                                                                   'conv4_block6_3_bn[0][0]']
#
#  conv4_block6_out (Activation)  (None, 7, 7, 1024)   0           ['conv4_block6_add[0][0]']
#
#  conv5_block1_1_conv (Conv2D)   (None, 4, 4, 512)    524800      ['conv4_block6_out[0][0]']
#
#  conv5_block1_1_bn (BatchNormal  (None, 4, 4, 512)   2048        ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 4, 4, 512)   0           ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_conv (Conv2D)   (None, 4, 4, 512)    2359808     ['conv5_block1_1_relu[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 4, 4, 512)   2048        ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 4, 4, 512)   0           ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 4, 4, 2048)   2099200     ['conv4_block6_out[0][0]']
#
#  conv5_block1_3_conv (Conv2D)   (None, 4, 4, 2048)   1050624     ['conv5_block1_2_relu[0][0]']
#
#  conv5_block1_0_bn (BatchNormal  (None, 4, 4, 2048)  8192        ['conv5_block1_0_conv[0][0]']
#  ization)
#
#  conv5_block1_3_bn (BatchNormal  (None, 4, 4, 2048)  8192        ['conv5_block1_3_conv[0][0]']
#  ization)
#
#  conv5_block1_add (Add)         (None, 4, 4, 2048)   0           ['conv5_block1_0_bn[0][0]',
#                                                                   'conv5_block1_3_bn[0][0]']
#
#  conv5_block1_out (Activation)  (None, 4, 4, 2048)   0           ['conv5_block1_add[0][0]']
#
#  conv5_block2_1_conv (Conv2D)   (None, 4, 4, 512)    1049088     ['conv5_block1_out[0][0]']
#
#  conv5_block2_1_bn (BatchNormal  (None, 4, 4, 512)   2048        ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 4, 4, 512)   0           ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_conv (Conv2D)   (None, 4, 4, 512)    2359808     ['conv5_block2_1_relu[0][0]']
#
#  conv5_block2_2_bn (BatchNormal  (None, 4, 4, 512)   2048        ['conv5_block2_2_conv[0][0]']
#  ization)
#
#  conv5_block2_2_relu (Activatio  (None, 4, 4, 512)   0           ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 4, 4, 2048)   1050624     ['conv5_block2_2_relu[0][0]']
#
#  conv5_block2_3_bn (BatchNormal  (None, 4, 4, 2048)  8192        ['conv5_block2_3_conv[0][0]']
#  ization)
#
#  conv5_block2_add (Add)         (None, 4, 4, 2048)   0           ['conv5_block1_out[0][0]',
#                                                                   'conv5_block2_3_bn[0][0]']
#
#  conv5_block2_out (Activation)  (None, 4, 4, 2048)   0           ['conv5_block2_add[0][0]']
#
#  conv5_block3_1_conv (Conv2D)   (None, 4, 4, 512)    1049088     ['conv5_block2_out[0][0]']
#
#  conv5_block3_1_bn (BatchNormal  (None, 4, 4, 512)   2048        ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 4, 4, 512)   0           ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_conv (Conv2D)   (None, 4, 4, 512)    2359808     ['conv5_block3_1_relu[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 4, 4, 512)   2048        ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 4, 4, 512)   0           ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 4, 4, 2048)   1050624     ['conv5_block3_2_relu[0][0]']
#
#  conv5_block3_3_bn (BatchNormal  (None, 4, 4, 2048)  8192        ['conv5_block3_3_conv[0][0]']
#  ization)
#
#  conv5_block3_add (Add)         (None, 4, 4, 2048)   0           ['conv5_block2_out[0][0]',
#                                                                   'conv5_block3_3_bn[0][0]']
#
#  conv5_block3_out (Activation)  (None, 4, 4, 2048)   0           ['conv5_block3_add[0][0]']
#
#  flatten_8 (Flatten)            (None, 32768)        0           ['conv5_block3_out[0][0]']
#
#  fc1 (Dense)                    (None, 1000)         32769000    ['flatten_8[0][0]']
#
#  dropout_11 (Dropout)           (None, 1000)         0           ['fc1[0][0]']
#
#  predictions (Dense)            (None, 5)            5005        ['dropout_11[0][0]']
#
# ==================================================================================================
# Total params: 56,361,717
# Trainable params: 32,774,005
# Non-trainable params: 23,587,712
# __________________________________________________________________________________________________
# Epoch 1/100
# 5/5 [==============================] - 22s 4s/step - loss: 3.9172 - accuracy: 0.2156 - val_loss: 2.6699 - val_accuracy: 0.1875
# Epoch 2/100
# 5/5 [==============================] - 18s 4s/step - loss: 2.3535 - accuracy: 0.2656 - val_loss: 1.7754 - val_accuracy: 0.3375
# Epoch 3/100
# 5/5 [==============================] - 18s 4s/step - loss: 1.8394 - accuracy: 0.3156 - val_loss: 1.5453 - val_accuracy: 0.3250
# Epoch 4/100
# 5/5 [==============================] - 18s 4s/step - loss: 1.6775 - accuracy: 0.3625 - val_loss: 1.3607 - val_accuracy: 0.4500
# Epoch 5/100
# 5/5 [==============================] - 17s 4s/step - loss: 1.5038 - accuracy: 0.3438 - val_loss: 1.2580 - val_accuracy: 0.3625
# Epoch 6/100
# 5/5 [==============================] - 17s 4s/step - loss: 1.4227 - accuracy: 0.4281 - val_loss: 1.1527 - val_accuracy: 0.5125
# Epoch 7/100
# 5/5 [==============================] - 17s 4s/step - loss: 1.3541 - accuracy: 0.4406 - val_loss: 1.2053 - val_accuracy: 0.3250
# Epoch 8/100
# 5/5 [==============================] - 18s 4s/step - loss: 1.3589 - accuracy: 0.4187 - val_loss: 1.1050 - val_accuracy: 0.5500
# Epoch 9/100
# 5/5 [==============================] - 18s 4s/step - loss: 1.2409 - accuracy: 0.4656 - val_loss: 1.1760 - val_accuracy: 0.4625
# Epoch 10/100
# 5/5 [==============================] - 18s 4s/step - loss: 1.1675 - accuracy: 0.4906 - val_loss: 1.1064 - val_accuracy: 0.5000
# Epoch 11/100
# 5/5 [==============================] - 17s 4s/step - loss: 1.1680 - accuracy: 0.4969 - val_loss: 1.1055 - val_accuracy: 0.6000
# Epoch 12/100
# 5/5 [==============================] - 17s 4s/step - loss: 1.1023 - accuracy: 0.5500 - val_loss: 1.0651 - val_accuracy: 0.5125
# Epoch 13/100
# 5/5 [==============================] - 17s 4s/step - loss: 1.0937 - accuracy: 0.5219 - val_loss: 1.0925 - val_accuracy: 0.5375
# Epoch 14/100
# 5/5 [==============================] - 17s 4s/step - loss: 1.0579 - accuracy: 0.5469 - val_loss: 1.0348 - val_accuracy: 0.6125
# Epoch 15/100
# 5/5 [==============================] - 17s 4s/step - loss: 1.0716 - accuracy: 0.5562 - val_loss: 1.0162 - val_accuracy: 0.5625
# Epoch 16/100
# 5/5 [==============================] - 17s 4s/step - loss: 1.0258 - accuracy: 0.5344 - val_loss: 1.0622 - val_accuracy: 0.5625
# Epoch 17/100
# 5/5 [==============================] - 17s 4s/step - loss: 1.0392 - accuracy: 0.6000 - val_loss: 0.9747 - val_accuracy: 0.6375
# Epoch 18/100
# 5/5 [==============================] - 17s 4s/step - loss: 1.0495 - accuracy: 0.5594 - val_loss: 0.9803 - val_accuracy: 0.6250
# Epoch 19/100
# 5/5 [==============================] - 17s 4s/step - loss: 1.1139 - accuracy: 0.5344 - val_loss: 1.0382 - val_accuracy: 0.6250

# %%
acc = grado_train_dropout.history['accuracy']
val_acc = grado_train_dropout.history['val_accuracy']

loss = grado_train_dropout.history['loss']
val_loss = grado_train_dropout.history['val_loss']

plt.figure(figsize=(10, 10))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Exactitud Entrenamiento ')
plt.plot(val_acc, label='Exactitud Validación')
plt.legend(loc='lower right')
plt.ylabel('Exactitud')
plt.ylim([min(plt.ylim()),1])
plt.title('Exactitud Entrenamiento y Validación ')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Pérdida Entrenamiento')
plt.plot(val_loss, label='Pérdida Validación')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,1.0])
plt.title(' Pérdida Entrenamiento y Validación ')
plt.xlabel('epoch')
plt.show()

# %%
test_eval = model_out_resnet50.evaluate(x_test, test_Y_one_hot, verbose=1)

print('Test loss:', test_eval[0])
print('Test accuracy:', test_eval[1])

predicted_classes = model_out_resnet50.predict(x_test)
predicted_classes = np.argmax(np.round(predicted_classes),axis=1)
predicted_classes.shape, y_test.shape
# Out:
# 4/4 [==============================] - 4s 973ms/step - loss: 1.0834 - accuracy: 0.5800
# Test loss: 1.0833569765090942
# Test accuracy: 0.5799999833106995
# ((100,), (100,))

# %%
from sklearn.metrics import classification_report
target_names = ["Class {}".format(i) for i in range(nClasses)]
print(classification_report(y_test, predicted_classes, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#      Class 0       0.27      0.95      0.43        21
#      Class 1       0.60      0.16      0.25        19
#      Class 2       1.00      0.24      0.38        17
#      Class 3       1.00      0.09      0.16        23
#      Class 4       0.94      0.75      0.83        20
#
#     accuracy                           0.44       100
#    macro avg       0.76      0.44      0.41       100
# weighted avg       0.76      0.44      0.41       100

# %%
from sklearn.metrics import confusion_matrix

matriz=confusion_matrix(y_test, predicted_classes)
print(matriz)
# Out:
# [[20  1  0  0  0]
#  [16  3  0  0  0]
#  [13  0  4  0  0]
#  [19  1  0  2  1]
#  [ 5  0  0  0 15]]

# %%
import numpy as np
import cv2
import glob
import os
import matplotlib.pyplot as plt
import string
from mlxtend.plotting import plot_decision_regions
#from mpl_toolkits.mplot3d import Axes3D
#from sklearn.decomposition import PCA
#from sklearn.preprocessing import StandardScaler
#from sklearn.neighbors import KNeighborsClassifier
#from sklearn.tree import DecisionTreeClassifier
#from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.utils.multiclass import unique_labels
from sklearn import metrics
#from sklearn.svm import SVC


import json
from skimage import color
from skimage.feature import hog
#from sklearn import svm
from sklearn.metrics import classification_report,accuracy_score, recall_score
from subprocess import check_output

def plot_confusion_matrix(y_true, y_pred, classes,
                          normalize=False,
                          title=None,
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if not title:
        if normalize:
            title = 'Matriz de confusión'
        else:
            title = 'Matriz de confusión, sin normalización'

    # Compute confusion matrix

    cm = metrics.confusion_matrix(y_true, y_pred)
    # Only use the labels that appear in the data
    classes = unique_labels(y_true, y_pred)
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    fig, ax = plt.subplots()
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    # We want to show all ticks...

    ax.set(xticks=np.arange(cm.shape[1]),
           yticks=np.arange(cm.shape[0]),
           # ... and label them with the respective list entries
           xticklabels=labels, yticklabels=labels,
           title=title,
           ylabel='Etiqueta verdadera',
           xlabel='Etiqueta prevista')

    # Rotate the tick labels and set their alignment.

    plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
             rotation_mode="anchor")

    # Loop over data dimensions and create text annotations.

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], fmt),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")
    fig.tight_layout()
    return cm,ax

precision=metrics.accuracy_score(y_test,predicted_classes, normalize=False)

print("Accuracy:{0:.2f}".format(precision))
cm,_=plot_confusion_matrix(y_test,predicted_classes,classes=nClasses,normalize=False,title="Matriz de confusión no nomalizada")
plt.show()


precision=metrics.accuracy_score(y_test,predicted_classes, normalize=True)*100

print("Accuracy:{0:.2f}%".format(precision))
cm,_=plot_confusion_matrix(y_test,predicted_classes,classes=nClasses,normalize=True,title="Matriz de confusión normalizada")
plt.show()
# Out:
# Accuracy:44.00
# Accuracy:44.00%

# %%
model_out_resnet50.save("/content/drive/My Drive/source_dir/gradoma_final_resnet50.h5py")
# Out:
# INFO:tensorflow:Assets written to: /content/drive/My Drive/source_dir/gradoma_final_resnet50.h5py/assets
# /usr/local/lib/python3.7/dist-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# /usr/local/lib/python3.7/dist-packages/keras/saving/saved_model/layer_serialization.py:112: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   return generic_utils.serialize_keras_object(obj)

# %% [markdown]
# VGG19

# %%
#preprocess_input = tf.keras.applications.VGG19.preprocess_input
rescale = tf.keras.layers.experimental.preprocessing.Rescaling(1./127.5, offset= -1)
IMG_SIZE = (100, 100)
img_height=100
img_width=100

IMG_SHAPE = IMG_SIZE + (3,)
base_model_vgg19 = tf.keras.applications.VGG19(input_shape=IMG_SHAPE,
                                               include_top=False,
                                               weights='imagenet')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 1s 0us/step
# 80150528/80134624 [==============================] - 1s 0us/step

# %%
base_model_vgg19.trainable = False

base_model_vgg19.summary()
for layer in base_model_vgg19.layers:
           if layer.name == 'block5_conv1':
              break
           layer.trainable = False
# We add our classificator (top_model) to the last layer of the model
last = base_model_vgg19.layers[-1].output
x = Flatten()(last)
x = Dense(1000, activation='relu', name='fc1')(x)
x = Dropout(0.3)(x)
x = Dense(5, activation='softmax', name='predictions')(x)
model_out_vgg19 = Model(base_model_vgg19.input, x)
#We compile the model
#We compile the model
model_out_vgg19.compile(loss=keras.losses.categorical_crossentropy, optimizer=tf.keras.optimizers.Adam(learning_rate=INIT_LR, decay=INIT_LR / 100),metrics=['accuracy'])
model_out_vgg19.summary()
callback = tf.keras.callbacks.EarlyStopping(monitor='loss', min_delta=0.0001, patience=3)

grado_train_dropout = model_out_vgg19.fit(train_x, train_label, batch_size=batch_size,epochs=epochs,verbose=1,validation_data=(valid_X, valid_label),callbacks=[callback])
# Out:
# Model: "vgg19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_9 (InputLayer)        [(None, 100, 100, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 100, 100, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 100, 100, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 50, 50, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 50, 50, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 50, 50, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 25, 25, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 25, 25, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 25, 25, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 25, 25, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 25, 25, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 12, 12, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 12, 12, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 12, 12, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 12, 12, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 12, 12, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 6, 6, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 6, 6, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 6, 6, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 6, 6, 512)         2359808
#
#  block5_conv4 (Conv2D)       (None, 6, 6, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 3, 3, 512)         0
#
# =================================================================
# Total params: 20,024,384
# Trainable params: 0
# Non-trainable params: 20,024,384
# _________________________________________________________________
# Model: "model_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_9 (InputLayer)        [(None, 100, 100, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 100, 100, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 100, 100, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 50, 50, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 50, 50, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 50, 50, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 25, 25, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 25, 25, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 25, 25, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 25, 25, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 25, 25, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 12, 12, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 12, 12, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 12, 12, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 12, 12, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 12, 12, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 6, 6, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 6, 6, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 6, 6, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 6, 6, 512)         2359808
#
#  block5_conv4 (Conv2D)       (None, 6, 6, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 3, 3, 512)         0
#
#  flatten_9 (Flatten)         (None, 4608)              0
#
#  fc1 (Dense)                 (None, 1000)              4609000
#
#  dropout_12 (Dropout)        (None, 1000)              0
#
#  predictions (Dense)         (None, 5)                 5005
#
# =================================================================
# Total params: 24,638,389
# Trainable params: 4,614,005
# Non-trainable params: 20,024,384
# _________________________________________________________________
# Epoch 1/100
# 5/5 [==============================] - 51s 10s/step - loss: 1.6853 - accuracy: 0.3219 - val_loss: 1.1929 - val_accuracy: 0.6750
# Epoch 2/100
# 5/5 [==============================] - 49s 10s/step - loss: 1.1164 - accuracy: 0.5531 - val_loss: 0.9448 - val_accuracy: 0.7250
# Epoch 3/100
# 5/5 [==============================] - 50s 10s/step - loss: 0.8423 - accuracy: 0.6906 - val_loss: 0.8547 - val_accuracy: 0.7375
# Epoch 4/100
# 5/5 [==============================] - 49s 10s/step - loss: 0.6609 - accuracy: 0.7750 - val_loss: 0.7086 - val_accuracy: 0.7750
# Epoch 5/100
# 5/5 [==============================] - 49s 10s/step - loss: 0.5587 - accuracy: 0.7937 - val_loss: 0.6383 - val_accuracy: 0.8125
# Epoch 6/100
# 5/5 [==============================] - 49s 10s/step - loss: 0.4984 - accuracy: 0.8406 - val_loss: 0.5897 - val_accuracy: 0.8250
# Epoch 7/100
# 5/5 [==============================] - 49s 10s/step - loss: 0.4295 - accuracy: 0.8562 - val_loss: 0.5857 - val_accuracy: 0.8000
# Epoch 8/100
# 5/5 [==============================] - 49s 10s/step - loss: 0.3586 - accuracy: 0.8875 - val_loss: 0.5530 - val_accuracy: 0.8125
# Epoch 9/100
# 5/5 [==============================] - 49s 10s/step - loss: 0.3419 - accuracy: 0.8906 - val_loss: 0.5053 - val_accuracy: 0.8375
# Epoch 10/100
# 5/5 [==============================] - 49s 10s/step - loss: 0.2996 - accuracy: 0.9125 - val_loss: 0.4823 - val_accuracy: 0.8500
# Epoch 11/100
# 5/5 [==============================] - 49s 10s/step - loss: 0
100
# 5/5 [==============================] - 49s 10s/step - loss: 0.0443 - accuracy: 0.9969 - val_loss: 0.4000 - val_accuracy: 0.8375
# Epoch 41/100
# 5/5 [==============================] - 50s 11s/step - loss: 0.0434 - accuracy: 0.9937 - val_loss: 0.4070 - val_accuracy: 0.8500
# Epoch 42/100
# 5/5 [==============================] - 50s 10s/step - loss: 0.0392 - accuracy: 1.0000 - val_loss: 0.4138 - val_accuracy: 0.8500
# Epoch 43/100
# 5/5 [==============================] - 50s 10s/step - loss: 0.0389 - accuracy: 1.0000 - val_loss: 0.4069 - val_accuracy: 0.8500
# Epoch 44/100
# 5/5 [==============================] - 50s 10s/step - loss: 0.0384 - accuracy: 1.0000 - val_loss: 0.4058 - val_accuracy: 0.8500
# Epoch 45/100
# 5/5 [==============================] - 51s 11s/step - loss: 0.0367 - accuracy: 1.0000 - val_loss: 0.4110 - val_accuracy: 0.8500
# Epoch 46/100
# 5/5 [==============================] - 50s 11s/step - loss: 0.0347 - accuracy: 1.0000 - val_loss: 0.4058 - val_accuracy: 0.8500
# Epoch 47/100
# 5/5 [==============================] - 49s 10s/step - loss: 0.0331 - accuracy: 1.0000 - val_loss: 0.4087 - val_accuracy: 0.8375
# Epoch 48/100
# 5/5 [==============================] - 49s 10s/step - loss: 0.0314 - accuracy: 1.0000 - val_loss: 0.4028 - val_accuracy: 0.8500
# Epoch 49/100
# 5/5 [==============================] - 49s 10s/step - loss: 0.0340 - accuracy: 0.9969 - val_loss: 0.4059 - val_accuracy: 0.8375
# Epoch 50/100
# 5/5 [==============================] - 49s 10s/step - loss: 0.0303 - accuracy: 1.0000 - val_loss: 0.4159 - val_accuracy: 0.8375
# Epoch 51/100
# 5/5 [==============================] - 49s 10s/step - loss: 0.0287 - accuracy: 1.0000 - val_loss: 0.4151 - val_accuracy: 0.8375
# Epoch 52/100
# 5/5 [==============================] - 50s 10s/step - loss: 0.0263 - accuracy: 1.0000 - val_loss: 0.4129 - val_accuracy: 0.8375
# Epoch 53/100
# 5/5 [==============================] - 49s 10s/step - loss: 0.0247 - accuracy: 1.0000 - val_loss: 0.4153 - val_accuracy: 0.8375
# Epoch 54/100
# 5/5 [==============================] - 49s 10s/step - loss: 0.0281 - accuracy: 1.0000 - val_loss: 0.4167 - val_accuracy: 0.8500
# Epoch 55/100
# 5/5 [==============================] - 49s 10s/step - loss: 0.0237 - accuracy: 1.0000 - val_loss: 0.4165 - val_accuracy: 0.8375
# Epoch 56/100
# 5/5 [==============================] - 49s 10s/step - loss: 0.0230 - accuracy: 1.0000 - val_loss: 0.4125 - val_accuracy: 0.8250
# Epoch 57/100
# 5/5 [==============================] - 49s 10s/step - loss: 0.0208 - accuracy: 1.0000 - val_loss: 0.4143 - val_accuracy: 0.8375
# Epoch 58/100
# 5/5 [==============================] - 49s 10s/step - loss: 0.0254 - accuracy: 1.0000 - val_loss: 0.4253 - val_accuracy: 0.8500
# Epoch 59/100
# 5/5 [==============================] - 49s 10s/step - loss: 0.0217 - accuracy: 1.0000 - val_loss: 0.4204 - val_accuracy: 0.8375
# Epoch 60/100
# 5/5 [==============================] - 49s 10s/step - loss: 0.0204 - accuracy: 1.0000 - val_loss: 0.4181 - val_accuracy: 0.8375
# Epoch 61/100
# 5/5 [==============================] - 49s 10s/step - loss: 0.0187 - accuracy: 1.0000 - val_loss: 0.4164 - val_accuracy: 0.8375
# Epoch 62/100
# 5/5 [==============================] - 49s 10s/step - loss: 0.0180 - accuracy: 1.0000 - val_loss: 0.4164 - val_accuracy: 0.8375
# Epoch 63/100
# 5/5 [==============================] - 49s 10s/step - loss: 0.0180 - accuracy: 1.0000 - val_loss: 0.4229 - val_accuracy: 0.8375
# Epoch 64/100
# 5/5 [==============================] - 49s 10s/step - loss: 0.0184 - accuracy: 1.0000 - val_loss: 0.4217 - val_accuracy: 0.8375
# Epoch 65/100
# 5/5 [==============================] - 49s 10s/step - loss: 0.0168 - accuracy: 1.0000 - val_loss: 0.4210 - val_accuracy: 0.8375
# Epoch 66/100
# 5/5 [==============================] - 49s 10s/step - loss: 0.0162 - accuracy: 1.0000 - val_loss: 0.4268 - val_accuracy: 0.8375
# Epoch 67/100
# 5/5 [==============================] - 49s 10s/step - loss: 0.0162 - accuracy: 1.0000 - val_loss: 0.4312 - val_accuracy: 0.8500
# Epoch 68/100
# 5/5 [==============================] - 49s 10s/step - loss: 0.0171 - accuracy: 1.0000 - val_loss: 0.4253 - val_accuracy: 0.8375
# Epoch 69/100
# 5/5 [==============================] - 49s 10s/step - loss: 0.0146 - accuracy: 1.0000 - val_loss: 0.4245 - val_accuracy: 0.8500
# Epoch 70/100
# 5/5 [==============================] - 49s 10s/step - loss: 0.0152 - accuracy: 1.0000 - val_loss: 0.4172 - val_accuracy: 0.8375
# Epoch 71/100
# 5/5 [==============================] - 50s 10s/step - loss: 0.0140 - accuracy: 1.0000 - val_loss: 0.4210 - val_accuracy: 0.8500
# Epoch 72/100
# 5/5 [==============================] - 49s 10s/step - loss: 0.0152 - accuracy: 1.0000 - val_loss: 0.4292 - val_accuracy: 0.8375
# Epoch 73/100
# 5/5 [==============================] - 49s 10s/step - loss: 0.0141 - accuracy: 1.0000 - val_loss: 0.4298 - val_accuracy: 0.8375
# Epoch 74/100
# 5/5 [==============================] - 49s 10s/step - loss: 0.0128 - accuracy: 1.0000 - val_loss: 0.4248 - val_accuracy: 0.8375
# Epoch 75/100
# 5/5 [==============================] - 49s 10s/step - loss: 0.0139 - accuracy: 1.0000 - val_loss: 0.4253 - val_accuracy: 0.8375
# Epoch 76/100
# 5/5 [==============================] - 49s 10s/step - loss: 0.0123 - accuracy: 1.0000 - val_loss: 0.4308 - val_accuracy: 0.8375
# Epoch 77/100
# 5/5 [==============================] - 49s 10s/step - loss: 0.0123 - accuracy: 1.0000 - val_loss: 0.4358 - val_accuracy: 0.8500
# Epoch 78/100
# 5/5 [==============================] - 49s 10s/step - loss: 0.0129 - accuracy: 1.0000 - val_loss: 0.4341 - val_accuracy: 0.8375
# Epoch 79/100
# 5/5 [==============================] - 50s 10s/step - loss: 0.0132 - accuracy: 1.0000 - val_loss: 0.4398 - val_accuracy: 0.8500

# %%
acc = grado_train_dropout.history['accuracy']
val_acc = grado_train_dropout.history['val_accuracy']

loss = grado_train_dropout.history['loss']
val_loss = grado_train_dropout.history['val_loss']

plt.figure(figsize=(10, 10))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Exactitud Entrenamiento ')
plt.plot(val_acc, label='Exactitud Validación')
plt.legend(loc='lower right')
plt.ylabel('Exactitud')
plt.ylim([min(plt.ylim()),1])
plt.title('Exactitud Entrenamiento y Validación ')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Pérdida Entrenamiento')
plt.plot(val_loss, label='Pérdida Validación')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,1.0])
plt.title(' Pérdida Entrenamiento y Validación ')
plt.xlabel('epoch')
plt.show()

# %%
test_eval = model_out_vgg19.evaluate(x_test, test_Y_one_hot, verbose=1)

print('Test loss:', test_eval[0])
print('Test accuracy:', test_eval[1])

predicted_classes = model_out_vgg19.predict(x_test)
predicted_classes = np.argmax(np.round(predicted_classes),axis=1)
predicted_classes.shape, y_test.shape
# Out:
# 4/4 [==============================] - 13s 3s/step - loss: 0.3961 - accuracy: 0.8800
# Test loss: 0.396121621131897
# Test accuracy: 0.8799999952316284
# ((100,), (100,))

# %%
from sklearn.metrics import classification_report
target_names = ["Class {}".format(i) for i in range(nClasses)]
print(classification_report(y_test, predicted_classes, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#      Class 0       0.82      0.86      0.84        21
#      Class 1       0.85      0.89      0.87        19
#      Class 2       0.74      0.82      0.78        17
#      Class 3       1.00      0.91      0.95        23
#      Class 4       1.00      0.90      0.95        20
#
#     accuracy                           0.88       100
#    macro avg       0.88      0.88      0.88       100
# weighted avg       0.89      0.88      0.88       100

# %%
from sklearn.metrics import confusion_matrix

matriz=confusion_matrix(y_test, predicted_classes)
print(matriz)
# Out:
# [[18  3  0  0  0]
#  [ 0 17  2  0  0]
#  [ 3  0 14  0  0]
#  [ 1  0  1 21  0]
#  [ 0  0  2  0 18]]

# %%
import numpy as np
import cv2
import glob
import os
import matplotlib.pyplot as plt
import string
from mlxtend.plotting import plot_decision_regions
#from mpl_toolkits.mplot3d import Axes3D
#from sklearn.decomposition import PCA
#from sklearn.preprocessing import StandardScaler
#from sklearn.neighbors import KNeighborsClassifier
#from sklearn.tree import DecisionTreeClassifier
#from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.utils.multiclass import unique_labels
from sklearn import metrics
#from sklearn.svm import SVC


import json
from skimage import color
from skimage.feature import hog
#from sklearn import svm
from sklearn.metrics import classification_report,accuracy_score, recall_score
from subprocess import check_output

def plot_confusion_matrix(y_true, y_pred, classes,
                          normalize=False,
                          title=None,
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if not title:
        if normalize:
            title = 'Matriz de confusión'
        else:
            title = 'Matriz de confusión, sin normalización'

    # Compute confusion matrix

    cm = metrics.confusion_matrix(y_true, y_pred)
    # Only use the labels that appear in the data
    classes = unique_labels(y_true, y_pred)
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    fig, ax = plt.subplots()
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    # We want to show all ticks...

    ax.set(xticks=np.arange(cm.shape[1]),
           yticks=np.arange(cm.shape[0]),
           # ... and label them with the respective list entries
           xticklabels=labels, yticklabels=labels,
           title=title,
           ylabel='Etiqueta verdadera',
           xlabel='Etiqueta prevista')

    # Rotate the tick labels and set their alignment.

    plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
             rotation_mode="anchor")

    # Loop over data dimensions and create text annotations.

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], fmt),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")
    fig.tight_layout()
    return cm,ax

precision=metrics.accuracy_score(y_test,predicted_classes, normalize=False)

print("Accuracy:{0:.2f}".format(precision))
cm,_=plot_confusion_matrix(y_test,predicted_classes,classes=nClasses,normalize=False,title="Matriz de confusión no nomalizada")
plt.show()


precision=metrics.accuracy_score(y_test,predicted_classes, normalize=True)*100

print("Accuracy:{0:.2f}%".format(precision))
cm,_=plot_confusion_matrix(y_test,predicted_classes,classes=nClasses,normalize=True,title="Matriz de confusión normalizada")
plt.show()
# Out:
# Accuracy:88.00
# Accuracy:88.00%

# %%
model_out_vgg19.save("/content/drive/My Drive/source_dir/gradoma_final_vgg19.h5py")

# %% [markdown]
# INCEPTION V3

# %%
#preprocess_input = tf.keras.applications.InceptionV3.preprocess_input
rescale = tf.keras.layers.experimental.preprocessing.Rescaling(1./127.5, offset= -1)
IMG_SIZE = (100, 100)
img_height=100
img_width=100

IMG_SHAPE = IMG_SIZE + (3,)
base_model_incepV3 = tf.keras.applications.InceptionV3(input_shape=IMG_SHAPE,
                                               include_top=False,
                                               weights='imagenet')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87916544/87910968 [==============================] - 1s 0us/step
# 87924736/87910968 [==============================] - 1s 0us/step

# %%
base_model_incepV3.trainable = False

base_model_incepV3.summary()
for layer in base_model_incepV3.layers:
           if layer.name == 'block5_conv1':
              break
           layer.trainable = False
# We add our classificator (top_model) to the last layer of the model
last = base_model_incepV3.layers[-1].output
x = Flatten()(last)
x = Dense(1000, activation='relu', name='fc1')(x)
x = Dropout(0.3)(x)
x = Dense(5, activation='softmax', name='predictions')(x)
model_out_incepv3 = Model(base_model_incepV3.input, x)
#We compile the model

model_out_incepv3.compile(loss=keras.losses.categorical_crossentropy, optimizer=tf.keras.optimizers.Adam(learning_rate=INIT_LR, decay=INIT_LR / 100),metrics=['accuracy'])
model_out_incepv3.summary()
callback = tf.keras.callbacks.EarlyStopping(monitor='loss', min_delta=0.0001, patience=3)

grado_train_dropout = model_out_incepv3.fit(train_x, train_label, batch_size=batch_size,epochs=epochs,verbose=1,validation_data=(valid_X, valid_label),callbacks=[callback])
# Out:
# Model: "inception_v3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_10 (InputLayer)          [(None, 100, 100, 3  0           []
#                                 )]
#
#  conv2d_210 (Conv2D)            (None, 49, 49, 32)   864         ['input_10[0][0]']
#
#  batch_normalization_207 (Batch  (None, 49, 49, 32)  96          ['conv2d_210[0][0]']
#  Normalization)
#
#  activation_203 (Activation)    (None, 49, 49, 32)   0           ['batch_normalization_207[0][0]']
#
#  conv2d_211 (Conv2D)            (None, 47, 47, 32)   9216        ['activation_203[0][0]']
#
#  batch_normalization_208 (Batch  (None, 47, 47, 32)  96          ['conv2d_211[0][0]']
#  Normalization)
#
#  activation_204 (Activation)    (None, 47, 47, 32)   0           ['batch_normalization_208[0][0]']
#
#  conv2d_212 (Conv2D)            (None, 47, 47, 64)   18432       ['activation_204[0][0]']
#
#  batch_normalization_209 (Batch  (None, 47, 47, 64)  192         ['conv2d_212[0][0]']
#  Normalization)
#
#  activation_205 (Activation)    (None, 47, 47, 64)   0           ['batch_normalization_209[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 23, 23, 64)  0           ['activation_205[0][0]']
#
#  conv2d_213 (Conv2D)            (None, 23, 23, 80)   5120        ['max_pooling2d_7[0][0]']
#
#  batch_normalization_210 (Batch  (None, 23, 23, 80)  240         ['conv2d_213[0][0]']
#  Normalization)
#
#  activation_206 (Activation)    (None, 23, 23, 80)   0           ['batch_normalization_210[0][0]']
#
#  conv2d_214 (Conv2D)            (None, 21, 21, 192)  138240      ['activation_206[0][0]']
#
#  batch_normalization_211 (Batch  (None, 21, 21, 192)  576        ['conv2d_214[0][0]']
#  Normalization)
#
#  activation_207 (Activation)    (None, 21, 21, 192)  0           ['batch_normalization_211[0][0]']
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 10, 10, 192)  0          ['activation_207[0][0]']
#
#  conv2d_218 (Conv2D)            (None, 10, 10, 64)   12288       ['max_pooling2d_8[0][0]']
#
#  batch_normalization_215 (Batch  (None, 10, 10, 64)  192         ['conv2d_218[0][0]']
#  Normalization)
#
#  activation_211 (Activation)    (None, 10, 10, 64)   0           ['batch_normalization_215[0][0]']
#
#  conv2d_216 (Conv2D)            (None, 10, 10, 48)   9216        ['max_pooling2d_8[0][0]']
#
#  conv2d_219 (Conv2D)            (None, 10, 10, 96)   55296       ['activation_211[0][0]']
#
#  batch_normalization_213 (Batch  (None, 10, 10, 48)  144         ['conv2d_216[0][0]']
#  Normalization)
#
#  batch_normalization_216 (Batch  (None, 10, 10, 96)  288         ['conv2d_219[0][0]']
#  Normalization)
#
#  activation_209 (Activation)    (None, 10, 10, 48)   0           ['batch_normalization_213[0][0]']
#
#  activation_212 (Activation)    (None, 10, 10, 96)   0           ['batch_normalization_216[0][0]']
#
#  average_pooling2d_1 (AveragePo  (None, 10, 10, 192)  0          ['max_pooling2d_8[0][0]']
#  oling2D)
#
#  conv2d_215 (Conv2D)            (None, 10, 10, 64)   12288       ['max_pooling2d_8[0][0]']
#
#  conv2d_217 (Conv2D)            (None, 10, 10, 64)   76800       ['activation_209[0][0]']
#
#  conv2d_220 (Conv2D)            (None, 10, 10, 96)   82944       ['activation_212[0][0]']
#
#  conv2d_221 (Conv2D)            (None, 10, 10, 32)   6144        ['average_pooling2d_1[0][0]']
#
#  batch_normalization_212 (Batch  (None, 10, 10, 64)  192         ['conv2d_215[0][0]']
#  Normalization)
#
#  batch_normalization_214 (Batch  (None, 10, 10, 64)  192         ['conv2d_217[0][0]']
#  Normalization)
#
#  batch_normalization_217 (Batch  (None, 10, 10, 96)  288         ['conv2d_220[0][0]']
#  Normalization)
#
#  batch_normalization_218 (Batch  (None, 10, 10, 32)  96          ['conv2d_221[0][0]']
#  Normalization)
#
#  activation_208 (Activation)    (None, 10, 10, 64)   0           ['batch_normalization_212[0][0]']
#
#  activation_210 (Activation)    (None, 10, 10, 64)   0           ['batch_normalization_214[0][0]']
#
#  activation_213 (Activation)    (None, 10, 10, 96)   0           ['batch_normalization_217[0][0]']
#
#  activation_214 (Activation)    (None, 10, 10, 32)   0           ['batch_normalization_218[0][0]']
#
#  mixed0 (Concatenate)           (None, 10, 10, 256)  0           ['activation_208[0][0]',
#                                                                   'activation_210[0][0]',
#                                                                   'activation_213[0][0]',
#                                                                   'activation_214[0][0]']
#
#  conv2d_225 (Conv2D)            (None, 10, 10, 64)   16384       ['mixed0[0][0]']
#
#  batch_normalization_222 (Batch  (None, 10, 10, 64)  192         ['conv2d_225[0][0]']
#  Normalization)
#
#  activation_218 (Activation)    (None, 10, 10, 64)   0           ['batch_normalization_222[0][0]']
#
#  conv2d_223 (Conv2D)            (None, 10, 10, 48)   12288       ['mixed0[0][0]']
#
#  conv2d_226 (Conv2D)            (None, 10, 10, 96)   55296       ['activation_218[0][0]']
#
#  batch_normalization_220 (Batch  (None, 10, 10, 48)  144         ['conv2d_223[0][0]']
#  Normalization)
#
#  batch_normalization_223 (Batch  (None, 10, 10, 96)  288         ['conv2d_226[0][0]']
#  Normalization)
#
#  activation_216 (Activation)    (None, 10, 10, 48)   0           ['batch_normalization_220[0][0]']
#
#  activation_219 (Activation)    (None, 10, 10, 96)   0           ['batch_normalization_223[0][0]']
#
#  average_pooling2d_2 (AveragePo  (None, 10, 10, 256)  0          ['mixed0[0][0]']
#  oling2D)
#
#  conv2d_222 (Conv2D)            (None, 10, 10, 64)   16384       ['mixed0[0][0]']
#
#  conv2d_224 (Conv2D)            (None, 10, 10, 64)   76800       ['activation_216[0][0]']
#
#  conv2d_227 (Conv2D)            (None, 10, 10, 96)   82944       ['activation_219[0][0]']
#
#  conv2d_228 (Conv2D)            (None, 10, 10, 64)   16384       ['average_pooling2d_2[0][0]']
#
#  batch_normalization_219 (Batch  (None, 10, 10, 64)  192         ['conv2d_222[0][0]']
#  Normalization)
#
#  batch_normalization_221 (Batch  (None, 10, 10, 64)  192         ['conv2d_224[0][0]']
#  Normalization)
#
#  batch_normalization_224 (Batch  (None, 10, 10, 96)  288         ['conv2d_227[0][0]']
#  Normalization)
#
#  batch_normalization_225 (Batch  (None, 10, 10, 64)  192         ['conv2d_228[0][0]']
#  Normalization)
#
#  activation_215 (Activation)    (None, 10, 10, 64)   0           ['batch_normalization_219[0][0]']
#
#  activation_217 (Activation)    (None, 10, 10, 64)   0           ['batch_normalization_221[0][0]']
#
#  activation_220 (Activation)    (None, 10, 10, 96)   0           ['batch_normalization_224[0][0]']
#
#  activation_221 (Activation)    (None, 10, 10, 64)   0           ['batch_normalization_225[0][0]']
#
#  mixed1 (Concatenate)           (None, 10, 10, 288)  0           ['activation_215[0][0]',
#                                                                   'activation_217[0][0]',
#                                                                   'activation_220[0][0]',
#                                                                   'activation_221[0][0]']
#
#  conv2d_232 (Conv2D)            (None, 10, 10, 64)   18432       ['mixed1[0][0]']
#
#  batch_normalization_229 (Batch  (None, 10, 10, 64)  192         ['conv2d_232[0][0]']
#  Normalization)
#
#  activation_225 (Activation)    (None, 10, 10, 64)   0           ['batch_normalization_229[0][0]']
#
#  conv2d_230 (Conv2D)            (None, 10, 10, 48)   13824       ['mixed1[0][0]']
#
#  conv2d_233 (Conv2D)            (None, 10, 10, 96)   55296       ['activation_225[0][0]']
#
#  batch_normalization_227 (Batch  (None, 10, 10, 48)  144         ['conv2d_230[0][0]']
#  Normalization)
#
#  batch_normalization_230 (Batch  (None, 10, 10, 96)  288         ['conv2d_233[0][0]']
#  Normalization)
#
#  activation_223 (Activation)    (None, 10, 10, 48)   0           ['batch_normalization_227[0][0]']
#
#  activation_226 (Activation)    (None, 10, 10, 96)   0           ['batch_normalization_230[0][0]']
#
#  average_pooling2d_3 (AveragePo  (None, 10, 10, 288)  0          ['mixed1[0][0]']
#  oling2D)
#
#  conv2d_229 (Conv2D)            (None, 10, 10, 64)   18432       ['mixed1[0][0]']
#
#  conv2d_231 (Conv2D)            (None, 10, 10, 64)   76800       ['activation_223[0][0]']
#
#  conv2d_234 (Conv2D)            (None, 10, 10, 96)   82944       ['activation_226[0][0]']
#
#  conv2d_235 (Conv2D)            (None, 10, 10, 64)   18432       ['average_pooling2d_3[0][0]']
#
#  batch_normalization_226 (Batch  (None, 10, 10, 64)  192         ['conv2d_229[0][0]']
#  Normalization)
#
#  batch_normalization_228 (Batch  (None, 10, 10, 64)  192         ['conv2d_231[0][0]']
#  Normalization)
#
#  batch_normalization_231 (Batch  (None, 10, 10, 96)  288         ['conv2d_234[0][0]']
#  Normalization)
#
#  batch_normalization_232 (Batch  (None, 10, 10, 64)  192         ['conv2d_235[0][0]']
#  Normalization)
#
#  activation_222 (Activation)    (None, 10, 10, 64)   0           ['batch_normalization_226[0][0]']
#
#  activation_224 (Activation)    (None, 10, 10, 64)   0           ['batch_normalization_228[0][0]']
#
#  activation_227 (Activation)    (None, 10, 10, 96)   0           ['batch_normalization_231[0][0]']
#
#  activation_228 (Activation)    (None, 10, 10, 64)   0           ['batch_normalization_232[0][0]']
#
#  mixed2 (Concatenate)           (None, 10, 10, 288)  0           ['activation_222[0][0]',
#                                                                   'activation_224[0][0]',
#                                                                   'activation_227[0][0]',
#                                                                   'activation_228[0][0]']
#
#  conv2d_237 (Conv2D)            (None, 10, 10, 64)   18432       ['mixed2[0][0]']
#
#  batch_normalization_234 (Batch  (None, 10, 10, 64)  192         ['conv2d_237[0][0]']
#  Normalization)
#
#  activation_230 (Activation)    (None, 10, 10, 64)   0           ['batch_normalization_234[0][0]']
#
#  conv2d_238 (Conv2D)            (None, 10, 10, 96)   55296       ['activation_230[0][0]']
#
#  batch_normalization_235 (Batch  (None, 10, 10, 96)  288         ['conv2d_238[0][0]']
#  Normalization)
#
#  activation_231 (Activation)    (None, 10, 10, 96)   0           ['batch_normalization_235[0][0]']
#
#  conv2d_236 (Conv2D)            (None, 4, 4, 384)    995328      ['mixed2[0][0]']
#
#  conv2d_239 (Conv2D)            (None, 4, 4, 96)     82944       ['activation_231[0][0]']
#
#  batch_normalization_233 (Batch  (None, 4, 4, 384)   1152        ['conv2d_236[0][0]']
#  Normalization)
#
#  batch_normalization_236 (Batch  (None, 4, 4, 96)    288         ['conv2d_239[0][0]']
#  Normalization)
#
#  activation_229 (Activation)    (None, 4, 4, 384)    0           ['batch_normalization_233[0][0]']
#
#  activation_232 (Activation)    (None, 4, 4, 96)     0           ['batch_normalization_236[0][0]']
#
#  max_pooling2d_9 (MaxPooling2D)  (None, 4, 4, 288)   0           ['mixed2[0][0]']
#
#  mixed3 (Concatenate)           (None, 4, 4, 768)    0           ['activation_229[0][0]',
#                                                                   'activation_232[0][0]',
#                                                                   'max_pooling2d_9[0][0]']
#
#  conv2d_244 (Conv2D)            (None, 4, 4, 128)    98304       ['mixed3[0][0]']
#
#  batch_normalization_241 (Batch  (None, 4, 4, 128)   384         ['conv2d_244[0][0]']
#  Normalization)
#
#  activation_237 (Activation)    (None, 4, 4, 128)    0           ['batch_normalization_241[0][0]']
#
#  conv2d_245 (Conv2D)            (None, 4, 4, 128)    114688      ['activation_237[0][0]']
#
#  batch_normalization_242 (Batch  (None, 4, 4, 128)   384         ['conv2d_245[0][0]']
#  Normalization)
#
#  activation_238 (Activation)    (None, 4, 4, 128)    0           ['batch_normalization_242[0][0]']
#
#  conv2d_241 (Conv2D)            (None, 4, 4, 128)    98304       ['mixed3[0][0]']
#
#  conv2d_246 (Conv2D)            (None, 4, 4, 128)    114688      ['activation_238[0][0]']
#
#  batch_normalization_238 (Batch  (None, 4, 4, 128)   384         ['conv2d_241[0][0]']
#  Normalization)
#
#  batch_normalization_243 (Batch  (None, 4, 4, 128)   384         ['conv2d_246[0][0]']
#  Normalization)
#
#  activation_234 (Activation)    (None, 4, 4, 128)    0           ['batch_normalization_238[0][0]']
#
#  activation_239 (Activation)    (None, 4, 4, 128)    0           ['batch_normalization_243[0][0]']
#
#  conv2d_242 (Conv2D)            (None, 4, 4, 128)    114688      ['activation_234[0][0]']
#
#  conv2d_247 (Conv2D)            (None, 4, 4, 128)    114688      ['activation_239[0][0]']
#
#  batch_normalization_239 (Batch  (None, 4, 4, 128)   384         ['conv2d_242[0][0]']
#  Normalization)
#
#  batch_normalization_244 (Batch  (None, 4, 4, 128)   384         ['conv2d_247[0][0]']
#  Normalization)
#
#  activation_235 (Activation)    (None, 4, 4, 128)    0           ['batch_normalization_239[0][0]']
#
#  activation_240 (Activation)    (None, 4, 4, 128)    0           ['batch_normalization_244[0][0]']
#
#  average_pooling2d_4 (AveragePo  (None, 4, 4, 768)   0           ['mixed3[0][0]']
#  oling2D)
#
#  conv2d_240 (Conv2D)            (None, 4, 4, 192)    147456      ['mixed3[0][0]']
#
#  conv2d_243 (Conv2D)            (None, 4, 4, 192)    172032      ['activation_235[0][0]']
#
#  conv2d_248 (Conv2D)            (None, 4, 4, 192)    172032      ['activation_240[0][0]']
#
#  conv2d_249 (Conv2D)            (None, 4, 4, 192)    147456      ['average_pooling2d_4[0][0]']
#
#  batch_normalization_237 (Batch  (None, 4, 4, 192)   576         ['conv2d_240[0][0]']
#  Normalization)
#
#  batch_normalization_240 (Batch  (None, 4, 4, 192)   576         ['conv2d_243[0][0]']
#  Normalization)
#
#  batch_normalization_245 (Batch  (None, 4, 4, 192)   576         ['conv2d_248[0][0]']
#  Normalization)
#
#  batch_normalization_246 (Batch  (None, 4, 4, 192)   576         ['conv2d_249[0][0]']
#  Normalization)
#
#  activation_233 (Activation)    (None, 4, 4, 192)    0           ['batch_normalization_237[0][0]']
#
#  activation_236 (Activation)    (None, 4, 4, 192)    0           ['batch_normalization_240[0][0]']
#
#  activation_241 (Activation)    (None, 4, 4, 192)    0           ['batch_normalization_245[0][0]']
#
#  activation_242 (Activation)    (None, 4, 4, 192)    0           ['batch_normalization_246[0][0]']
#
#  mixed4 (Concatenate)           (None, 4, 4, 768)    0           ['activation_233[0][0]',
#                                                                   'activation_236[0][0]',
#                                                                   'activation_241[0][0]',
#                                                                   'activation_242[0][0]']
#
#  conv2d_254 (Conv2D)            (None, 4, 4, 160)    122880      ['mixed4[0][0]']
#
#  batch_normalization_251 (Batch  (None, 4, 4, 160)   480         ['conv2d_254[0][0]']
#  Normalization)
#
#  activation_247 (Activation)    (None, 4, 4, 160)    0           ['batch_normalization_251[0][0]']
#
#  conv2d_255 (Conv2D)            (None, 4, 4, 160)    179200      ['activation_247[0][0]']
#
#  batch_normalization_252 (Batch  (None, 4, 4, 160)   480         ['conv2d_255[0][0]']
#  Normalization)
#
#  activation_248 (Activation)    (None, 4, 4, 160)    0           ['batch_normalization_252[0][0]']
#
#  conv2d_251 (Conv2D)            (None, 4, 4, 160)    122880      ['mixed4[0][0]']
#
#  conv2d_256 (Conv2D)            (None, 4, 4, 160)    179200      ['activation_248[0][0]']
#
#  batch_normalization_248 (Batch  (None, 4, 4, 160)   480         ['conv2d_251[0][0]']
#  Normalization)
#
#  batch_normalization_253 (Batch  (None, 4, 4, 160)   480         ['conv2d_256[0][0]']
#  Normalization)
#
#  activation_244 (Activation)    (None, 4, 4, 160)    0           ['batch_normalization_248[0][0]']
#
#  activation_249 (Activation)    (None, 4, 4, 160)    0           ['batch_normalization_253[0][0]']
#
#  conv2d_252 (Conv2D)            (None, 4, 4, 160)    179200      ['activation_244[0][0]']
#
#  conv2d_257 (Conv2D)            (None, 4, 4, 160)    179200      ['activation_249[0][0]']
#
#  batch_normalization_249 (Batch  (None, 4, 4, 160)   480         ['conv2d_252[0][0]']
#  Normalization)
#
#  batch_normalization_254 (Batch  (None, 4, 4, 160)   480         ['conv2d_257[0][0]']
#  Normalization)
#
#  activation_245 (Activation)    (None, 4, 4, 160)    0           ['batch_normalization_249[0][0]']
#
#  activation_250 (Activation)    (None, 4, 4, 160)    0           ['batch_normalization_254[0][0]']
#
#  average_pooling2d_5 (AveragePo  (None, 4, 4, 768)   0           ['mixed4[0][0]']
#  oling2D)
#
#  conv2d_250 (Conv2D)            (None, 4, 4, 192)    147456      ['mixed4[0][0]']
#
#  conv2d_253 (Conv2D)            (None, 4, 4, 192)    215040      ['activation_245[0][0]']
#
#  conv2d_258 (Conv2D)            (None, 4, 4, 192)    215040      ['activation_250[0][0]']
#
#  conv2d_259 (Conv2D)            (None, 4, 4, 192)    147456      ['average_pooling2d_5[0][0]']
#
#  batch_normalization_247 (Batch  (None, 4, 4, 192)   576         ['conv2d_250[0][0]']
#  Normalization)
#
#  batch_normalization_250 (Batch  (None, 4, 4, 192)   576         ['conv2d_253[0][0]']
#  Normalization)
#
#  batch_normalization_255 (Batch  (None, 4, 4, 192)   576         ['conv2d_258[0][0]']
#  Normalization)
#
#  batch_normalization_256 (Batch  (None, 4, 4, 192)   576         ['conv2d_259[0][0]']
#  Normalization)
#
#  activation_243 (Activation)    (None, 4, 4, 192)    0           ['batch_normalization_247[0][0]']
#
#  activation_246 (Activation)    (None, 4, 4, 192)    0           ['batch_normalization_250[0][0]']
#
#  activation_251 (Activation)    (None, 4, 4, 192)    0           ['batch_normalization_255[0][0]']
#
#  activation_252 (Activation)    (None, 4, 4, 192)    0           ['batch_normalization_256[0][0]']
#
#  mixed5 (Concatenate)           (None, 4, 4, 768)    0           ['activation_243[0][0]',
#                                                                   'activation_246[0][0]',
#                                                                   'activation_251[0][0]',
#                                                                   'activation_252[0][0]']
#
#  conv2d_264 (Conv2D)            (None, 4, 4, 160)    122880      ['mixed5[0][0]']
#
#  batch_normalization_261 (Batch  (None, 4, 4, 160)   480         ['conv2d_264[0][0]']
#  Normalization)
#
#  activation_257 (Activation)    (None, 4, 4, 160)    0           ['batch_normalization_261[0][0]']
#
#  conv2d_265 (Conv2D)            (None, 4, 4, 160)    179200      ['activation_257[0][0]']
#
#  batch_normalization_262 (Batch  (None, 4, 4, 160)   480         ['conv2d_265[0][0]']
#  Normalization)
#
#  activation_258 (Activation)    (None, 4, 4, 160)    0           ['batch_normalization_262[0][0]']
#
#  conv2d_261 (Conv2D)            (None, 4, 4, 160)    122880      ['mixed5[0][0]']
#
#  conv2d_266 (Conv2D)            (None, 4, 4, 160)    179200      ['activation_258[0][0]']
#
#  batch_normalization_258 (Batch  (None, 4, 4, 160)   480         ['conv2d_261[0][0]']
#  Normalization)
#
#  batch_normalization_263 (Batch  (None, 4, 4, 160)   480         ['conv2d_266[0][0]']
#  Normalization)
#
#  activation_254 (Activation)    (None, 4, 4, 160)    0           ['batch_normalization_258[0][0]']
#
#  activation_259 (Activation)    (None, 4, 4, 160)    0           ['batch_normalization_263[0][0]']
#
#  conv2d_262 (Conv2D)            (None, 4, 4, 160)    179200      ['activation_254[0][0]']
#
#  conv2d_267 (Conv2D)            (None, 4, 4, 160)    179200      ['activation_259[0][0]']
#
#  batch_normalization_259 (Batch  (None, 4, 4, 160)   480         ['conv2d_262[0][0]']
#  Normalization)
#
#  batch_normalization_264 (Batch  (None, 4, 4, 160)   480         ['conv2d_267[0][0]']
#  Normalization)
#
#  activation_255 (Activation)    (None, 4, 4, 160)    0           ['batch_normalization_259[0][0]']
#
#  activation_260 (Activation)    (None, 4, 4, 160)    0           ['batch_normalization_264[0][0]']
#
#  average_pooling2d_6 (AveragePo  (None, 4, 4, 768)   0           ['mixed5[0][0]']
#  oling2D)
#
#  conv2d_260 (Conv2D)            (None, 4, 4, 192)    147456      ['mixed5[0][0]']
#
#  conv2d_263 (Conv2D)            (None, 4, 4, 192)    215040      ['activation_255[0][0]']
#
#  conv2d_268 (Conv2D)            (None, 4, 4, 192)    215040      ['activation_260[0][0]']
#
#  conv2d_269 (Conv2D)            (None, 4, 4, 192)    147456      ['average_pooling2d_6[0][0]']
#
#  batch_normalization_257 (Batch  (None, 4, 4, 192)   576         ['conv2d_260[0][0]']
#  Normalization)
#
#  batch_normalization_260 (Batch  (None, 4, 4, 192)   576         ['conv2d_263[0][0]']
#  Normalization)
#
#  batch_normalization_265 (Batch  (None, 4, 4, 192)   576         ['conv2d_268[0][0]']
#  Normalization)
#
#  batch_normalization_266 (Batch  (None, 4, 4, 192)   576         ['conv2d_269[0][0]']
#  Normalization)
#
#  activation_253 (Activation)    (None, 4, 4, 192)    0           ['batch_normalization_257[0][0]']
#
#  activation_256 (Activation)    (None, 4, 4, 192)    0           ['batch_normalization_260[0][0]']
#
#  activation_261 (Activation)    (None, 4, 4, 192)    0           ['batch_normalization_265[0][0]']
#
#  activation_262 (Activation)    (None, 4, 4, 192)    0           ['batch_normalization_266[0][0]']
#
#  mixed6 (Concatenate)           (None, 4, 4, 768)    0           ['activation_253[0][0]',
#                                                                   'activation_256[0][0]',
#                                                                   'activation_261[0][0]',
#                                                                   'activation_262[0][0]']
#
# ...
#
#  conv2d_302 (Conv2D)            (None, 1, 1, 384)    442368      ['activation_293[0][0]']
#
#  average_pooling2d_9 (AveragePo  (None, 1, 1, 2048)  0           ['mixed9[0][0]']
#  oling2D)
#
#  conv2d_295 (Conv2D)            (None, 1, 1, 320)    655360      ['mixed9[0][0]']
#
#  batch_normalization_294 (Batch  (None, 1, 1, 384)   1152        ['conv2d_297[0][0]']
#  Normalization)
#
#  batch_normalization_295 (Batch  (None, 1, 1, 384)   1152        ['conv2d_298[0][0]']
#  Normalization)
#
#  batch_normalization_298 (Batch  (None, 1, 1, 384)   1152        ['conv2d_301[0][0]']
#  Normalization)
#
#  batch_normalization_299 (Batch  (None, 1, 1, 384)   1152        ['conv2d_302[0][0]']
#  Normalization)
#
#  conv2d_303 (Conv2D)            (None, 1, 1, 192)    393216      ['average_pooling2d_9[0][0]']
#
#  batch_normalization_292 (Batch  (None, 1, 1, 320)   960         ['conv2d_295[0][0]']
#  Normalization)
#
#  activation_290 (Activation)    (None, 1, 1, 384)    0           ['batch_normalization_294[0][0]']
#
#  activation_291 (Activation)    (None, 1, 1, 384)    0           ['batch_normalization_295[0][0]']
#
#  activation_294 (Activation)    (None, 1, 1, 384)    0           ['batch_normalization_298[0][0]']
#
#  activation_295 (Activation)    (None, 1, 1, 384)    0           ['batch_normalization_299[0][0]']
#
#  batch_normalization_300 (Batch  (None, 1, 1, 192)   576         ['conv2d_303[0][0]']
#  Normalization)
#
#  activation_288 (Activation)    (None, 1, 1, 320)    0           ['batch_normalization_292[0][0]']
#
#  mixed9_1 (Concatenate)         (None, 1, 1, 768)    0           ['activation_290[0][0]',
#                                                                   'activation_291[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 1, 1, 768)    0           ['activation_294[0][0]',
#                                                                   'activation_295[0][0]']
#
#  activation_296 (Activation)    (None, 1, 1, 192)    0           ['batch_normalization_300[0][0]']
#
#  mixed10 (Concatenate)          (None, 1, 1, 2048)   0           ['activation_288[0][0]',
#                                                                   'mixed9_1[0][0]',
#                                                                   'concatenate_1[0][0]',
#                                                                   'activation_296[0][0]']
#
#  flatten_10 (Flatten)           (None, 2048)         0           ['mixed10[0][0]']
#
#  fc1 (Dense)                    (None, 1000)         2049000     ['flatten_10[0][0]']
#
#  dropout_13 (Dropout)           (None, 1000)         0           ['fc1[0][0]']
#
#  predictions (Dense)            (None, 5)            5005        ['dropout_13[0][0]']
#
# ==================================================================================================
# Total params: 23,856,789
# Trainable params: 2,054,005
# Non-trainable params: 21,802,784
# __________________________________________________________________________________________________
# Epoch 1/100
# 5/5 [==============================] - 14s 2s/step - loss: 1.8595 - accuracy: 0.2594 - val_loss: 1.5573 - val_accuracy: 0.4375
# Epoch 2/100
# 5/5 [==============================] - 6s 1s/step - loss: 1.3249 - accuracy: 0.4531 - val_loss: 1.3201 - val_accuracy: 0.4875
# Epoch 3/100
# 5/5 [==============================] - 6s 1s/step - loss: 0.9607 - accuracy: 0.6469 - val_loss: 1.1618 - val_accuracy: 0.5875
# Epoch 4/100
# 5/5 [==============================] - 6s 1s/step - loss: 0.7978 - accuracy: 0.7094 - val_loss: 1.0428 - val_accuracy: 0.6500
# Epoch 5/100
# 5/5 [==============================] - 6s 1s/step - loss: 0.6018 - accuracy: 0.8406 - val_loss: 0.9693 - val_accuracy: 0.7000
# Epoch 6/100
# 5/5 [==============================] - 6s 1s/step - loss: 0.4925 - accuracy: 0.8687 - val_loss: 0.9037 - val_accuracy: 0.7000
# Epoch 7/100
# 5/5 [==============================] - 6s 1s/step - loss: 0.4158 - accuracy: 0.9281 - val_loss: 0.8751 - val_accuracy: 0.7375
# Epoch 8/100
# 5/5 [==============================] - 6s 1s/step - loss: 0.3674 - accuracy: 0.9406 - val_loss: 0.8339 - val_accuracy: 0.7500
# Epoch 9/100
# 5/5 [==============================] - 6s 1s/step - loss: 0.3024 - accuracy: 0.9594 - val_loss: 0.7994 - val_accuracy: 0.7625
# Epoch 10/100
# 5/5 [==============================] - 6s 1s/step - loss: 0.2489 - accuracy: 0.9781 - val_loss: 0.7744 - val_accuracy: 0.7625
# Epoch 11/100
# 5/5 [==============================] - 6s 1s/step - loss: 0
100
# 5/5 [==============================] - 6s 1s/step - loss: 0.0214 - accuracy: 1.0000 - val_loss: 0.6937 - val_accuracy: 0.7875
# Epoch 48/100
# 5/5 [==============================] - 6s 1s/step - loss: 0.0217 - accuracy: 1.0000 - val_loss: 0.6953 - val_accuracy: 0.7875
# Epoch 49/100
# 5/5 [==============================] - 6s 1s/step - loss: 0.0199 - accuracy: 1.0000 - val_loss: 0.6942 - val_accuracy: 0.7875
# Epoch 50/100
# 5/5 [==============================] - 6s 1s/step - loss: 0.0198 - accuracy: 1.0000 - val_loss: 0.6908 - val_accuracy: 0.7875
# Epoch 51/100
# 5/5 [==============================] - 6s 1s/step - loss: 0.0193 - accuracy: 1.0000 - val_loss: 0.6894 - val_accuracy: 0.7875
# Epoch 52/100
# 5/5 [==============================] - 6s 1s/step - loss: 0.0219 - accuracy: 1.0000 - val_loss: 0.6862 - val_accuracy: 0.7875
# Epoch 53/100
# 5/5 [==============================] - 6s 1s/step - loss: 0.0185 - accuracy: 1.0000 - val_loss: 0.6855 - val_accuracy: 0.7875
# Epoch 54/100
# 5/5 [==============================] - 6s 1s/step - loss: 0.0192 - accuracy: 1.0000 - val_loss: 0.6851 - val_accuracy: 0.7875
# Epoch 55/100
# 5/5 [==============================] - 6s 1s/step - loss: 0.0176 - accuracy: 1.0000 - val_loss: 0.6881 - val_accuracy: 0.7875
# Epoch 56/100
# 5/5 [==============================] - 6s 1s/step - loss: 0.0164 - accuracy: 1.0000 - val_loss: 0.6939 - val_accuracy: 0.7875
# Epoch 57/100
# 5/5 [==============================] - 6s 1s/step - loss: 0.0160 - accuracy: 1.0000 - val_loss: 0.6975 - val_accuracy: 0.7875
# Epoch 58/100
# 5/5 [==============================] - 6s 1s/step - loss: 0.0161 - accuracy: 1.0000 - val_loss: 0.6986 - val_accuracy: 0.7875
# Epoch 59/100
# 5/5 [==============================] - 6s 1s/step - loss: 0.0156 - accuracy: 1.0000 - val_loss: 0.7038 - val_accuracy: 0.7875
# Epoch 60/100
# 5/5 [==============================] - 6s 1s/step - loss: 0.0154 - accuracy: 1.0000 - val_loss: 0.7088 - val_accuracy: 0.7875
# Epoch 61/100
# 5/5 [==============================] - 6s 1s/step - loss: 0.0146 - accuracy: 1.0000 - val_loss: 0.7105 - val_accuracy: 0.7875
# Epoch 62/100
# 5/5 [==============================] - 6s 1s/step - loss: 0.0140 - accuracy: 1.0000 - val_loss: 0.7097 - val_accuracy: 0.7875
# Epoch 63/100
# 5/5 [==============================] - 6s 1s/step - loss: 0.0130 - accuracy: 1.0000 - val_loss: 0.7061 - val_accuracy: 0.7875
# Epoch 64/100
# 5/5 [==============================] - 6s 1s/step - loss: 0.0134 - accuracy: 1.0000 - val_loss: 0.7090 - val_accuracy: 0.7875
# Epoch 65/100
# 5/5 [==============================] - 6s 1s/step - loss: 0.0134 - accuracy: 1.0000 - val_loss: 0.7154 - val_accuracy: 0.7875
# Epoch 66/100
# 5/5 [==============================] - 6s 1s/step - loss: 0.0125 - accuracy: 1.0000 - val_loss: 0.7147 - val_accuracy: 0.7875
# Epoch 67/100
# 5/5 [==============================] - 6s 1s/step - loss: 0.0118 - accuracy: 1.0000 - val_loss: 0.7106 - val_accuracy: 0.7875
# Epoch 68/100
# 5/5 [==============================] - 6s 1s/step - loss: 0.0110 - accuracy: 1.0000 - val_loss: 0.7089 - val_accuracy: 0.7875
# Epoch 69/100
# 5/5 [==============================] - 6s 1s/step - loss: 0.0115 - accuracy: 1.0000 - val_loss: 0.7090 - val_accuracy: 0.8125
# Epoch 70/100
# 5/5 [==============================] - 6s 1s/step - loss: 0.0109 - accuracy: 1.0000 - val_loss: 0.7105 - val_accuracy: 0.8125
# Epoch 71/100
# 5/5 [==============================] - 6s 1s/step - loss: 0.0117 - accuracy: 1.0000 - val_loss: 0.7077 - val_accuracy: 0.8125

# %%
test_eval = model_out_incepv3.evaluate(x_test, test_Y_one_hot, verbose=1)

print('Test loss:', test_eval[0])
print('Test accuracy:', test_eval[1])

predicted_classes = model_out_incepv3.predict(x_test)
predicted_classes = np.argmax(np.round(predicted_classes),axis=1)
predicted_classes.shape, y_test.shape
# Out:
# 4/4 [==============================] - 2s 362ms/step - loss: 0.5272 - accuracy: 0.8300
# Test loss: 0.5271933078765869
# Test accuracy: 0.8299999833106995
# ((100,), (100,))

# %%
from sklearn.metrics import classification_report
target_names = ["Class {}".format(i) for i in range(nClasses)]
print(classification_report(y_test, predicted_classes, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#      Class 0       0.73      0.76      0.74        21
#      Class 1       0.79      0.79      0.79        19
#      Class 2       0.76      0.76      0.76        17
#      Class 3       0.95      0.78      0.86        23
#      Class 4       0.87      1.00      0.93        20
#
#     accuracy                           0.82       100
#    macro avg       0.82      0.82      0.82       100
# weighted avg       0.82      0.82      0.82       100

# %%
from sklearn.metrics import confusion_matrix

matriz=confusion_matrix(y_test, predicted_classes)
print(matriz)
# Out:
# [[16  4  1  0  0]
#  [ 1 15  2  0  1]
#  [ 2  0 13  1  1]
#  [ 3  0  1 18  1]
#  [ 0  0  0  0 20]]

# %%
import numpy as np
import cv2
import glob
import os
import matplotlib.pyplot as plt
import string
from mlxtend.plotting import plot_decision_regions
#from mpl_toolkits.mplot3d import Axes3D
#from sklearn.decomposition import PCA
#from sklearn.preprocessing import StandardScaler
#from sklearn.neighbors import KNeighborsClassifier
#from sklearn.tree import DecisionTreeClassifier
#from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.utils.multiclass import unique_labels
from sklearn import metrics
#from sklearn.svm import SVC


import json
from skimage import color
from skimage.feature import hog
#from sklearn import svm
from sklearn.metrics import classification_report,accuracy_score, recall_score
from subprocess import check_output

def plot_confusion_matrix(y_true, y_pred, classes,
                          normalize=False,
                          title=None,
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if not title:
        if normalize:
            title = 'Matriz de confusión'
        else:
            title = 'Matriz de confusión, sin normalización'

    # Compute confusion matrix

    cm = metrics.confusion_matrix(y_true, y_pred)
    # Only use the labels that appear in the data
    classes = unique_labels(y_true, y_pred)
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    fig, ax = plt.subplots()
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    # We want to show all ticks...

    ax.set(xticks=np.arange(cm.shape[1]),
           yticks=np.arange(cm.shape[0]),
           # ... and label them with the respective list entries
           xticklabels=labels, yticklabels=labels,
           title=title,
           ylabel='Etiqueta verdadera',
           xlabel='Etiqueta prevista')

    # Rotate the tick labels and set their alignment.

    plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
             rotation_mode="anchor")

    # Loop over data dimensions and create text annotations.

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], fmt),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")
    fig.tight_layout()
    return cm,ax

precision=metrics.accuracy_score(y_test,predicted_classes, normalize=False)

print("Accuracy:{0:.2f}".format(precision))
cm,_=plot_confusion_matrix(y_test,predicted_classes,classes=nClasses,normalize=False,title="Matriz de confusión no nomalizada")
plt.show()


precision=metrics.accuracy_score(y_test,predicted_classes, normalize=True)*100

print("Accuracy:{0:.2f}%".format(precision))
cm,_=plot_confusion_matrix(y_test,predicted_classes,classes=nClasses,normalize=True,title="Matriz de confusión normalizada")
plt.show()
# Out:
# Accuracy:82.00
# Accuracy:82.00%

# %%
model_out_incepv3.save("/content/drive/My Drive/source_dir/gradoma_final_incepv3.h5py")
# Out:
# INFO:tensorflow:Assets written to: /content/drive/My Drive/source_dir/gradoma_final_incepv3.h5py/assets
